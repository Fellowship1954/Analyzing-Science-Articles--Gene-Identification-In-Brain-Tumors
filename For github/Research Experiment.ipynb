# %% [markdown]
# # Analyzing Science Articles: Gene Identification In Brain Tumors
#
# ## By: Julia Christensen

# %% [markdown]
# -------------------------------------------------
# The steps of the experiment down below.
#
# #### This is for sections
# #### <span style="color:blue"> Titles in this color are the subcategories</span>
# ##### <span style="color:red"> These are to help separate Abstracts from Full-Text </span>
# --------------------------------------------------

# %% [markdown]
# ### Dealing with PMIDs
# This is were looking through the samples list of PMIDs checking for duplicates and separating them into abstract and full-text.

# %% [markdown]
# #### <span style="color:blue">Checking Data For Duplicates</span>
# Checking at duplicates for the total samples.

# %%
# Step 1: Read the text file and extract ID numbers
file_name = 'Gene and Diseases proper pmids.txt'
id_num = []

with open(file_name, 'r') as file:
    for line in file:
        line = line.strip()
        if line:
            id_num.append(line)
            
# Step 2: Create a set to store the ID 
#     numbers for quick uniqueness checks
id_set = set()
duplicate_ids = []

# Step 3: Check for duplicates
for id_number in id_num:
    if id_number in id_set:
        duplicate_ids.append(id_number)
    else:
        id_set.add(id_number)
# Output
if not duplicate_ids:
    print("No duplicates found.")
else:
    print("Duplicates:")
    for id in duplicate_ids:
        print(id)
# Out:
# No duplicates found.

# %% [markdown]
# #### <span style="color:blue"> Count Number of Samples</span>
# Looks at how many PMIDs are in the total sample file.

# %%
# Step 1: Read the text file and extract ID numbers
file_name = 'Gene and Diseases proper pmids.txt'
id_num = []

with open(file_name, 'r') as file:
    for line in file:
        line = line.strip()
        if line:
            id_num.append(line)
            
# Step 2: Count the number of samples
total_count_sample = len(id_num)

# Output
print(f"The total number of samples for this experiment: {total_count_sample}")
# Out:
# The total number of samples for this experiment: 1100

# %% [markdown]
# #### <span style="color:blue">Separating Abstracts and Full-Text IDs</span>
# This is where separating the abstracts and full-text happens in preparation of obtaining the data. It will also check for duplicates and make sure nothing was lost.

# %% [markdown]
# #### <span style="color:red"> Length Checking for Abstracts</span>
# Checking the length or number of samples in the abstracts file

# %%
# Step 1: Read the text file and extract ID numbers
file_name = 'Pmids_Abstracts.txt'
id_num = []

with open(file_name, 'r') as file:
    for line in file:
        line = line.strip()
        if line:
            id_num.append(line)
            
# Step 2: Count the number of samples
ab_count_sample = len(id_num)

# Output
print(f"The total number of samples for this experiment: {ab_count_sample}")
# Out:
# The total number of samples for this experiment: 683

# %% [markdown]
# #### <span style="color:red"> Length Checking for Full-Text</span>
# Checking the length or number of samples in the full-text file

# %%
# Looking at length of full-text list

# Step 1: Read the text file and extract ID numbers
file_name = 'Pmcids_FullText.txt'
id_num = []

with open(file_name, 'r') as file:
    for line in file:
        line = line.strip()
        if line:
            id_num.append(line)
            
# Step 2: Count the number of samples
full_count_sample = len(id_num)

# Output
print(f"The total number of samples for this experiment: {full_count_sample}")
# Out:
# The total number of samples for this experiment: 417

# %% [markdown]
# #### <span style="color:red"> Checking for Duplicates in Abstracts</span>
# Checking for duplicates in the abstracts file

# %%
# Step 1: Read the text file and extract ID numbers
file_name = 'Pmids_Abstracts.txt'
id_num = []

with open(file_name, 'r') as file:
    for line in file:
        line = line.strip()
        if line:
            id_num.append(line)
            
# Step 2: Create a set to store the ID numbers for quick uniqueness checks
id_set = set()
duplicate_ids = []

# Step 3: Check for duplicates
for id_number in id_num:
    if id_number in id_set:
        duplicate_ids.append(id_number)
    else:
        id_set.add(id_number)
# Output
if not duplicate_ids:
    print("No duplicates found.")
else:
    print("Duplicates:")
    for id in duplicate_ids:
        print(id)
# Out:
# No duplicates found.

# %% [markdown]
# #### <span style="color:red"> Checking for Duplicates in Full-Text</span>
# Checking for duplicates in the full-text file

# %%
# Step 1: Read the text file and extract ID numbers
file_name = 'Pmcids_FullText.txt'
id_num = []

with open(file_name, 'r') as file:
    for line in file:
        line = line.strip()
        if line:
            id_num.append(line)
            
# Step 2: Create a set to store the ID numbers for quick uniqueness checks
id_set = set()
duplicate_ids = []

# Step 3: Check for duplicates
for id_number in id_num:
    if id_number in id_set:
        duplicate_ids.append(id_number)
    else:
        id_set.add(id_number)
# Output
if not duplicate_ids:
    print("No duplicates found.")
else:
    print("Duplicates:")
    for id in duplicate_ids:
        print(id)
# Out:
# No duplicates found.

# %% [markdown]
# #### <span style="color:red"> Checking for Duplicates in Abstracts and Full-Text</span>
# Checking and making sure that the PMIDs in either file is not in the other.

# %%
# Step 1: Read the contents of the first text file and extract numbers
file_path1 = 'Pmids_Abstracts.txt'
numbers1 = set()

with open(file_path1, 'r') as file1:
    for line in file1:
        line = line.strip()
        if line:  # Ignore empty lines
            numbers1.add(line)

# Step 2: Read the contents of the second text file and extract numbers
file_path2 = 'Pmcids_FullText.txt'
numbers2 = set()

with open(file_path2, 'r') as file2:
    for line in file2:
        line = line.strip()
        if line:  # Ignore empty lines
            numbers2.add(line)

# Step 3: Compare the two sets to find duplicates
duplicates = numbers1.intersection(numbers2)

# Check if there are duplicates (Output)
if not duplicates:
    print("No duplicates found.")
else:
    print("Duplicates found:")
    for duplicate in duplicates:
        print(duplicate)
# Out:
# No duplicates found.

# %% [markdown]
# #### <span style="color:red"> Making Sure That The Length of Each File Equals Total Samples</span>
# Making sure that the numbers equal the total samples.

# %%
# do the numbers add up?
print(total_count_sample)

match = ab_count_sample + full_count_sample
print(match)

total_count_sample == match
# Out:
# 1100
# 1100
# True

# %% [markdown]
# <span style="color:purple">**These are testing the API code with an PMID in abstracts file.**</span>

# %%
# For Abstracts

import requests

# Define the URL
url = "https://www.ncbi.nlm.nih.gov/research/pubtator-api/publications/export/biocjson?pmids=28516751&concepts=gene"

# Send a GET request to the URL
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Process the response data as needed
    data = response.text  # This assumes the response is in text format
    # You can then parse and use the response data.

    # Example: Print the response data
    print(data)
else:
    print("Error:", response.status_code)
    print(response.text)  # Print the response content for error debugging
# Out:
# {"_id": "28516751|None", "id": "28516751", "infons": {}, "passages": [{"infons": {"journal": "Pediatr Endocrinol Rev; 2017 Mar; 14 Suppl 1(Suppl 1) 229-234. doi:10.17458/per.vol14.2017.t.growthhormonetherapy", "year": "2017", "type": "title", "authors": "Teramoto A", "section": "Title"}, "offset": 0, "text": "Growth Hormone Therapy and Brain Tumors.", "sentences": [], "annotations": [{"id": "2", "infons": {"identifier": "2688", "type": "Gene", "ncbi_homologene": "128036"}, "text": "Growth Hormone", "locations": [{"offset": 0, "length": 14}]}, {"id": "3", "infons": {"identifier": "MESH:D001932", "type": "Disease"}, "text": "Brain Tumors", "locations": [{"offset": 27, "length": 12}]}], "relations": []}, {"infons": {"type": "abstract", "section": "Abstract"}, "offset": 41, "text": "As one of the projects of the Adverse Events Study Group of the Foundation for Growth Science in Japan, the literatures on the recurrence and / or regrowth or new formation of brain tumors in patients treated with growth hormone (GH) were reviewed. Since the tumor volume of the sellar lesion can be accurately evaluated only by magnetic resonance imaging (MRI), the related literatures published after 1990 were retrieved by searching under keywords, such as GH, replacement therapy, brain tumor, recurrence, tumor formation, etc. It is undeniable that GH therapy may result in tumor enlargement only in a very small percentage of cases. However, within a scientifically reliable range of confirmation with large-scale researches and case-control studies, it can be considered that there is no relation between GH therapy and the recurrence or new formation of brain tumors.", "sentences": [], "annotations": [{"id": "16", "infons": {"identifier": "MESH:D001932", "type": "Disease"}, "text": "brain tumors", "locations": [{"offset": 217, "length": 12}]}, {"id": "17", "infons": {"identifier": "9606", "type": "Species"}, "text": "patients", "locations": [{"offset": 233, "length": 8}]}, {"id": "18", "infons": {"identifier": "2688", "type": "Gene", "ncbi_homologene": "128036"}, "text": "growth hormone", "locations": [{"offset": 255, "length": 14}]}, {"id": "19", "infons": {"identifier": "2688", "type": "Gene", "ncbi_homologene": "128036"}, "text": "GH", "locations": [{"offset": 271, "length": 2}]}, {"id": "20", "infons": {"identifier": "MESH:D009369", "type": "Disease"}, "text": "tumor", "locations": [{"offset": 300, "length": 5}]}, {"id": "21", "infons": {"identifier": "2688", "type": "Gene", "ncbi_homologene": "128036"}, "text": "GH", "locations": [{"offset": 501, "length": 2}]}, {"id": "22", "infons": {"identifier": "MESH:D001932", "type": "Disease"}, "text": "brain tumor", "locations": [{"offset": 526, "length": 11}]}, {"id": "23", "infons": {"identifier": "MESH:D009369", "type": "Disease"}, "text": "tumor", "locations": [{"offset": 551, "length": 5}]}, {"id": "24", "infons": {"identifier": "2688", "type": "Gene", "ncbi_homologene": "128036"}, "text": "GH", "locations": [{"offset": 595, "length": 2}]}, {"id": "25", "infons": {"identifier": "MESH:D009369", "type": "Disease"}, "text": "tumor", "locations": [{"offset": 620, "length": 5}]}, {"id": "26", "infons": {"identifier": "2688", "type": "Gene", "ncbi_homologene": "128036"}, "text": "GH", "locations": [{"offset": 853, "length": 2}]}, {"id": "27", "infons": {"identifier": "MESH:D001932", "type": "Disease"}, "text": "brain tumors", "locations": [{"offset": 903, "length": 12}]}], "relations": []}], "relations": [], "pmid": 28516751, "pmcid": null, "created": {"$date": 1643813405108}, "accessions": ["disease@MESH:D001932", "species@9606", "disease@MESH:D009369", "gene@2688"], "journal": "Pediatr Endocrinol Rev", "year": 2017, "authors": ["Teramoto A"]}

# %%
# For Abstracts
import requests
import json

# Define the URL
url = "https://www.ncbi.nlm.nih.gov/research/pubtator-api/publications/export/biocjson?pmids=28516751&concepts=gene"

# Send a GET request to the URL
response = requests.get(url)

test = json.loads(response.text)

#print(test)

# Creating dictionary for gene names
data_test = []
for passage in test['passages']:
    for ann in passage['annotations']:
        infons = ann.get('infons', {})
        if infons.get('type') == 'Gene':
            identifier = infons.get('identifier')
            gene_type = infons.get('type')
            gene_name = ann.get('text')
            
            gene_info = {"identifier" : identifier, "type": gene_type, "gene_name": gene_name}
            
            data_test.append(gene_info)
    
print(data_test)
# Out:
# [{'identifier': '2688', 'type': 'Gene', 'gene_name': 'Growth Hormone'}, {'identifier': '2688', 'type': 'Gene', 'gene_name': 'growth hormone'}, {'identifier': '2688', 'type': 'Gene', 'gene_name': 'GH'}, {'identifier': '2688', 'type': 'Gene', 'gene_name': 'GH'}, {'identifier': '2688', 'type': 'Gene', 'gene_name': 'GH'}, {'identifier': '2688', 'type': 'Gene', 'gene_name': 'GH'}]

# %%
import requests
import json

# Define the URL
url = "https://www.ncbi.nlm.nih.gov/research/pubtator-api/publications/export/biocjson?pmids=28516751,30239861,33069197&concepts=gene"

# Send a GET request to the URL
response = requests.get(url)

# Split the response by newline characters to handle multiple JSON objects
if response.status_code == 200:
    json_objects = response.text.split('\n')

    # Parse each individual JSON object
    for json_obj in json_objects:
        if json_obj.strip():  
            data = json.loads(json_obj)
            print(data)
else:
    print("Error:", response.status_code)
    print(response.text)
# Out:
# {'_id': '33069197|None', 'id': '33069197', 'infons': {}, 'passages': [{'infons': {'journal': 'Curr Cancer Drug Targets;2021; 21 (1) 2-20. doi:10.2174/1568009620666201016121005', 'year': '2021', 'type': 'title', 'authors': 'Ashrafizadeh M, Zarabi A, Hushmandi K, Moghadam ER, Hashemi F, Daneshi S, Hashemi F, Tavakol S, Mohammadinejad R, Najafi M, Dudha N, Garg M, ', 'section': 'Title'}, 'offset': 0, 'text': 'C-Myc Signaling Pathway in Treatment and Prevention of Brain Tumors.', 'sentences': [], 'annotations': [{'id': '2', 'infons': {'identifier': '4609', 'type': 'Gene', 'ncbi_homologene': '31092'}, 'text': 'C-Myc', 'locations': [{'offset': 0, 'length': 5}]}, {'id': '3', 'infons': {'identifier': 'MESH:D001932', 'type': 'Disease'}, 'text': 'Brain Tumors', 'locations': [{'offset': 55, 'length': 12}]}], 'relations': []}, {'infons': {'type': 'abstract', 'section': 'Abstract'}, 'offset': 69, 'text': 'Brain tumors are responsible for high morbidity and mortality worldwide. Several factors such as the presence of blood-brain barrier (BBB), sensitive location in the brain, and unique biological features challenge the treatment of brain tumors. The conventional drugs are no longer effective in the treatment of brain tumors, and scientists are trying to find novel therapeutics for brain tumors. In this way, identification of molecular pathways can facilitate finding an effective treatment. c-Myc is an oncogene signaling pathway capable of regulation of biological processes such as apoptotic cell death, proliferation, survival, differentiation, and so on. These pleiotropic effects of c-Myc have resulted in much fascination with its role in different cancers, particularly brain tumors. In the present review, we aim to demonstrate the upstream and down-stream mediators of c-Myc in brain tumors such as glioma, glioblastoma, astrocytoma, and medulloblastoma. The capacity of c-Myc as a prognostic factor in brain tumors will be investigated. Our goal is to define an axis in which the c-Myc signaling pathway plays a crucial role and to provide direction for therapeutic targeting in these signaling networks in brain tumors.', 'sentences': [], 'annotations': [{'id': '23', 'infons': {'identifier': 'MESH:D001932', 'type': 'Disease'}, 'text': 'Brain tumors', 'locations': [{'offset': 69, 'length': 12}]}, {'id': '24', 'infons': {'identifier': 'MESH:D003643', 'type': 'Disease'}, 'text': 'mortality', 'locations': [{'offset': 121, 'length': 9}]}, {'id': '25', 'infons': {'identifier': 'MESH:D001932', 'type': 'Disease'}, 'text': 'brain tumors', 'locations': [{'offset': 300, 'length': 12}]}, {'id': '26', 'infons': {'identifier': 'MESH:D001932', 'type': 'Disease'}, 'text': 'brain tumors', 'locations': [{'offset': 381, 'length': 12}]}, {'id': '27', 'infons': {'identifier': 'MESH:D001932', 'type': 'Disease'}, 'text': 'brain tumors', 'locations': [{'offset': 452, 'length': 12}]}, {'id': '28', 'infons': {'identifier': '4609', 'type': 'Gene', 'ncbi_homologene': '31092'}, 'text': 'c-Myc', 'locations': [{'offset': 563, 'length': 5}]}, {'id': '29', 'infons': {'identifier': '4609', 'type': 'Gene', 'ncbi_homologene': '31092'}, 'text': 'c-Myc', 'locations': [{'offset': 760, 'length': 5}]}, {'id': '30', 'infons': {'identifier': 'MESH:D009369', 'type': 'Disease'}, 'text': 'cancers', 'locations': [{'offset': 827, 'length': 7}]}, {'id': '31', 'infons': {'identifier': 'MESH:D001932', 'type': 'Disease'}, 'text': 'brain tumors', 'locations': [{'offset': 849, 'length': 12}]}, {'id': '32', 'infons': {'identifier': '4609', 'type': 'Gene', 'ncbi_homologene': '31092'}, 'text': 'c-Myc', 'locations': [{'offset': 950, 'length': 5}]}, {'id': '33', 'infons': {'identifier': 'MESH:D001932', 'type': 'Disease'}, 'text': 'brain tumors', 'locations': [{'offset': 959, 'length': 12}]}, {'id': '34', 'infons': {'identifier': 'MESH:D005910', 'type': 'Disease'}, 'text': 'glioma', 'locations': [{'offset': 980, 'length': 6}]}, {'id': '35', 'infons': {'identifier': 'MESH:D005909', 'type': 'Disease'}, 't ...
# {'_id': '30239861|None', 'id': '30239861', 'infons': {}, 'passages': [{'infons': {'journal': 'Neuro Oncol. 2019 Feb 14;21(2):151-166. doi: 10.1093/neuonc/noy151.', 'year': '2019', 'article-id_pmc': 'PMC6374757', 'type': 'title', 'authors': 'Ajithkumar T, Imbulgoda N, Rees E, Harris F, Horan G, Burke A, Jefferies S, Price S, Cross J, Allinson K', 'section': 'Title'}, 'offset': 0, 'text': 'Uncommon low-grade brain tumors.', 'sentences': [], 'annotations': [{'id': '1', 'infons': {'identifier': 'MESH:D001932', 'type': 'Disease'}, 'text': 'brain tumors', 'locations': [{'offset': 19, 'length': 12}]}], 'relations': []}, {'infons': {'type': 'abstract', 'section': 'Abstract'}, 'offset': 33, 'text': 'The 2016 World Health Organization (WHO) classification of primary central nervous system (CNS) tumors includes numerous uncommon (representing <=1% of tumors) low-grade (grades I-II) brain neoplasms with varying clinical behaviors and outcomes. Generally, gross tumor or maximal safe resection is the primary treatment. Adjuvant treatments, though their exact role is unknown, may be considered individually based on pathological subtypes and a proper assessment of risks and benefits. Targetable mutations such as BRAF (proto-oncogene B-Raf), TRAIL (tumor necrosis factor apoptosis inducing ligand), and PDGFR (platelet derived growth factor receptor) have promising roles in future management.', 'sentences': [], 'annotations': [{'id': '12', 'infons': {'identifier': 'MESH:D009369', 'type': 'Disease'}, 'text': 'tumors', 'locations': [{'offset': 129, 'length': 6}]}, {'id': '13', 'infons': {'identifier': 'MESH:D009369', 'type': 'Disease'}, 'text': 'tumors', 'locations': [{'offset': 185, 'length': 6}]}, {'id': '14', 'infons': {'identifier': 'MESH:D001932', 'type': 'Disease'}, 'text': 'brain neoplasms', 'locations': [{'offset': 217, 'length': 15}]}, {'id': '15', 'infons': {'identifier': 'MESH:D009369', 'type': 'Disease'}, 'text': 'tumor', 'locations': [{'offset': 296, 'length': 5}]}, {'id': '16', 'infons': {'identifier': '673', 'type': 'Gene', 'ncbi_homologene': '3197'}, 'text': 'BRAF', 'locations': [{'offset': 549, 'length': 4}]}, {'id': '17', 'infons': {'identifier': '673', 'type': 'Gene', 'ncbi_homologene': '3197'}, 'text': 'proto-oncogene B-Raf', 'locations': [{'offset': 555, 'length': 20}]}, {'id': '18', 'infons': {'identifier': '8743', 'type': 'Gene', 'ncbi_homologene': '2824'}, 'text': 'TRAIL', 'locations': [{'offset': 578, 'length': 5}]}, {'id': '19', 'infons': {'identifier': '8743', 'type': 'Gene', 'ncbi_homologene': '2824'}, 'text': 'tumor necrosis factor apoptosis inducing ligand', 'locations': [{'offset': 585, 'length': 47}]}, {'id': '20', 'infons': {'identifier': '5159', 'type': 'Gene', 'ncbi_homologene': '1960'}, 'text': 'PDGFR', 'locations': [{'offset': 639, 'length': 5}]}, {'id': '21', 'infons': {'identifier': '5159', 'type': 'Gene', 'ncbi_homologene': '1960'}, 'text': 'platelet derived growth factor receptor', 'locations': [{'offset': 646, 'length': 39}]}], 'relations': []}], 'relations': [], 'pmid': 30239861, 'pmcid': None, 'created': {'$date': 1643813405108}, 'accessions': ['gene@5159', 'gene@8743', 'disease@MESH:D009369', 'disease@MESH:D001932', 'gene@673'], 'journal': 'Neuro Oncol. 2019 Feb 14', 'year': 2019, 'authors': ['Ajithkumar T', 'Imbulgoda N', 'Rees E', 'Harris F', 'Horan G', 'Burke A', 'Jefferies S', 'Price S', 'Cross J', 'Allinson K']}
# {'_id': '28516751|None', 'id': '28516751', 'infons': {}, 'passages': [{'infons': {'journal': 'Pediatr Endocrinol Rev; 2017 Mar; 14 Suppl 1(Suppl 1) 229-234. doi:10.17458/per.vol14.2017.t.growthhormonetherapy', 'year': '2017', 'type': 'title', 'authors': 'Teramoto A', 'section': 'Title'}, 'offset': 0, 'text': 'Growth Hormone Therapy and Brain Tumors.', 'sentences': [], 'annotations': [{'id': '2', 'infons': {'identifier': '2688', 'type': 'Gene', 'ncbi_homologene': '128036'}, 'text': 'Growth Hormone', 'locations': [{'offset': 0, 'length': 14}]}, {'id': '3', 'infons': {'identifier': 'MESH:D001932', 'type': 'Disease'}, 'text': 'Brain Tumors', 'locations': [{'offset': 27, 'length': 12}]}], 'relations': []}, {'infons': {'type': 'abstract', 'section': 'Abstract'}, 'offset': 41, 'text': 'As one of the projects of the Adverse Events Study Group of the Foundation for Growth Science in Japan, the literatures on the recurrence and / or regrowth or new formation of brain tumors in patients treated with growth hormone (GH) were reviewed. Since the tumor volume of the sellar lesion can be accurately evaluated only by magnetic resonance imaging (MRI), the related literatures published after 1990 were retrieved by searching under keywords, such as GH, replacement therapy, brain tumor, recurrence, tumor formation, etc. It is undeniable that GH therapy may result in tumor enlargement only in a very small percentage of cases. However, within a scientifically reliable range of confirmation with large-scale researches and case-control studies, it can be considered that there is no relation between GH therapy and the recurrence or new formation of brain tumors.', 'sentences': [], 'annotations': [{'id': '16', 'infons': {'identifier': 'MESH:D001932', 'type': 'Disease'}, 'text': 'brain tumors', 'locations': [{'offset': 217, 'length': 12}]}, {'id': '17', 'infons': {'identifier': '9606', 'type': 'Species'}, 'text': 'patients', 'locations': [{'offset': 233, 'length': 8}]}, {'id': '18', 'infons': {'identifier': '2688', 'type': 'Gene', 'ncbi_homologene': '128036'}, 'text': 'growth hormone', 'locations': [{'offset': 255, 'length': 14}]}, {'id': '19', 'infons': {'identifier': '2688', 'type': 'Gene', 'ncbi_homologene': '128036'}, 'text': 'GH', 'locations': [{'offset': 271, 'length': 2}]}, {'id': '20', 'infons': {'identifier': 'MESH:D009369', 'type': 'Disease'}, 'text': 'tumor', 'locations': [{'offset': 300, 'length': 5}]}, {'id': '21', 'infons': {'identifier': '2688', 'type': 'Gene', 'ncbi_homologene': '128036'}, 'text': 'GH', 'locations': [{'offset': 501, 'length': 2}]}, {'id': '22', 'infons': {'identifier': 'MESH:D001932', 'type': 'Disease'}, 'text': 'brain tumor', 'locations': [{'offset': 526, 'length': 11}]}, {'id': '23', 'infons': {'identifier': 'MESH:D009369', 'type': 'Disease'}, 'text': 'tumor', 'locations': [{'offset': 551, 'length': 5}]}, {'id': '24', 'infons': {'identifier': '2688', 'type': 'Gene', 'ncbi_homologene': '128036'}, 'text': 'GH', 'locations': [{'offset': 595, 'length': 2}]}, {'id': '25', 'infons': {'identifier': 'MESH:D009369', 'type': 'Disease'}, 'text': 'tumor', 'locations': [{'offset': 620, 'length': 5}]}, {'id': '26', 'infons': {'identifier': '2688', 'type': 'Gene', 'ncbi_homologene': '128036'}, 'text': 'GH', 'locations': [{'offset': 853, 'length': 2}]}, {'id': '27', 'infons': {'identifier': 'MESH:D001932', 'type': 'Disease'}, 'text': 'brain tumors', 'locations': [{'offset': 903, 'length': 12}]}], 'relations': []}], 'relations': [], 'pmid': 28516751, 'pmcid': None, 'created': {'$date': 1643813405108}, 'accessions': ['disease@MESH:D001932', 'species@9606', 'disease@MESH:D009369', 'gene@2688'], 'journal': 'Pediatr Endocrinol Rev', 'year': 2017, 'authors': ['Teramoto A']}

# %%
import requests
import json

# Define the URL
url = "https://www.ncbi.nlm.nih.gov/research/pubtator-api/publications/export/biocjson?pmids=28516751,30239861,33069197&concepts=gene"

# Send a GET request to the URL
response = requests.get(url)

if response.status_code == 200:
    # Split the response by newline characters to handle multiple JSON objects
    json_objects = response.text.split('\n')

    # List to store extracted gene-related information
    gene_info = []

    # Iterate through each individual JSON object
    for json_obj in json_objects:
        if json_obj.strip():  # Check if the JSON object is not empty
            data = json.loads(json_obj)

            # Extract _id and gene-related information from 'passages'
            _id = data.get('_id')  # Extracting _id field
            for passage in data['passages']:
                for annotation in passage['annotations']:
                    infons = annotation.get('infons', {})
                    if infons.get('type') == 'Gene':
                        identifier = infons.get('identifier')
                        gene_type = infons.get('type')
                        gene_name = annotation.get('text')

                        gene_details = {
                            "_id": _id,
                            "identifier": identifier,
                            "type": gene_type,
                            "gene_name": gene_name
                        }

                        gene_info.append(gene_details)

    # Print or use the collected information
    print(gene_info)
else:
    print("Error:", response.status_code)
    print(response.text)
# Out:
# [{'_id': '33069197|None', 'identifier': '4609', 'type': 'Gene', 'gene_name': 'C-Myc'}, {'_id': '33069197|None', 'identifier': '4609', 'type': 'Gene', 'gene_name': 'c-Myc'}, {'_id': '33069197|None', 'identifier': '4609', 'type': 'Gene', 'gene_name': 'c-Myc'}, {'_id': '33069197|None', 'identifier': '4609', 'type': 'Gene', 'gene_name': 'c-Myc'}, {'_id': '33069197|None', 'identifier': '4609', 'type': 'Gene', 'gene_name': 'c-Myc'}, {'_id': '33069197|None', 'identifier': '4609', 'type': 'Gene', 'gene_name': 'c-Myc'}, {'_id': '30239861|None', 'identifier': '673', 'type': 'Gene', 'gene_name': 'BRAF'}, {'_id': '30239861|None', 'identifier': '673', 'type': 'Gene', 'gene_name': 'proto-oncogene B-Raf'}, {'_id': '30239861|None', 'identifier': '8743', 'type': 'Gene', 'gene_name': 'TRAIL'}, {'_id': '30239861|None', 'identifier': '8743', 'type': 'Gene', 'gene_name': 'tumor necrosis factor apoptosis inducing ligand'}, {'_id': '30239861|None', 'identifier': '5159', 'type': 'Gene', 'gene_name': 'PDGFR'}, {'_id': '30239861|None', 'identifier': '5159', 'type': 'Gene', 'gene_name': 'platelet derived growth factor receptor'}, {'_id': '28516751|None', 'identifier': '2688', 'type': 'Gene', 'gene_name': 'Growth Hormone'}, {'_id': '28516751|None', 'identifier': '2688', 'type': 'Gene', 'gene_name': 'growth hormone'}, {'_id': '28516751|None', 'identifier': '2688', 'type': 'Gene', 'gene_name': 'GH'}, {'_id': '28516751|None', 'identifier': '2688', 'type': 'Gene', 'gene_name': 'GH'}, {'_id': '28516751|None', 'identifier': '2688', 'type': 'Gene', 'gene_name': 'GH'}, {'_id': '28516751|None', 'identifier': '2688', 'type': 'Gene', 'gene_name': 'GH'}]

# %% [markdown]
# ### Using PubTator API to create JSON code

# %%
import requests
import json
from openpyxl import load_workbook

# Define the URL
url = "https://www.ncbi.nlm.nih.gov/research/pubtator-api/publications/export/biocjson?pmids=28516751,30239861,33069197&concepts=gene"

# Send a GET request to the URL
response = requests.get(url)

if response.status_code == 200:
    # Split the response by newline characters to handle multiple JSON objects
    json_objects = response.text.split('\n')

    # List to store extracted gene-related information
    gene_info = []

    # Iterate through each individual JSON object
    for json_obj in json_objects:
        if json_obj.strip():  # Check if the JSON object is not empty
            data = json.loads(json_obj)

            # Extract _id and gene-related information from 'passages'
            _id = data.get('_id')  # Extracting _id field
            for passage in data['passages']:
                for annotation in passage['annotations']:
                    infons = annotation.get('infons', {})
                    if infons.get('type') == 'Gene':
                        identifier = infons.get('identifier')
                        gene_type = infons.get('type')
                        gene_name = annotation.get('text')

                        gene_details = {
                            "_id": _id,
                            "identifier": identifier,
                            "type": gene_type,
                            "gene_name": gene_name
                        }

                        gene_info.append(gene_details)

    # Load the existing Excel file
    workbook = load_workbook('Abstracts and full text.xlsx')

    # Select the worksheet to input the data
    worksheet = workbook['AB_Gene_Names']  

    # Append data to the worksheet starting from a specific row (e.g., row 2)
    start_row = 2
    for row, gene in enumerate(gene_info, start=start_row):
        worksheet.cell(row=row, column=1).value = gene['_id']
        worksheet.cell(row=row, column=2).value = gene['identifier']
        worksheet.cell(row=row, column=3).value = gene['type']
        worksheet.cell(row=row, column=4).value = gene['gene_name']

    # Save the updated workbook
    workbook.save('Abstracts and full text.xlsx')

    print("Data has been successfully added to 'Abstracts and full text.xlsx'.")
else:
    print("Error:", response.status_code)
    print(response.text)
# Out:
# Data has been successfully added to 'Abstracts and full text.xlsx'.

# %% [markdown]
# ### Obtaining Gene Names Data
# Gathering the gene names.

# %% [markdown]
# ### <span style="color:red"> For Abstracts </span>

# %%
import requests
import json
from openpyxl import load_workbook
from openpyxl.styles import PatternFill
import pandas as pd

def modify_url():
    workbook = load_workbook('Abstracts and full text.xlsx')
    read_worksheet = workbook['abstracts']
    max_row = read_worksheet.max_row
    chunk_size = 8
    
    yellow_fill = PatternFill(start_color='FFFF00', end_color='FFFF00', fill_type='solid')
    
    gene_info_list = []  # Collect gene info into a list
    
    for start_row in range(1, max_row, chunk_size):
        end_row = min(start_row + chunk_size - 1, max_row)
        
        pmid_list = []
        for row_num in range(start_row, end_row + 1):
            cell_value = read_worksheet.cell(row=row_num, column=1).value
            pmid_list.append(cell_value)
            read_worksheet.cell(row=row_num, column=1).fill = yellow_fill
        
        gene_info = extract_geneInfo(pmid_list)
        gene_info_list.extend(gene_info)  # Append gene info to the list
    
    update_worksheet(gene_info_list, workbook)  # Write all gene info at once

def extract_geneInfo(pmid_list):
    base_url = "https://www.ncbi.nlm.nih.gov/research/pubtator-api/publications/export/biocjson"
    concepts = "gene"
    gene_info_list = []
    
    # Fetch data in batches of 100 PMIDs
    for i in range(0, len(pmid_list), 100):
        pmids = ','.join(str(p) for p in pmid_list[i:i+100])
        mod_url = f"{base_url}?pmids={pmids}&concepts={concepts}"
        response = requests.get(mod_url)
        
        if response.status_code == 200:
            json_objects = response.text.split('\n')
            for json_obj in json_objects:
                if json_obj.strip():
                    data = json.loads(json_obj)
                    _id = data.get('_id')
                    for passage in data['passages']:
                        for ann in passage['annotations']:
                            infons = ann.get('infons', {})
                            if infons.get('type') == 'Gene':
                                identifier = infons.get('identifier')
                                gene_type = infons.get('type')
                                gene_name = ann.get('text')
                                gene_details = {"_id": _id, "identifier": identifier, "type": gene_type, "gene_name": gene_name}
                                gene_info_list.append(gene_details)
        else:
            print("Error:", response.status_code)
            print(response.text) 
    
    return gene_info_list

#update the worksheet
def update_worksheet(gene_info, workbook):
    df = pd.DataFrame(gene_info, columns=['_id', 'identifier', 'type', 'gene_name'])
    with pd.ExcelWriter('Abstracts and full text.xlsx', engine='openpyxl') as writer:
        writer.book = workbook
        writer.sheets = {ws.title: ws for ws in workbook.worksheets}
        df.to_excel(writer, sheet_name='AB_Gene_Names', index=False, startrow=1, header=False)

modify_url()

# %% [markdown]
# ### <span style="color:red">For Full-text</span>

# %%
import requests
import json
from openpyxl import load_workbook
from openpyxl.styles import PatternFill
import pandas as pd

def modify_url():
    workbook = load_workbook('Abstracts and full text.xlsx')
    read_worksheet = workbook['FT']
    max_row = read_worksheet.max_row
    
    blue_fill = PatternFill(start_color='0000FF', end_color='0000FF', fill_type='solid')
    
    gene_info_list = []  # Collect gene info into a list
    
    for row_num in range(1, max_row + 1):
        cell_value = read_worksheet.cell(row=row_num, column=1).value
        read_worksheet.cell(row=row_num, column=1).fill = blue_fill
        
        if cell_value is not None:
            pmid_list = [cell_value]
            gene_info = extract_geneInfo(pmid_list)
            gene_info_list.extend(gene_info)  # Append gene info to the list
    
    update_worksheet(gene_info_list, workbook)  # Write all gene info at once

def extract_geneInfo(pmid_list):
    # Remaining code remains the same...
    base_url = "https://www.ncbi.nlm.nih.gov/research/pubtator-api/publications/export/biocjson"
    concepts = "gene"
    gene_info_list = []
    
    # Fetch data in batches of 100 PMIDs
    for i in range(0, len(pmid_list), 100):
        pmids = ','.join(str(p) for p in pmid_list[i:i+100])
        mod_url = f"{base_url}?pmids={pmids}&concepts={concepts}"
        response = requests.get(mod_url)
        
        if response.status_code == 200:
            json_objects = response.text.split('\n')
            for json_obj in json_objects:
                if json_obj.strip():
                    data = json.loads(json_obj)
                    _id = data.get('_id')
                    for passage in data['passages']:
                        for ann in passage['annotations']:
                            infons = ann.get('infons', {})
                            if infons.get('type') == 'Gene':
                                identifier = infons.get('identifier')
                                gene_type = infons.get('type')
                                gene_name = ann.get('text')
                                gene_details = {"_id": _id, "identifier": identifier, "type": gene_type, "gene_name": gene_name}
                                gene_info_list.append(gene_details)
        else:
            print("Error:", response.status_code)
            print(response.text)  
            
    return gene_info_list  # Return the collected gene information

# Update the worksheet
def update_worksheet(gene_info, workbook):
    df = pd.DataFrame(gene_info, columns=['_id', 'identifier', 'type', 'gene_name'])
    with pd.ExcelWriter('Abstracts and full text.xlsx', engine='openpyxl', mode='a') as writer:
        writer.book = workbook
        writer.sheets = {ws.title: ws for ws in workbook.worksheets}
        df.to_excel(writer, sheet_name='fullT_Gene_Names', index=False, startrow=1, header=False)

modify_url()

# %% [markdown]
# ### Obtaining the Gene names
# This is were the gene names are obtained

# %% [markdown]
# ### <span style="color:red"> Abstracts </span>

# %%
import openpyxl

# Load the Excel workbook
file_path = 'Abstracts and full text.xlsx'
worksheet_name = 'AB_Gene_Names'  
workbook = openpyxl.load_workbook(file_path)
worksheet = workbook[worksheet_name]

# Create an empty dictionary to store unique identifiers with gene names
unique_identifiers = {}

# Iterate through the rows, limit to 10 rows for testing purposes
for index, row in enumerate(worksheet.iter_rows(min_row=2, max_row=worksheet.max_row, values_only=True), start=2):
    pmid = row[0]  # PMID is in the first column (column A)
    identifier = row[1]  # Identifier is in the second column (column B)
    gene_name = row[3]  # Gene Name is in the fourth column (column D)

    # Combine PMID and Identifier to create a unique identifier key
    unique_identifier = f"{pmid}_{identifier}"

    # Check if the unique identifier is already in the dictionary
    if unique_identifier not in unique_identifiers:
        unique_identifiers[unique_identifier] = [gene_name]  # Initialize a list with the gene name
    else:
        # If the key exists, append the gene name to the existing list
        unique_identifiers[unique_identifier].append(gene_name)

    # Highlight the current row with yellow fill color
    for cell in worksheet[index]:
        cell.fill = openpyxl.styles.PatternFill(start_color='FFFF00', end_color='FFFF00', fill_type='solid')

# Display the unique identifiers with their corresponding gene names
for identifier, gene_names in unique_identifiers.items():
    print(f"Unique Identifier: {identifier}, Gene Names: {', '.join(gene_names)}")

# Save the modified workbook to a new file
workbook.save(file_path)

# Close the workbook
workbook.close()
# Out:
# Unique Identifier: 33273172|None_57379, Gene Names: aid
# Unique Identifier: 33069197|None_4609, Gene Names: C-Myc, c-Myc, c-Myc, c-Myc, c-Myc, c-Myc
# Unique Identifier: 30239861|None_673, Gene Names: BRAF, proto-oncogene B-Raf
# Unique Identifier: 30239861|None_8743, Gene Names: TRAIL, tumor necrosis factor apoptosis inducing ligand
# Unique Identifier: 30239861|None_5159, Gene Names: PDGFR, platelet derived growth factor receptor
# Unique Identifier: 28516751|None_2688, Gene Names: Growth Hormone, growth hormone, GH, GH, GH, GH
# Unique Identifier: 17032559|None_4255, Gene Names: MGMT, MGMT
# Unique Identifier: 16778750|None_148398, Gene Names: MRS, MRS, MRS, MRS
# Unique Identifier: 15612600|None_84366, Gene Names: PRACTICE
# Unique Identifier: 1361524|None_5243, Gene Names: P-glycoprotein, P-glycoprotein, P-gp, P-gp, P-gp, P-gp, P-gp, P-gp, P-gp, P-gp, P-gp
# Unique Identifier: 19238661|None_1437, Gene Names: CSF, CSF, CSF
# Unique Identifier: 16245217|None_23405, Gene Names: DICER
# Unique Identifier: 16245217|None_59342, Gene Names: RISC
# Unique Identifier: 15993075|None_5881, Gene Names: Rac3, Rac3, Rac3, Rac3, Rac3, Rac3, Rac3, Rac3, Rac3, Rac3, Rac3, Rac3
# Unique Identifier: 12216107|None_79811, Gene Names: MET, MET, MET, MET, MET, MET
# Unique Identifier: 12216107|None_57534, Gene Names: MIB-1
# Unique Identifier: 11900859|None_7157, Gene Names: p53, p53, p53, p53, p53, p53, p53, p53, p53, p53
# Unique Identifier: 11051794|None_5364, Gene Names: SEP
# Unique Identifier: 11051794|None_29, Gene Names: ABR
# Unique Identifier: 10652582|None_808, Gene Names: CAM
# Unique Identifier: 9879457|None_338412, Gene Names: PS 2
# Unique Identifier: 34061562|None_43, Gene Names: acetylcholinesterase
# Unique Identifier: 30935361|None_3417, Gene Names: isocitrate dehydrogenase, IDH, IDH
# Unique Identifier: 27463526|None_2149, Gene Names: TR
# Unique Identifier: 25054358|None_7422, Gene Names: VEGF
# Unique Identifier: 20521177|None_3565, Gene Names: IL-4
# Unique Identifier: 20521177|None_8743, Gene Names: TRAIL
# Unique Identifier: 3729310|None_57379, Gene Names: aid
# Unique Identifier: 2643496|None_22915, Gene Names: ECM, ECM
# Unique Identifier: 2558501|None_24387, Gene Names: glial fibrillary acidic protein, S-100
# Unique Identifier: 2558501|None_81818, Gene Names: vimentin
# Unique Identifier: 17725214|None_23218, Gene Names: GPS
# Unique Identifier: 11816741|None_2936, Gene Names: glutathione reductase, glutathione reductase
# Unique Identifier: 11816741|None_6647, Gene Names: SOD-1
# Unique Identifier: 11408092|None_24609, Gene Names: ornithine decarboxylase, ornithine decarboxylase, ODC, ODC, ODC, ODC, ODC, ODC, ODC
# Unique Identifier: 11151727|None_799, Gene Names: CRT, CRT, CRT
# Unique Identifier: 10100707|None_1508, Gene Names: Cathepsin B, cathepsin (Cat) B, Cat B, Cat B, Cat B, Cat B, Cat B, Cat B, Cat B
# Unique Identifier: 6098128|None_24387, Gene Names: glial fibrillary acidic protein
# Unique Identifier: 4027919|None_174, Gene Names: alpha-fetoprotein
# Unique Identifier: 1016286|None_10309, Gene Names: CCNU, CCNU
# Unique Identifier: 25241806|None_57379, Gene Names: aid
# Unique Identifier: 23944103|None_3938, Gene Names: Lac, Lac
# Unique Identifier: 23944103|None_23049, Gene Names: Lip, Lip
# Unique Identifier: 16900783|None_5743, Gene Names: Cyclooxygenase-2, COX-2, COX-2, COX-2
# Unique Identifier: 9949905|None_5734, Gene Names: EP4, EP4
# Unique Identifier: 9949905|None_6855, Gene Names: synaptophysin
# Unique Identifier: 7793096|None_2495, Gene Names: ferritin heavy chain
# Unique Identifier: 7651591|None_1445, Gene Names: CSK
# Unique Identifier: 7582248|None_57534, Gene Names: MIB-1, MIB-1, MIB-1
# Unique Identifier: 3801549|None_2670, Gene Names: glial fibrillary acidic protein, GFAP, GFAP, GFAP
# Unique Identifier: 33711670|None_4842, Gene Names: nitric oxide synthase, nNOS
# Unique Identifier: 33711670|None_4843, Gene Names: iNOS
# Unique Identifier: 33711670|None_4846, Gene Names: eNOS
# Unique Identifier: 33711670|None_4953, Gene Names: ornithine decarboxylase
# Unique Identifier: 28844173|None_57120, Gene Names: GOPC
# Unique Identifier: 28844173|None_6098, Gene Names: ROS1
# Unique Identifier: 28844173|None_1019, Gene Names: CDK4
# Unique Identifier: 28844173|None_4763, Gene Names: NF1
# Unique Identifier: 28844173|None_57670, Gene Names: KIAA1549
# Unique Identifier: 28844173|None_673, Gene Names: BRAF
# Unique Identifier: 22497851|None_6598, Gene Names: INI-1, INI-1
# Unique Identifier: 19618856|None_2146, Gene Names: EZH2
# Unique Identifier: 8597115|None_7157, Gene Names: p53, p53
# Unique Identifier: 7546012|None_5443, Gene Names: Adrenocorticotropic hormone
# Unique Identifier: 2192793|None_1956, Gene Names: epidermal growth factor receptor
# Unique Identifier: 2192793|None_4609, Gene Names: c-myc
# Unique Identifier: 1798908|None_253260, Gene Names: pia
# Unique Identifier: 25783972|None_4255, Gene Names: O-6-methylguanine-DNA methyltransferase, MGMT
# Unique Identifier: 19587462|None_10178, Gene Names: TNM
# Unique Identifier: 15756927|None_4836, Gene Names: N-myristoyltransferase, N-myristoyltransferase, NMT, NMT, NMT, NMT1, NMT, NMT
# Unique Identifier: 15756927|None_9397, Gene Names: NMT2
# Unique Identifier: 7882284|None_7157, Gene Names: p53, p53, p53, p53, p53
# Unique Identifier: 7745467|None_5328, Gene Names: urokinase-type plasminogen activator, uPAR, uPAR, uPAR, uPA, uPA, uPAR, uPAR, uPA, uPAR
# Unique Identifier: 7745467|None_5340, Gene Names: plasmin, plasmin
# Unique Identifier: 3900810|None_1084, Gene Names: CEA, CEA, carcinoembryonic antigen, CEA, CEA
# Unique Identifier: 3808569|None_2670, Gene Names: Glial fibrillary acidic protein, Glial fibrillary acidic protein, glial fibrillary acidic protein
# Unique Identifier: 1608541|None_348, Gene Names: apolipoprotein E, apolipoprotein E, apolipoprotein E, apolipoprotein-E
# Unique Identifier: 31917601|None_139628, Gene Names: FOXR2
# Unique Identifier: 31917601|None_54880, Gene Names: BCOR
# Unique Identifier: 28493234|None_7157, Gene Names: p53
# Unique Identifier: 28493234|None_472, Gene Names: ATM
# Unique Identifier: 28493234|None_894, Gene Names: cyclin D2
# Unique Identifier: 28493234|None_1956, Gene Names: EGFR
# Unique Identifier: 28493234|None_207, Gene Names: Akt
# Unique Identifier: 28395087|None_7157, Gene Names: TP53
# Unique Identifier: 28395087|None_3417, Gene Names: IDH1
# Unique Identifier: 28395087|None_5290, Gene Names: PIK3CA, PIK3CA
# Unique Identifier: 28395087|None_5728, Gene Names: PTEN
# Unique Identifier: 28395087|None_1956, Gene Names: EGFR
# Unique Identifier: 28395087|None_673, Gene Names: BRAF
# Unique Identifier: 28395087|None_1499, Gene Names: CTNNB1
# Unique Identifier: 18046441|None_207, Gene Names: Akt, Akt, Akt
# Unique Identifier: 18046441|None_5728, Gene Names: PTEN, PTEN, PTEN
# Unique Identifier: 18046441|None_57126, Gene Names: cell surface receptor, cell surface receptor
# Unique Identifier: 15877531|None_8658, Gene Names: Part 5
# Unique Identifier: 15877531|None_581, Gene Names: Bax
# Unique Identifier: 15877531|None_596, Gene Names: Bcl-2
# Unique Identifier: 15877531|None_8837, Gene Names: cFLIP, effector caspases
# Unique Identifier: 15877531|None_207, Gene Names: Akt
# Unique Identifier: 12456378|None_7124, Gene Names: transforming growth factor-beta, Transforming growth factor beta
# Unique Identifier: 12456378|None_7039, Gene Names: TGF-beta, TGF-beta, TGF-beta, TGF-beta
# Unique Identifier: 7843802|None_259, Gene Names: bikunin, bikunin, Bikunin, bikunin, bikunin, bikunin
# Unique Identifier: 2464270|None_2335, Gene Names: fibronectin
# Unique Identifier: 35715607|None_361, Gene Names: aquaporin 4, Aquaporin-4, AQP4, AQP4, AQP4, AQP4, AQP4
# Unique Identifier: 35715607|None_54205, Gene Names: cytochrome C
# Unique Identifier: 35715607|None_596, Gene Names: Bcl-2
# Unique Identifier: 35715607|None_3620, Gene Names: IDO1
# Unique Identifier: 35715607|None_6999, Gene Names: TDO
# Unique Identifier: 35715607|None_196, Gene Names: AhR
# Unique Identifier: 35715607|None_645323, Gene Names: LINC00461
# Unique Identifier: 35715607|None_406998, Gene Names: miR-216a
# Unique Identifier: 25792036|None_129807, Gene Names: NEU4
# Unique Identifier: 25792036|None_1486, Gene Names: CTBS
# Unique Identifier: 25792036|None_57704, Gene Names: GBA2
# Unique Identifier: 25792036|None_1075, Gene Names: CTSC
# Unique Identifier: 25792036|None_1513, Gene Names: CTSK
# Unique Identifier: 25792036|None_8722, Gene Names: CTSF
# Unique Identifier: 25139406|None_3075, Gene Names: arms 1p
# Unique Identifier: 25139406|None_3417, Gene Names: IDH1
# Unique Identifier: 25139406|None_3418, Gene Names: IDH2
# Unique Identifier: 25037494|None_4255, Gene Names: O6-methylguanine-DNA methyltransferase, MGMT
# Unique Identifier: 24169416|None_7422, Gene Names: vascular endothelial growth factor, VEGF
# Unique Identifier: 24169416|None_1956, Gene Names: epidermal growth factor receptor, EGFR
# Unique Identifier: 16988585|None_1499, Gene Names: beta-catenin
# Unique Identifier: 8367211|None_5788, Gene Names: CD45RO, CD45RO
# Unique Identifier: 3973708|None_2670, Gene Names: GFAP, glial fibrillary acidic protein, GFAP, GFAP
# Unique Identifier: 35704146|None_5467, Gene Names: PPARdelta
# Unique Identifier: 35704146|None_5468, Gene Names: PPARgamma
# Unique Identifier: 34739635|None_1029, Gene Names: CDKN2A
# Unique Identifier: 34739635|None_1956, Gene Names: EGFR
# Unique Identifier: 34739635|None_5156, Gene Names: PDGFRa
# Unique Identifier: 34739635|None_5728, Gene Names: PTEN
# Unique Identifier: 34739635|None_1019, Gene Names: CDK4
# Unique Identifier: 34739635|None_3815, Gene Names: KIT
# Unique Identifier: 34739635|None_5290, Gene Names: PIK3CA
# Unique Identifier: 34739635|None_4193, Gene Names: MDM2
# Unique Identifier: 27281939|None_3417, Gene Names: Isocytrate dehydrogenase, IDH
# Unique Identifier: 27281939|None_4255, Gene Names: MGMT
# Unique Identifier: 24896362|None_5243, Gene Names: ABCB1
# Unique Identifier: 20860895|None_3934, Gene Names: NGAL, neutrophil gelatinase-associated lipocalin, NGAL, NGAL, NGAL, NGAL, NGAL, NGAL, NGAL, NGAL, NGAL, NGAL
# Unique Identifier: 19107440|None_7157, Gene Names: TP53
# Unique Identifier: 19107440|None_4255, Gene Names: O6 -methylguanine-DNA methyltransferase, MGMT
# Unique Identifier: 11496317|None_990, Gene Names: Cdc6, Cdc6, Cdc6, Cdc6, Cdc6, Cdc6, Cdc6
# Unique Identifier: 11496317|None_4174, Gene Names: Mcm5
# Unique Identifier: 11496317|None_57534, Gene Names: MIB-1, MIB-1, MIB-1
# Unique Identifier: 11134091|None_2688, Gene Names: Growth hormone
# Unique Identifier: 11134091|None_8836, Gene Names: GH, GH, GH, GH, GH, GH, GH, GH
# Unique Identifier: 36191126|None_9970, Gene Names: CAR, Chimeric Antigen Receptor, CAR, CAR, CAR, CAR, CAR, CAR
# Unique Identifier: 29429648|None_3702, Gene Names: ITK
# Unique Identifier: 25037493|None_4255, Gene Names: O6-methylguanine-DNA methyltransferase, MGMT
# Unique Identifier: 24881141|None_3417, Gene Names: IDH
# Unique Identifier: 20075834|None_7422, Gene Names: VEGF, vascular endothelial growth factor, VEGF
# Unique Identifier: 15816119|None_3371, Gene Names: tenascin, tenascin, tenascin
# Unique Identifier: 10895165|None_2670, Gene Names: GFAP
# Unique Identifier: 10895165|None_2026, Gene Names: NSE
# Unique Identifier: 10895165|None_4155, Gene Names: MBP
# Unique Identifier: 6964044|None_9344, Gene Names: PSK, PSK, PSK
# Unique Identifier: 6964044|None_4067, Gene Names: Lyn
# Unique Identifier: 36841424|None_653108, Gene Names: CAR, CAR, CAR, CAR, CAR, CAR
# Unique Identifier: 31918786|None_546, Gene Names: ATRX
# Unique Identifier: 31918786|None_7157, Gene Names: TP53
# Unique Identifier: 15757449|None_7157, Gene Names: p53, p53, p53, p53, p53, p53, p53, p53, p53, p53
# Unique Identifier: 15757449|None_4193, Gene Names: mdm2
# Unique Identifier: 15612598|None_84366, Gene Names: PRACTICE
# Unique Identifier: 13680293|None_4843, Gene Names: NO synthase, inducible-form NOS, iNOS, iNOS, iNOS
# Unique Identifier: 8402649|None_5443, Gene Names: met-enkephalin, Met-enkephalin, met-enkephalin, met-enkephalin, met-enkephalin, met-enkephalin
# Unique Identifier: 8402649|None_5179, Gene Names: preproenkephalin
# Unique Identifier: 7931595|None_1511, Gene Names: hCG, hCG, hCG, hCG, hCG, hCG, hCG, hCG, hCG, hCG, hCG
# Unique Identifier: 7931595|None_2796, Gene Names: gonadotropin-releasing hormone
# Unique Identifier: 2812355|None_10178, Gene Names: TNM, TNM
# Unique Identifier: 25175689|None_6892, Gene Names: tapasin, tapasin, tapasin
# Unique Identifier: 25175689|None_3458, Gene Names: IFNgamma
# Unique Identifier: 24061639|None_7517, Gene Names: XRCC3, X-ray repair cross-complementing group 3, XRCC3, XRCC3, XRCC3, XRCC3, XRCC3, XRCC3, XRCC3, XRCC3
# Unique Identifier: 22528799|None_79811, Gene Names: MET, MET, MET, MET, MET, MET, MET, MET
# Unique Identifier: 22238331|None_3417, Gene Names: isocitrate dehydrogenase, IDH
# Unique Identifier: 18384511|None_3958, Gene Names: Galectin-3, Galectin-3, gal-3, Gal-3, gal-3, gal-3, gal-3, gal-3
# Unique Identifier: 18384511|None_148003, Gene Names: beta-galactoside-binding lectin
# Unique Identifier: 7807193|None_5243, Gene Names: p-glycoprotein
# Unique Identifier: 6384434|None_6236, Gene Names: rad
# Unique Identifier: 3560451|None_1084, Gene Names: CEA
# Unique Identifier: 29791066|None_4591, Gene Names: muL, muL
# Unique Identifier: 17593388|None_5243, Gene Names: MDR1, P-glycoprotein, MDR1, MDR1, MDR1, MDR1, MDR1
# Unique Identifier: 17593388|None_283871, Gene Names: Pgp, Pgp, Pgp, Pgp
# Unique Identifier: 17157785|None_8842, Gene Names: CD133
# Unique Identifier: 17157785|None_1111, Gene Names: CHK1
# Unique Identifier: 17157785|None_11200, Gene Names: CHK2
# Unique Identifier: 15645005|None_80781, Gene Names: endostatin, endostatin, endostatin
# Unique Identifier: 12722932|None_4193, Gene Names: MDM2
# Unique Identifier: 12722932|None_1029, Gene Names: INK4a
# Unique Identifier: 12271818|None_3479, Gene Names: IGF-I
# Unique Identifier: 11342692|None_3009, Gene Names: H15, H15
# Unique Identifier: 11120864|None_12504, Gene Names: CD4
# Unique Identifier: 31749132|None_4914, Gene Names: TRK
# Unique Identifier: 19770657|None_1956, Gene Names: epidermal growth factor receptor
# Unique Identifier: 15612602|None_84366, Gene Names: PRACTICE
# Unique Identifier: 10597192|None_113829, Gene Names: tumor-rejection antigen, tumor-rejection antigen
# Unique Identifier: 10597192|None_9092, Gene Names: SART1, SART1, SART1, SART1, SART1, SART1, SART1, SART1
# Unique Identifier: 7965140|None_3456, Gene Names: Interferon-beta, IFN-B, IFN-B
# Unique Identifier: 3099535|None_2670, Gene Names: glial fibrillary acidic protein, GFAP, GFAP, GFAP, GFAP
# Unique Identifier: 2990597|None_2673, Gene Names: GFA, GFA
# Unique Identifier: 2288775|None_373156, Gene Names: glutathione S-transferase
# Unique Identifier: 36314394|None_57741, Gene Names: NIR, NIR, NIR, NIR, NIR, NIR
# Unique Identifier: 36314394|None_12484, Gene Names: HSA, HSA, HSA, HSA
# Unique Identifier: 36314394|None_15953, Gene Names: iRGD, iRGD, iRGD, iRGD, iRGD, iRGD
# Unique Identifier: 36314394|None_11657, Gene Names: albumin
# Unique Identifier: 36154607|None_92737, Gene Names: Bromodomain and Extraterminal, BET
# Unique Identifier: 36154607|None_1025, Gene Names: Cyclin-Dependent Kinase 9, CDK9
# Unique Identifier: 36154607|None_558, Gene Names: AXL
# Unique Identifier: 36154607|None_648, Gene Names: BMI1
# Unique Identifier: 36154607|None_1387, Gene Names: CREB Binding Protein, CBP
# Unique Identifier: 10850867|None_1956, Gene Names: EGFR
# Unique Identifier: 10850867|None_1019, Gene Names: CDK4
# Unique Identifier: 10850867|None_1029, Gene Names: CDKN2A
# Unique Identifier: 10850867|None_7157, Gene Names: TP53
# Unique Identifier: 10850867|None_1755, Gene Names: DMBT1
# Unique Identifier: 10850867|None_4771, Gene Names: NF2
# Unique Identifier: 10850867|None_5728, Gene Names: PTEN
# Unique Identifier: 9241081|None_57534, Gene Names: MIB-1, MIB-1
# Unique Identifier: 8741689|None_596, Gene Names: Bcl-2, Bcl-2
# Unique Identifier: 8741689|None_598, Gene Names: Bcl-x
# Unique Identifier: 8741689|None_581, Gene Names: Bax
# Unique Identifier: 8741689|None_8824, Gene Names: ICE, ICE
# Unique Identifier: 8741689|None_835, Gene Names: Ich-1
# Unique Identifier: 8741689|None_356, Gene Names: Fas ligand
# Unique Identifier: 8494908|None_7157, Gene Names: p53, p53, p53
# Unique Identifier: 8494908|None_4763, Gene Names: neurofibromatosis 1, NF1
# Unique Identifier: 8494908|None_1956, Gene Names: epidermal growth factor receptor
# Unique Identifier: 8494908|None_7124, Gene Names: transforming growth factor-alpha and -beta
# Unique Identifier: 8494908|None_4609, Gene Names: c-myc
# Unique Identifier: 8494908|None_2353, Gene Names: c-fos
# Unique Identifier: 8494908|None_3479;3481, Gene Names: insulin-like growth factor I and II
# Unique Identifier: 8494908|None_2064, Gene Names: c-erb B-2
# Unique Identifier: 8329302|None_6521, Gene Names: Sao
# Unique Identifier: 1648677|None_57379, Gene Names: aid
# Unique Identifier: 35419084|None_49860, Gene Names: CRNN
# Unique Identifier: 34806136|None_4763, Gene Names: neurofibromatosis 1
# Unique Identifier: 29890272|None_2521, Gene Names: FUS
# Unique Identifier: 29802595|None_2688, Gene Names: growth hormone
# Unique Identifier: 28303493|None_4255, Gene Names: MGMT
# Unique Identifier: 28303493|None_1956, Gene Names: EGFR
# Unique Identifier: 28303493|None_546, Gene Names: ATRX
# Unique Identifier: 28303493|None_7015, Gene Names: TERT
# Unique Identifier: 28303493|None_673, Gene Names: BRAF
# Unique Identifier: 25142793|None_1786, Gene Names: DNA methyltransferases, DNMT
# Unique Identifier: 25142793|None_57348, Gene Names: TTYH1
# Unique Identifier: 25142793|None_1789, Gene Names: DNMT3B
# Unique Identifier: 19322535|None_4255, Gene Names: MGMT
# Unique Identifier: 15593389|None_361, Gene Names: aquaporin-4, aquaporin-4, AQP4, AQP4, AQP4, AQP4, AQP4, AQP4
# Unique Identifier: 36400017|None_3417, Gene Names: IDH
# Unique Identifier: 35067500|None_2475, Gene Names: mammalian target of Rapamycin
# Unique Identifier: 21533813|None_1401, Gene Names: C-reactive protein
# Unique Identifier: 21533813|None_213, Gene Names: albumin
# Unique Identifier: 17538177|None_5243, Gene Names: P-glycoprotein, P-gp, P-gp, P-gp, P-gp, P-gp, P-gp, P-gp
# Unique Identifier: 9503517|None_84366, Gene Names: PRACTICE
# Unique Identifier: 7794250|None_6298, Gene Names: MTS1, MTS1, MTS1, MTS1, MTS1, MTS1, MTS1
# Unique Identifier: 3213427|None_2670, Gene Names: glial fibrillary acidic protein, GFAP, GFAP, GFAP
# Unique Identifier: 3213427|None_7431, Gene Names: vimentin
# Unique Identifier: 3213427|None_5265, Gene Names: alpha-1-antitrypsin
# Unique Identifier: 3213427|None_12, Gene Names: alpha-1-antichymotrypsin
# Unique Identifier: 2262373|None_8836, Gene Names: GH
# Unique Identifier: 37743328|None_9644, Gene Names: SH3PXD2A
# Unique Identifier: 37743328|None_5654, Gene Names: HTRA1
# Unique Identifier: 37743328|None_4771, Gene Names: NF2
# Unique Identifier: 37743328|None_84231, Gene Names: TRAF7
# Unique Identifier: 37743328|None_9314, Gene Names: KLF4
# Unique Identifier: 37743328|None_207, Gene Names: AKT1
# Unique Identifier: 37743328|None_6608, Gene Names: SMO
# Unique Identifier: 37743328|None_7015, Gene Names: TERT
# Unique Identifier: 37743328|None_1029;1030, Gene Names: CDKN2A/B
# Unique Identifier: 29391205|None_1493, Gene Names: cytotoxic T-lymphocyte protein 4, CTLA4, CTLA4
# Unique Identifier: 29391205|None_5133, Gene Names: programmed cell death 1
# Unique Identifier: 29391205|None_29126, Gene Names: PDL1
# Unique Identifier: 20402394|None_100855519, Gene Names: Kel, Kel
# Unique Identifier: 6761344|None_847, Gene Names: CAT
# Unique Identifier: 3496430|None_5265, Gene Names: Alpha-1-antitrypsin, alpha-1-antitrypsin, alpha 1-AT, alpha 1-AT, alpha 1-AT, alpha 1-AT, alpha 1-AT, alpha 1-AT
# Unique Identifier: 3496430|None_2, Gene Names: alpha 2-macroglobulin, alpha 2-macroglobulin
# Unique Identifier: 3496430|None_2244, Gene Names: fibrinogen
# Unique Identifier: 2395512|None_1476, Gene Names: PME, PME
# Unique Identifier: 1695101|None_2670, Gene Names: Glial fibrillary acidic protein, GFAP, GFAP
# Unique Identifier: 1695101|None_7431, Gene Names: Vimentin
# Unique Identifier: 1695101|None_2335, Gene Names: fibronectin
# Unique Identifier: 28967635|None_8842, Gene Names: CD133, CD133, CD133, CD133, CD133, CD133, CD133, CD133, CD133, CD133, CD133
# Unique Identifier: 28339700|None_3417, Gene Names: IDH, IDH, IDH, IDH
# Unique Identifier: 28339700|None_7015, Gene Names: TERT
# Unique Identifier: 28339700|None_673, Gene Names: BRAF
# Unique Identifier: 28339700|None_3020, Gene Names: H3F3A
# Unique Identifier: 24328865|None_673, Gene Names: BRAF
# Unique Identifier: 24328865|None_3417, Gene Names: IDH1
# Unique Identifier: 12724228|None_3596, Gene Names: interleukin 13, IL-13
# Unique Identifier: 12724228|None_3598, Gene Names: IL-13Ralpha2, IL-13Ralpha2
# Unique Identifier: 12724228|None_2277, Gene Names: vascular endothelial growth factor-D, VEGF-D, VEGF-D
# Unique Identifier: 12724228|None_3727, Gene Names: activating protein-1, AP-1, AP-1, AP-1, AP-1, AP-1
# Unique Identifier: 8393842|None_4255, Gene Names: O6-methylguanine-DNA methyltransferase, O6-methylguanine-DNA methyltransferase, MGMT, MGMT, MGMT, MGMT, MGMT
# Unique Identifier: 3729448|None_13982, Gene Names: estrogen receptor
# Unique Identifier: 2080375|None_84539, Gene Names: SLT
# Unique Identifier: 1583854|None_4580, Gene Names: MTX
# Unique Identifier: 26948345|None_3417, Gene Names: IDH
# Unique Identifier: 26948345|None_7157, Gene Names: TP53
# Unique Identifier: 25382612|None_57670, Gene Names: KIAA1549, KIAA1549, KIAA1549
# Unique Identifier: 25382612|None_673, Gene Names: BRAF, BRAF, BRAF
# Unique Identifier: 23037605|None_1956, Gene Names: EGFR
# Unique Identifier: 23037605|None_7157, Gene Names: TP53
# Unique Identifier: 19357959|None_768, Gene Names: carbonic anhydrase IX
# Unique Identifier: 19357959|None_7422, Gene Names: vascular endothelial growth factor
# Unique Identifier: 15612603|None_84366, Gene Names: PRACTICE
# Unique Identifier: 10667228|None_4313;4318;4321, Gene Names: MMPs, MMPs, MMP, MMP
# Unique Identifier: 10667228|None_4313, Gene Names: MMP-2, MMP-2, MMP-2
# Unique Identifier: 10667228|None_4318, Gene Names: MMP-9
# Unique Identifier: 10667228|None_4321, Gene Names: MMP-12
# Unique Identifier: 10667228|None_7076, Gene Names: TIMP-1, TIMP
# Unique Identifier: 10667228|None_7077, Gene Names: TIMP-2, TIMP-2
# Unique Identifier: 9482679|None_7422, Gene Names: VEGF
# Unique Identifier: 6303729|None_2006, Gene Names: elastin
# Unique Identifier: 29687323|None_9306, Gene Names: cis-4, Cis-4
# Unique Identifier: 22520479|None_79811, Gene Names: MET, MET, MET, MET, MET, MET
# Unique Identifier: 20536289|None_361, Gene Names: Aquaporin-4, AQP-4, aquaporin-4, AQP-4, AQP-4, AQP-4, AQP-4, AQP-4
# Unique Identifier: 16551993|None_4137, Gene Names: Taurine, Tau, Tau
# Unique Identifier: 9407934|None_7157, Gene Names: TP53, TP53
# Unique Identifier: 9407934|None_1956, Gene Names: EGFR
# Unique Identifier: 1743696|None_2670, Gene Names: glial fibrillary acidic protein
# Unique Identifier: 1456739|None_5973, Gene Names: Age
# Unique Identifier: 189021|None_5443, Gene Names: ACTH
# Unique Identifier: 31162240|None_10927, Gene Names: Spin, spin, spin, spin
# Unique Identifier: 28748347|None_2475, Gene Names: mammalian target of rapamycin
# Unique Identifier: 28453743|None_54880, Gene Names: BCOR
# Unique Identifier: 28453743|None_5894, Gene Names: RAF1
# Unique Identifier: 28453743|None_673, Gene Names: BRAF
# Unique Identifier: 28453743|None_171023, Gene Names: ASXL1
# Unique Identifier: 28453743|None_5604, Gene Names: MAP2K1
# Unique Identifier: 22294272|None_1956, Gene Names: Epidermal Growth factor Receptor, EGFR
# Unique Identifier: 22294272|None_5159, Gene Names: Platelet Derived Growth Factor Receptor, PDGFR
# Unique Identifier: 22294272|None_7422, Gene Names: Vascular Endothelial Growth factor, VEGF
# Unique Identifier: 22294272|None_207, Gene Names: Akt
# Unique Identifier: 22294272|None_2475, Gene Names: mTOR
# Unique Identifier: 21129060|None_1956, Gene Names: epidermal growth factor receptor, EGFR
# Unique Identifier: 21129060|None_673, Gene Names: BRAF
# Unique Identifier: 18521796|None_18591, Gene Names: PDGF-B
# Unique Identifier: 2667588|None_7276, Gene Names: transthyretin, transthyretin, TTR, TTR, TTR, TTR, TTR, TTR
# Unique Identifier: 2274129|None_5973, Gene Names: Age
# Unique Identifier: 17244552|None_8842, Gene Names: CD133
# Unique Identifier: 10928105|None_920, Gene Names: CD4
# Unique Identifier: 10928105|None_5788, Gene Names: Leukocyte common antigen, LCA
# Unique Identifier: 10896208|None_4313, Gene Names: Matrix metalloproteinase 2, MMP-2, 72 kDa type IV collagenase, matrix metalloproteinase 2, MMP-2, MMP-2, MMP-2, MMP-2, MMP-2, MMP-2, MMP-2, MMP-2, MMP-2, MMP-2, MMP-2
# Unique Identifier: 10049993|None_2688, Gene Names: growth hormone
# Unique Identifier: 9804370|None_7157, Gene Names: TP53, TP53
# Unique Identifier: 8657489|None_5973, Gene Names: Age
# Unique Identifier: 7538161|None_5328, Gene Names: urokinase type plasminogen activator, uPA, uPA, uPA, uPA, uPA, uPA, uPA
# Unique Identifier: 7538161|None_5054, Gene Names: plasminogen activator inhibitor-1, PAI-1
# Unique Identifier: 7538161|None_5327, Gene Names: Tissue-type plasminogen activator, tPA, tPA, tPA, tPA, tPA, tPA
# Unique Identifier: 2750486|None_112476, Gene Names: protein kinase C, Protein kinase C, PKC, PKC, PKC
# Unique Identifier: 34092558|None_3417, Gene Names: IDH1
# Unique Identifier: 34092558|None_673, Gene Names: BRAF
# Unique Identifier: 34092558|None_7015, Gene Names: TERT
# Unique Identifier: 31123752|None_348, Gene Names: APOE
# Unique Identifier: 31123752|None_1312, Gene Names: COMT, COMT
# Unique Identifier: 31123752|None_627, Gene Names: BDNF
# Unique Identifier: 31123752|None_5150, Gene Names: PDE7A
# Unique Identifier: 31123752|None_3569, Gene Names: IL-6
# Unique Identifier: 31123752|None_1812, Gene Names: DRD1
# Unique Identifier: 31123752|None_6925, Gene Names: TCF4
# Unique Identifier: 31123752|None_5888, Gene Names: RAD51
# Unique Identifier: 31123752|None_27244, Gene Names: SESN1
# Unique Identifier: 31123752|None_2950, Gene Names: GSTP1
# Unique Identifier: 25976260|None_2670, Gene Names: glial fibrillary acidic protein, GFAP, GFAP
# Unique Identifier: 25976260|None_9118, Gene Names: alpha-internexin, alpha-internexin
# Unique Identifier: 25976260|None_5630, Gene Names: peripherin
# Unique Identifier: 25976260|None_7431, Gene Names: vimentin, vimentin
# Unique Identifier: 25976260|None_10763, Gene Names: nestin, nestin, nestin, Nestin, nestin
# Unique Identifier: 25976260|None_23336, Gene Names: synemin, synemin, Synemin
# Unique Identifier: 7692323|None_3558, Gene Names: interleukin-2, interleukin-2, IL-2, IL-2, IL-2
# Unique Identifier: 6086852|None_22978, Gene Names: GMP, GMP
# Unique Identifier: 2997416|None_2670, Gene Names: glial fibrillary acidic protein, GFAP
# Unique Identifier: 2997416|None_6271, Gene Names: S-100
# Unique Identifier: 1020546|None_213, Gene Names: HSA
# Unique Identifier: 522954|None_23584, Gene Names: CT-H
# Unique Identifier: 34509751|None_6598, Gene Names: SMARCB1
# Unique Identifier: 26459515|None_4763, Gene Names: neurofibromatosis type 1
# Unique Identifier: 18374501|None_351, Gene Names: alpha/beta, a, A, alpha/beta, a, a
# Unique Identifier: 17447046|None_10178, Gene Names: TNM
# Unique Identifier: 15485315|None_100616101, Gene Names: Proteinase
# Unique Identifier: 12357552|None_57534, Gene Names: MIB.1
# Unique Identifier: 12168843|None_2064, Gene Names: HER-2/neu, HER-2/neu, HER-2/neu, HER-2/neu, HER-2/neu, HER-2/neu, HER-2/neu, HER-2/neu, HER-2/neu, Her-2/neu, HER-2, neu, HER-2/neu
# Unique Identifier: 7523634|None_7422, Gene Names: Vascular permeability factor, VPF, VPF, VPF, VPF, VPF, VPF, VPF, VPF, VPF
# Unique Identifier: 31853548|None_2521, Gene Names: FUS, FUS, FUS, FUS, FUS
# Unique Identifier: 30993541|None_857, Gene Names: caveolin-1, Caveolin-1, cav-1, cav-1, cav-1, cav-1, cav-1, cav-1, Cav-1, cav-1, cav-1
# Unique Identifier: 26376741|None_3417, Gene Names: IDH1
# Unique Identifier: 26376741|None_3598, Gene Names: IL-13Ralpha2
# Unique Identifier: 26376741|None_2064, Gene Names: Her2
# Unique Identifier: 26376741|None_7039, Gene Names: TGFbeta
# Unique Identifier: 22632886|None_7040, Gene Names: TGF-beta1, Transforming growth factor (TGF) beta1, TGF-beta1, TGF-beta1, TGF-beta1, TGF-beta1, TGF-beta1, TGF-beta1, TGF-beta1, TGF-beta1, TGF-beta1
# Unique Identifier: 21768887|None_4139, Gene Names: Mark
# Unique Identifier: 21768887|None_4140, Gene Names: Mark 3
# Unique Identifier: 19409045|None_9173, Gene Names: T1/B1, T1/B1, T1/B1
# Unique Identifier: 19409045|None_292;7905, Gene Names: T2/B2, T2/B2, T2/B2
# Unique Identifier: 17987960|None_5728, Gene Names: 10q/phosphate and tensin homolog, PTEN
# Unique Identifier: 17939769|None_4255, Gene Names: methylguanine-DNA methyltransferase
# Unique Identifier: 35768633|None_1956, Gene Names: EGFR
# Unique Identifier: 35768633|None_3417, Gene Names: IDH
# Unique Identifier: 35768633|None_4255, Gene Names: MGMT
# Unique Identifier: 34623468|None_6469, Gene Names: SHH
# Unique Identifier: 34092569|None_3417, Gene Names: IDH
# Unique Identifier: 34054040|None_5443, Gene Names: Adrenocorticotropic hormone, Adrenocorticotropic hormone
# Unique Identifier: 28691414|None_7422, Gene Names: vascular endothelial growth factor, vascular endothelial growth factor, VEGF, VEGF, VEGF, VEGF, VEGF, VEGF, VEGF, VEGF
# Unique Identifier: 28691414|None_2247, Gene Names: basic fibroblast growth factor, basic fibroblast growth factor, bFGF, bFGF, bFGF, bFGF, bFGF, bFGF
# Unique Identifier: 22821367|None_8279783, Gene Names: proliferating cell nuclear antigen
# Unique Identifier: 17636068|None_5973, Gene Names: age, Age, age, age, age, age, age, age
# Unique Identifier: 1882640|None_6271, Gene Names: S-100 alpha, S-100 beta, S-100 alpha, S-100 beta, S-100 alpha, S-100 beta, S-100 alpha, S-100 beta, S-100 alpha, S-100 beta, S-100 beta, S-100 beta, S-100 alpha, S-100 beta, S-100 alpha, S-100 alpha, S-100 beta
# Unique Identifier: 22350668|None_10763, Gene Names: Nestin, nestin, Nestin, nestin, nestin, nestin, nestin, nestin, nestin, nestin, nestin, nestin, nestin
# Unique Identifier: 19430698|None_207, Gene Names: Akt
# Unique Identifier: 19430698|None_2475, Gene Names: mTOR
# Unique Identifier: 19430698|None_5591, Gene Names: DNA-PK
# Unique Identifier: 19159078|None_406991, Gene Names: miR-21, miR-21, miR-21, miR-21, miRNA-21
# Unique Identifier: 19159078|None_407006, Gene Names: miRNA-221
# Unique Identifier: 15328205|None_14069, Gene Names: factor VIII
# Unique Identifier: 15328205|None_12367, Gene Names: caspase-3
# Unique Identifier: 15328205|None_11545, Gene Names: poly(ADP-ribose) polymerase
# Unique Identifier: 15328205|None_16000, Gene Names: insulin-like growth factor I
# Unique Identifier: 9205070|None_2272, Gene Names: FHIT, FHIT, FHIT
# Unique Identifier: 8008171|None_1956, Gene Names: epidermal growth factor receptor, epidermal growth factor receptor
# Unique Identifier: 8008171|None_1950, Gene Names: epidermal growth factor
# Unique Identifier: 8008171|None_7124, Gene Names: transforming growth factor-alpha
# Unique Identifier: 8008171|None_7422, Gene Names: vascular endothelial growth factor
# Unique Identifier: 7509461|None_4155, Gene Names: Myelin basic protein, Myelin basic protein, MBP, MBP, MBP, MBP, MBP, MBP, MBP, MBP, MBP
# Unique Identifier: 7509461|None_3054, Gene Names: VP-16
# Unique Identifier: 3812039|None_2670, Gene Names: glial fibrillary acidic protein, glial fibrillary acidic protein, GFAP, GFAP, GFAP, GFAP, GFAP, GFAP, GFAP, GFAP, GFAP
# Unique Identifier: 29464548|None_3952, Gene Names: Leptin, leptin, leptin, leptin, leptin, leptin
# Unique Identifier: 26026669|None_3417, Gene Names: IDH, IDH, IDH
# Unique Identifier: 26026669|None_673, Gene Names: BRAF
# Unique Identifier: 26026669|None_4255, Gene Names: MGMT, MGMT
# Unique Identifier: 25866320|None_113451, Gene Names: ADC, ADC
# Unique Identifier: 25468226|None_3417, Gene Names: isocitrate dehydrogenase 1, IDH1
# Unique Identifier: 23909061|None_3417, Gene Names: isocitrate dehydrogenase, IDH, IDH, IDH, IDH, IDH
# Unique Identifier: 20175962|None_7422, Gene Names: vascular endothelial growth factor, VEGF, VEGF
# Unique Identifier: 20175962|None_1956, Gene Names: epidermal growth factor receptor, EGFR, EGFR, EGFR
# Unique Identifier: 20175962|None_7039, Gene Names: TGFbeta
# Unique Identifier: 20175962|None_7040, Gene Names: TGFbeta1
# Unique Identifier: 20175962|None_7042, Gene Names: TGFbeta2
# Unique Identifier: 20175962|None_7043, Gene Names: TGFbeta3
# Unique Identifier: 12705813|None_5775, Gene Names: MEG, MEG, MEG
# Unique Identifier: 3572470|None_3054, Gene Names: VP-16, VP-16, VP-16, VP-16, VP-16
# Unique Identifier: 29322427|None_29126, Gene Names: PDL1
# Unique Identifier: 12241105|None_373156, Gene Names: glutathione S-transferase, GST, glutathione S-transferase, GST, GST, GST
# Unique Identifier: 12241105|None_2944, Gene Names: GSTM1, GSTM1, GSTM1
# Unique Identifier: 12241105|None_2952, Gene Names: GSTT1
# Unique Identifier: 12241105|None_2950, Gene Names: GSTP1, GSTP1, GSTP1, GSTP1, GSTP1
# Unique Identifier: 12140754|None_5599, Gene Names: JNK, JNK, JNK, JNK, JNK, JNK, JNK, JNK, JNK, JNK
# Unique Identifier: 12140754|None_5594, Gene Names: ERK, ERK, ERK
# Unique Identifier: 12140754|None_1956, Gene Names: EGF receptor, EGF receptor, EGF receptor
# Unique Identifier: 6401866|None_3456, Gene Names: fibroblast interferon
# Unique Identifier: 2992677|None_6714, Gene Names: src, src, Src
# Unique Identifier: 2992677|None_2673, Gene Names: GFA
# Unique Identifier: 1789685|None_3848, Gene Names: K1, k2
# Unique Identifier: 1710320|None_362686, Gene Names: rCBF, rCBF, rCBF, rCBF, rCBF, rCBF
# Unique Identifier: 1407435|None_117189, Gene Names: GD3, GD3, GD3, GD3
# Unique Identifier: 19182242|None_4255, Gene Names: MGMT
# Unique Identifier: 18648328|None_4852, Gene Names: neuropeptide Y, NPY, NPY, NPY, NPY, NPY, NPY
# Unique Identifier: 16030117|None_373156, Gene Names: glutathione S-transferases, glutathione S-transferases, GST, GST, GST, GST, GST
# Unique Identifier: 16030117|None_2944, Gene Names: GSTM1
# Unique Identifier: 16030117|None_2952, Gene Names: GSTT1
# Unique Identifier: 16030117|None_2950, Gene Names: GSTP1, GSTP1
# Unique Identifier: 14727688|None_5663, Gene Names: PS1
# Unique Identifier: 9818841|None_7157, Gene Names: p53
# Unique Identifier: 9818841|None_1029, Gene Names: p16
# Unique Identifier: 9818841|None_5728, Gene Names: PTEN, MMAC1
# Unique Identifier: 9503511|None_84366, Gene Names: PRACTICE
# Unique Identifier: 9252700|None_3315, Gene Names: Hsp-27, heat shock protein-27, Hsp-27, Hsp-27, Hsp-27, Hsp-27, Hsp-27, Hsp-27, Hsp-27, Hsp-27, Hsp-27, Hsp-27
# Unique Identifier: 6577813|None_9344, Gene Names: PSK
# Unique Identifier: 32377829|None_673, Gene Names: BRAF
# Unique Identifier: 32377829|None_1029, Gene Names: CDKN2A
# Unique Identifier: 32377829|None_3020, Gene Names: H3F3A
# Unique Identifier: 22528793|None_387, Gene Names: RhoA
# Unique Identifier: 22528793|None_388, Gene Names: RhoB
# Unique Identifier: 22528793|None_5879, Gene Names: Rac1
# Unique Identifier: 22528793|None_8976, Gene Names: N-WASP
# Unique Identifier: 22528793|None_5728, Gene Names: PTEN
# Unique Identifier: 19804368|None_2925, Gene Names: gastrin-releasing peptide receptor, GRPR
# Unique Identifier: 18000980|None_649, Gene Names: bone morphogenetic protein
# Unique Identifier: 17721931|None_4763, Gene Names: neurofibromatosis 1, NF1
# Unique Identifier: 17721931|None_4771, Gene Names: NF2
# Unique Identifier: 15236125|None_3048, Gene Names: methemoglobin
# Unique Identifier: 15015671|None_57534, Gene Names: MIB-1
# Unique Identifier: 12722674|None_7248, Gene Names: tumor suppressor
# Unique Identifier: 34613491|None_673, Gene Names: BRAF
# Unique Identifier: 34303558|None_673, Gene Names: BRAF, BRAF
# Unique Identifier: 34303558|None_2260, Gene Names: FGFR1
# Unique Identifier: 34303558|None_3417;3418, Gene Names: IDH1/2
# Unique Identifier: 34303558|None_5609, Gene Names: MEK
# Unique Identifier: 29478614|None_2475, Gene Names: mechanistic target of rapamycin
# Unique Identifier: 29478614|None_6469, Gene Names: sonic hedgehog
# Unique Identifier: 22702213|None_2690, Gene Names: Growth hormone receptor, GH receptor, GHR, GHR, GHR, GHR, GHR, GHR, GHR, GHR
# Unique Identifier: 22702213|None_2688, Gene Names: Growth hormone
# Unique Identifier: 22702213|None_8836, Gene Names: GH, GH, GH, GH
# Unique Identifier: 8621248|None_1030, Gene Names: p15, p15, p15, p15
# Unique Identifier: 8621248|None_1029, Gene Names: p16, p16, p16, p16, p16, p16
# Unique Identifier: 8621248|None_1019, Gene Names: CDK4, CDK4, CDK4, CDK4
# Unique Identifier: 8621248|None_595, Gene Names: cyclin D1, cyclin D1, cyclin D1
# Unique Identifier: 7007589|None_8658, Gene Names: Part 5
# Unique Identifier: 1967302|None_5422, Gene Names: DNA polymerase alpha, deoxyribonucleic acid (DNA) polymerase alpha, DNA polymerase alpha, DNA polymerase alpha
# Unique Identifier: 1967302|None_5111, Gene Names: proliferating cell nuclear antigen, PCNA/cyclin, PCNA/cyclin
# Unique Identifier: 37488051|None_4513, Gene Names: Cyclooxygenase (COX)-2
# Unique Identifier: 37488051|None_240, Gene Names: 5-lipoxygenase, LOX
# Unique Identifier: 10023002|None_2272, Gene Names: FHIT, FHIT, FHIT, FHIT, FHIT, FHIT, FHIT
# Unique Identifier: 8699239|None_79811, Gene Names: MET, MET, MET, MET, MET, MET, MET, MET, MET
# Unique Identifier: 8699239|None_3848;58164, Gene Names: K1, k2, k3
# Unique Identifier: 7443176|None_3054, Gene Names: VP-16, VP-16
# Unique Identifier: 4005831|None_847, Gene Names: catalase, catalase, catalase
# Unique Identifier: 3488031|None_3558, Gene Names: interleukin 2, IL-2
# Unique Identifier: 3488031|None_403989, Gene Names: interleukin-2, IL-2, IL-2
# Unique Identifier: 3488031|None_116562, Gene Names: rIL-2, rIL-2, rIL-2, rIL-2, rIL-2
# Unique Identifier: 2396538|None_448843, Gene Names: albumin, albumin
# Unique Identifier: 2352372|None_23657, Gene Names: X-CT, X-CT, X-CT, X-CT, X-CT
# Unique Identifier: 18831033|None_4051, Gene Names: cytochrome P450, CYP, CYP
# Unique Identifier: 17825381|None_796, Gene Names: calcitonin
# Unique Identifier: 17262828|None_51053, Gene Names: Geminin, Geminin, geminin, geminin, geminin, Geminin, geminin, geminin, geminin, geminin, geminin
# Unique Identifier: 17262828|None_81620, Gene Names: Cdt1
# Unique Identifier: 16330944|None_3769, Gene Names: Kir7.1, Kir7.1
# Unique Identifier: 16330944|None_6781, Gene Names: stanniocalcin-1, stanniocalcin-1
# Unique Identifier: 16330944|None_7276, Gene Names: Transthyretin
# Unique Identifier: 16330944|None_2153, Gene Names: coagulation factor V
# Unique Identifier: 16330944|None_2878, Gene Names: glutathione peroxidase 3
# Unique Identifier: 16330944|None_2192, Gene Names: fibulin-1
# Unique Identifier: 16330944|None_5357, Gene Names: plastin-1
# Unique Identifier: 16330944|None_3875, Gene Names: cytokeratin 18
# Unique Identifier: 15140402|None_113451, Gene Names: ADC
# Unique Identifier: 12564764|None_7431, Gene Names: vimentin
# Unique Identifier: 12564764|None_1674, Gene Names: desmin
# Unique Identifier: 12564764|None_2670, Gene Names: GFAP
# Unique Identifier: 12564764|None_6855, Gene Names: synaptophysin
# Unique Identifier: 11064393|None_3559, Gene Names: Interleukin-2 receptor alpha, IL-2Ralpha, IL-2Ralpha
# Unique Identifier: 11064393|None_3558, Gene Names: IL-2
# Unique Identifier: 10885653|None_2670, Gene Names: GFAP
# Unique Identifier: 10885653|None_7431, Gene Names: vimentin
# Unique Identifier: 33270865|None_139628, Gene Names: FOXR2, FOXR2, FOXR2, FOXR2
# Unique Identifier: 33270865|None_6855, Gene Names: synaptophysin
# Unique Identifier: 33270865|None_4133, Gene Names: MAP2
# Unique Identifier: 33270865|None_10215, Gene Names: OLIG2
# Unique Identifier: 26328970|None_2180, Gene Names: LACS, LACS
# Unique Identifier: 23775285|None_4255, Gene Names: MGMT
# Unique Identifier: 22138445|None_2729, Gene Names: Glutamate cysteine ligase, GCL
# Unique Identifier: 22138445|None_2937, Gene Names: glutathione synthetase, GS
# Unique Identifier: 22138445|None_2936, Gene Names: glutathione reductase, GR
# Unique Identifier: 22138445|None_4363, Gene Names: GS-X
# Unique Identifier: 21577129|None_6046, Gene Names: NaT, NaT, NaT, NaT, NaT, NaT, NaT, NaT
# Unique Identifier: 20425041|None_57534, Gene Names: MIB-1, MIB-1, MIB-1
# Unique Identifier: 20336349|None_3717, Gene Names: JAK-2, Janus Kinase 2, JAK-2, JAK
# Unique Identifier: 20336349|None_6776, Gene Names: STAT-5, STAT-5, STAT-5
# Unique Identifier: 20336349|None_2057, Gene Names: erythropoietin receptor, EpoR, EpoR, EpoR, EpoR, EpoR, EpoR, EpoR
# Unique Identifier: 20336349|None_2056, Gene Names: erythropoietin, Epo, Epo
# Unique Identifier: 1407341|None_373156, Gene Names: glutathione S-transferase, Glutathione S-transferase, GST, GST, GST, GST, GST, GST, GST
# Unique Identifier: 1407341|None_2950, Gene Names: GST-p
# Unique Identifier: 33239357|None_4904, Gene Names: Y-Box Binding Protein-1, Y-box binding protein 1, YB-1, YB-1, YB-1, YB-1, YB-1, YB-1
# Unique Identifier: 30629215|None_1956, Gene Names: epidermal growth factor receptor
# Unique Identifier: 30629215|None_673, Gene Names: BRAF
# Unique Identifier: 30629215|None_2064, Gene Names: HER2
# Unique Identifier: 30629215|None_7422, Gene Names: vascular endothelial growth factor
# Unique Identifier: 27526097|None_6469, Gene Names: sonic hedgehog, Shh
# Unique Identifier: 3020865|None_24387, Gene Names: glial fibrillary acidic protein
# Unique Identifier: 3001488|None_2670, Gene Names: GFAP, GFAP, GFAP, GFAP
# Unique Identifier: 2409734|None_480495, Gene Names: glial fibrillary acidic protein, GFAP, GFAP, GFAP, GFAP
# Unique Identifier: 2409734|None_476160, Gene Names: myelin basic protein, MBP, MBP
# Unique Identifier: 2409734|None_611884, Gene Names: myelin-associated glycoprotein, MAG, MAG
# Unique Identifier: 1992913|None_1950, Gene Names: epidermal growth factor, EGF
# Unique Identifier: 1450489|None_3558, Gene Names: interleukin-2, interleukin-2, IL-2
# Unique Identifier: 1450489|None_7124, Gene Names: tumor necrosis factor-alpha, tumor necrosis factor-alpha, TNF-alpha
# Unique Identifier: 1450489|None_116562, Gene Names: rIL-2
# Unique Identifier: 1450489|None_24835, Gene Names: TNF-alpha
# Unique Identifier: 11136998|None_6696, Gene Names: osteopontin, osteopontin
# Unique Identifier: 11126911|None_780, Gene Names: discoidin domain receptor-1, DDR1, DDR1, DDR1, DDR1
# Unique Identifier: 11126911|None_12305, Gene Names: DDR1, DDR1, DDR1, DDR1, DDR1, DDR1
# Unique Identifier: 11055797|None_4613, Gene Names: N-myc, N-myc
# Unique Identifier: 11055797|None_4609, Gene Names: c-myc, c-myc
# Unique Identifier: 10746685|None_10608, Gene Names: Mad-4
# Unique Identifier: 8621289|None_9622;51155, Gene Names: Arms 1, 2 and 3
# Unique Identifier: 8287355|None_183, Gene Names: angiotensin II, angiotensin II
# Unique Identifier: 8113867|None_3558, Gene Names: interleukin-2, Interleukin-2, IL-2
# Unique Identifier: 8113867|None_3560, Gene Names: IL-2 receptor
# Unique Identifier: 8113867|None_116562, Gene Names: IL-2, IL-2, IL-2, IL-2, IL-2
# Unique Identifier: 8113867|None_16183, Gene Names: IL-2
# Unique Identifier: 3976624|None_2688, Gene Names: Growth hormone, growth hormone
# Unique Identifier: 24453059|None_55511, Gene Names: Sage
# Unique Identifier: 23211553|None_177, Gene Names: RAGE, RAGE, RAGE
# Unique Identifier: 21082387|None_24186, Gene Names: albumin
# Unique Identifier: 19369008|None_8842, Gene Names: CD133, CD133, CD133, CD133, CD133, CD133, CD133, CD133
# Unique Identifier: 18412241|None_24224, Gene Names: bcl-2
# Unique Identifier: 18412241|None_24248, Gene Names: catalase
# Unique Identifier: 18412241|None_24786, Gene Names: sod-1
# Unique Identifier: 18412241|None_24787, Gene Names: sod-2
# Unique Identifier: 15249715|None_7422, Gene Names: vascular endothelial growth factor
# Unique Identifier: 15249715|None_5743, Gene Names: cyclooxygenase-2
# Unique Identifier: 12197239|None_7018, Gene Names: transferrin
# Unique Identifier: 12092682|None_2688, Gene Names: growth hormone
# Unique Identifier: 34433223|None_261726, Gene Names: Tip, tip
# Unique Identifier: 32725495|None_653108, Gene Names: CAR
# Unique Identifier: 30528355|None_7248;7249, Gene Names: TSC, TSC, TSC, TSC1/2, TSC, TSC, TSC
# Unique Identifier: 28993028|None_3417, Gene Names: IDH, IDH1
# Unique Identifier: 28993028|None_546, Gene Names: ATRX
# Unique Identifier: 27935156|None_842, Gene Names: CASP9, CASP9, CASP9, caspase-9, Caspase-9, caspase-9, CASP9
# Unique Identifier: 27935156|None_3417, Gene Names: IDH1
# Unique Identifier: 27935156|None_7157, Gene Names: TP53, TP53, TP53
# Unique Identifier: 26002233|None_103937, Gene Names: NanoLuc, NanoLuc
# Unique Identifier: 16132504|None_3815, Gene Names: CD117, C-kit, CD117, CD117, CD117, CD117, CD117, CD117, CD117, CD117
# Unique Identifier: 1690593|None_24387, Gene Names: glial fibrillary acidic protein
# Unique Identifier: 35641277|None_5286, Gene Names: PI3KC2beta, PI3KC2beta, PI3KC2beta, PI3KC2beta, PI3KC2beta, PI3KC2beta
# Unique Identifier: 11358858|None_7157, Gene Names: p53
# Unique Identifier: 9703825|None_9788, Gene Names: Mim
# Unique Identifier: 9447625|None_7157, Gene Names: p53
# Unique Identifier: 9210058|None_7124, Gene Names: tumor necrosis factor-alpha, tumor necrosis factor-alpha
# Unique Identifier: 8005794|None_1728, Gene Names: DT-diaphorase, DT-diaphorase
# Unique Identifier: 8005794|None_5447, Gene Names: NADPH cytochrome P-450 reductase, NADPH cytochrome P-450 reductase
# Unique Identifier: 7900450|None_30818, Gene Names: dream
# Unique Identifier: 7808603|None_8011, Gene Names: MRS, MRS, MRS, MRS
# Unique Identifier: 21955925|None_3417, Gene Names: IDH, Isocitrate dehydrogenase 1, IDH1, IDH, IDH, IDH, IDH, IDH, IDH
# Unique Identifier: 21955925|None_7157, Gene Names: TP53
# Unique Identifier: 21955925|None_4255, Gene Names: MGMT
# Unique Identifier: 21416251|None_57534, Gene Names: MIB-1, MIB-1
# Unique Identifier: 21416251|None_7345, Gene Names: UCHL-1
# Unique Identifier: 21416251|None_2670, Gene Names: GFAP
# Unique Identifier: 21416251|None_174, Gene Names: AFP
# Unique Identifier: 21416251|None_9373, Gene Names: PLAP
# Unique Identifier: 21165751|None_80835, Gene Names: TR 1
# Unique Identifier: 20192643|None_4609, Gene Names: c-Myc, c-Myc, c-Myc
# Unique Identifier: 19076777|None_11628, Gene Names: aid
# Unique Identifier: 16266053|None_6513, Gene Names: Glut-1
# Unique Identifier: 16266053|None_283871, Gene Names: PgP
# Unique Identifier: 11831641|None_5243, Gene Names: MDR1, P-glycoprotein, P-gp, P-gp
# Unique Identifier: 11780459|None_404663, Gene Names: tumor antigen, tumor antigen, Tag, Tag, Tag, Tag, Tag, Tag, Tag, Tag, Tag, Tag, Tag, Tag, Tag, Tag
# Unique Identifier: 11780459|None_5925, Gene Names: pRb, pRb, pRb, pRb, pRb, pRb
# Unique Identifier: 29071695|None_3417, Gene Names: IDH, IDH
# Unique Identifier: 28431179|None_4763, Gene Names: neurofibromatosis type 1
# Unique Identifier: 28431179|None_5728, Gene Names: PTEN
# Unique Identifier: 28431179|None_406991, Gene Names: miR-21
# Unique Identifier: 28431179|None_406900, Gene Names: miR-106b
# Unique Identifier: 28431179|None_407015, Gene Names: miR-26a
# Unique Identifier: 28431179|None_5979, Gene Names: receptor tyrosine kinase
# Unique Identifier: 28431179|None_407002, Gene Names: miR-219
# Unique Identifier: 28431179|None_442906, Gene Names: miR-338
# Unique Identifier: 27834580|None_22914, Gene Names: NKG2D, NKG2D, NKG2D, NKG2D
# Unique Identifier: 25529918|None_2744, Gene Names: glutaminase, Glutaminase, KGA
# Unique Identifier: 25529918|None_27165, Gene Names: GLS2, GLS2, GLS2, GLS2, GLS2
# Unique Identifier: 25529918|None_1, Gene Names: GAB
# Unique Identifier: 25529918|None_4609, Gene Names: c-Myc
# Unique Identifier: 25017328|None_1437, Gene Names: CSF
# Unique Identifier: 24481542|None_7157, Gene Names: TP53, TP53, TP53, TP53, TP53, TP53, TP53, TP53
# Unique Identifier: 23789953|None_9429, Gene Names: breast cancer resistance protein, BCRP
# Unique Identifier: 23550771|None_3091, Gene Names: hypoxia-inducible factor-1, hypoxia-inducible factor-1, HIF-1, HIF-1, HIF-1, HIF-1, HIF-1, HIF-1, HIF-1, HIF-1, HIF-1, HIF-1
# Unique Identifier: 34591198|None_7442, Gene Names: TRPV1, TRPV1, TRPV1, TRPV1, TRPV1, TRPV1, TRPV1, TRPV1, TRPV1, TRPV1, TRPV1
# Unique Identifier: 34591198|None_8989, Gene Names: TRPA1, TRPA1, TRPA1, TRPA1, TRPA1, TRPA1, TRPA1, TRPA1, TRPA1
# Unique Identifier: 34591198|None_3297, Gene Names: Heat-Shock Factor 1, HSF1, HSF1, HSF1, HSF1, HSF1, HSF1, HSF1, HSF1, HSF1
# Unique Identifier: 29931654|None_3417;3418, Gene Names: IDH1/2
# Unique Identifier: 29931654|None_3020, Gene Names: H3F3A
# Unique Identifier: 29931654|None_673, Gene Names: BRAF
# ...
# Unique Identifier: 23412799|None_5728, Gene Names: PTEN
# Unique Identifier: 23412799|None_4771, Gene Names: NF2
# Unique Identifier: 37743337|None_6469, Gene Names: SHH, SHH, SHH, SHH, SHH
# Unique Identifier: 37743337|None_7157, Gene Names: TP53, TP53, TP53
# Unique Identifier: 9876472|None_25819, Gene Names: NOC
# Unique Identifier: 8876132|None_17872, Gene Names: MyD116
# Unique Identifier: 8586464|None_1956, Gene Names: EGFR, EGFR, EGFR
# Unique Identifier: 8586464|None_1019, Gene Names: CDK4, CDK4, CDK4
# Unique Identifier: 8586464|None_6302, Gene Names: SAS, SAS, SAS
# Unique Identifier: 8586464|None_4193, Gene Names: MDM2, MDM2
# Unique Identifier: 8586464|None_2735, Gene Names: GLI, GLI
# Unique Identifier: 8586464|None_4609, Gene Names: MYC
# Unique Identifier: 8586464|None_4613, Gene Names: N MYC
# Unique Identifier: 8586464|None_4610, Gene Names: MYCL1
# Unique Identifier: 8586464|None_79811, Gene Names: MET
# Unique Identifier: 8586464|None_1649, Gene Names: GADD153, GADD153
# Unique Identifier: 8586464|None_3815, Gene Names: KIT
# Unique Identifier: 8586464|None_4035, Gene Names: A2MR, A2MR
# Unique Identifier: 8213081|None_4137, Gene Names: tau, tau, tau, Tau, tau, tau, tau, tau, tau
# Unique Identifier: 6174892|None_3439, Gene Names: IFN-alpha, IFN, IFN, IFN
# Unique Identifier: 2759715|None_567, Gene Names: beta 2-microglobulin
# Unique Identifier: 2605041|None_2026, Gene Names: neuron specific enolase, NSE, Neuron specific enolase, NSE, NSE, NSE, NSE, NSE, NSE, NSE, NSE, NSE, NSE
# Unique Identifier: 16872076|None_3976, Gene Names: LiF
# Unique Identifier: 16804715|None_7157, Gene Names: p53, p53
# Unique Identifier: 15853207|None_4255, Gene Names: O6-methylguanine-DNA methyltransferase, MGMT, MGMT, MGMT
# Unique Identifier: 15853207|None_1956, Gene Names: EGFR
# Unique Identifier: 15853207|None_3791, Gene Names: VEGFR
# Unique Identifier: 12002056|None_4287, Gene Names: Jos, Jos, Jos, Jos
# Unique Identifier: 11310919|None_7422, Gene Names: vascular endothelial growth factor, VEGF
# Unique Identifier: 11310919|None_57534, Gene Names: MIB-1
# Unique Identifier: 11197866|None_3438, Gene Names: IFN-beta
# Unique Identifier: 10401596|None_8011, Gene Names: MRS, MRS, MRS, MRS
# Unique Identifier: 10206462|None_174, Gene Names: alpha-fetoprotein
# Unique Identifier: 28104717|None_673, Gene Names: BRAF, BRAF
# Unique Identifier: 28104717|None_4602, Gene Names: MYB
# Unique Identifier: 28104717|None_9444, Gene Names: QKI
# Unique Identifier: 28104717|None_4603, Gene Names: MYBL1
# Unique Identifier: 28104717|None_2260, Gene Names: FGFR1
# Unique Identifier: 26022855|None_4255, Gene Names: O-6-methylguanine-DNA methyltransferase, MGMT
# Unique Identifier: 26022855|None_3075, Gene Names: arms 1p
# Unique Identifier: 26022855|None_1956, Gene Names: epidermal growth factor receptor
# Unique Identifier: 26022855|None_3417, Gene Names: isocitrate dehydrogenase 1, IDH-1
# Unique Identifier: 24857135|None_673, Gene Names: BRAF, BRAF, BRAF, BRAF, BRAF, BRAF, BRAF, BRAF, BRAF
# Unique Identifier: 24857135|None_57670, Gene Names: KIAA1549
# Unique Identifier: 23948902|None_2475, Gene Names: mTOR, mammalian target of rapamycin, mTOR, mTOR, mTOR, mTOR
# Unique Identifier: 19249579|None_8842, Gene Names: CD133, CD133
# Unique Identifier: 16961139|None_12504, Gene Names: CD4, CD4, CD4, CD4
# Unique Identifier: 16961139|None_20371, Gene Names: FoxP3
# Unique Identifier: 16961139|None_12477, Gene Names: CTLA-4
# Unique Identifier: 16961139|None_20343, Gene Names: CD62L
# Unique Identifier: 16389943|None_22339, Gene Names: Vascular endothelial growth factor, VEGF
# Unique Identifier: 15565811|None_2064, Gene Names: HER-2/neu, HER-2/neu, HER-2/neu, HER-2/neu, HER-2/neu, HER-2/neu, HER-2, neu, HER-2/neu, HER-2/neu, HER-2/neu, HER-2/neu
# Unique Identifier: 35830573|None_1593, Gene Names: CTX, CTX
# Unique Identifier: 35347632|None_1993, Gene Names: hub, hub, hub, hub, hub
# Unique Identifier: 35347632|None_3071, Gene Names: NCKAP1L, NCKAP1L, NCKAP1L
# Unique Identifier: 35347632|None_9283, Gene Names: GPR37L1, GPR37L1
# Unique Identifier: 35347632|None_1464, Gene Names: CSPG4, CSPG4
# Unique Identifier: 35347632|None_8497, Gene Names: PPFIA4, PPFIA4
# Unique Identifier: 35347632|None_254778, Gene Names: C8orf46, C8orf46
# Unique Identifier: 32553924|None_4613, Gene Names: MYCN
# Unique Identifier: 28499219|None_7157, Gene Names: TP53
# Unique Identifier: 10374339|None_5111, Gene Names: proliferating cell nuclear antigen
# Unique Identifier: 2141872|None_212541, Gene Names: rod-opsin, rod-opsin, rod-opsin, rod-opsin
# Unique Identifier: 2141872|None_13807, Gene Names: neuron-specific enolase
# Unique Identifier: 2141872|None_14580, Gene Names: glial fibrillary acidic protein
# Unique Identifier: 1383844|None_2670, Gene Names: GFAP, glial fibrillary acidic protein
# Unique Identifier: 1286726|None_968, Gene Names: CD 68, CD 68
# Unique Identifier: 35179708|None_3417, Gene Names: IDH
# Unique Identifier: 35179708|None_10630, Gene Names: podoplanin
# Unique Identifier: 33349075|None_3569, Gene Names: Interleukin (IL)-6, IL-6, IL-6, IL-6, IL-6, IL-6
# Unique Identifier: 33349075|None_7124, Gene Names: tumor necrosis factor (TNF)- alpha, TNF- alpha, TNF- alpha, TNF-alpha
# Unique Identifier: 33349075|None_3586, Gene Names: IL-10
# Unique Identifier: 31820275|None_24855, Gene Names: tsc2, TSC, tsc2
# Unique Identifier: 20167814|None_9900, Gene Names: synaptic vesicle protein 2A, Synaptic vesicle protein 2A, SV2A, SV2A, SV2A, SV2A, SV2A, SV2A, SV2A, SV2A, SV2A, SV2A
# Unique Identifier: 20167814|None_64051, Gene Names: SV2A, SV2A
# Unique Identifier: 20118657|None_3371, Gene Names: tenascin-C, TN-C, TN-C, tenascin-C, TN-C, TN-C
# Unique Identifier: 8740561|None_7018, Gene Names: transferrin
# Unique Identifier: 8740561|None_1950, Gene Names: epidermal growth factor
# Unique Identifier: 8509820|None_11224, Gene Names: L3-5
# Unique Identifier: 2681875|None_3456, Gene Names: interferon-beta
# Unique Identifier: 2681875|None_3451, Gene Names: INF-beta, INF-beta, IFN-beta
# Unique Identifier: 18768229|None_79811, Gene Names: MET, MET, MET, MET, MET, MET, MET, MET, MET, MET
# Unique Identifier: 18647264|None_10585, Gene Names: protein-o-mannosyltransferase-1, protein-o-mannosyltransferase-1, POMT1, POMT1, POMT1, POMT1
# Unique Identifier: 17909991|None_4613, Gene Names: MYCN
# Unique Identifier: 14522905|None_8842, Gene Names: CD133, CD133
# Unique Identifier: 12567456|None_8836, Gene Names: GH
# Unique Identifier: 12403562|None_4763, Gene Names: neurofibromatosis 1, Neurofibromatosis 1, neurofibromatosis 1, neurofibromatosis 1, neurofibromatosis 1, neurofibromatosis 1, neurofibromatosis 1, neurofibromatosis 1
# Unique Identifier: 11152340|None_16410, Gene Names: alpha(v) integrin
# Unique Identifier: 10531783|None_175, Gene Names: Aga
# Unique Identifier: 25022336|None_26198, Gene Names: COX-2
# Unique Identifier: 25022336|None_29527, Gene Names: cyclooxygenase-2, cyclooxygenase-2
# Unique Identifier: 25022336|None_25712, Gene Names: interferon-gamma
# Unique Identifier: 24640739|None_7422, Gene Names: VEGF, VEGF, VEGF
# Unique Identifier: 24640739|None_3791, Gene Names: VEGFR2, VEGFR2, VEGFR2, VEGFR2, VEGFR2
# Unique Identifier: 24640739|None_7422;5281;3091, Gene Names: VEGF,-PIGF,-HIF1alpha
# Unique Identifier: 24374326|None_6863, Gene Names: substance P, SP, SP, SP, SP, SP, SP
# Unique Identifier: 24374326|None_6869, Gene Names: NK1 receptor, NK1 receptor, NK1 receptor, NK1 receptor
# Unique Identifier: 23700325|None_5366, Gene Names: Apr
# Unique Identifier: 17541421|None_8743, Gene Names: tumor necrosis factor-related apoptosis-inducing ligand, TRAIL, tumor necrosis factor-related apoptosis-inducing ligand, TRAIL, TRAIL, TRAIL, TRAIL, TRAIL
# Unique Identifier: 17541421|None_1958, Gene Names: Egr-1, Egr-1
# Unique Identifier: 17541421|None_22035, Gene Names: TRAIL
# Unique Identifier: 15624764|None_57124, Gene Names: endosialin, tumor endothelial marker 1, Endosialin, tumor endothelial marker 1, endosialin, endosialin, endosialin, endosialin, endosialin, Endosialin, Endosialin
# Unique Identifier: 15624764|None_7056, Gene Names: thrombomodulin, CD141, thrombomodulin
# Unique Identifier: 15624764|None_7070, Gene Names: Thy-1
# Unique Identifier: 11826363|None_2670, Gene Names: GFAP
# Unique Identifier: 11563634|None_5743, Gene Names: prostaglandin H synthase-2, prostaglandin H synthase-2, PHS-2, PHS-2, PHS-2, PHS-2, PHS-2, PHS-2, PHS-2
# Unique Identifier: 11563634|None_5092, Gene Names: PHS, PHS
# Unique Identifier: 11563634|None_5742, Gene Names: PHS-1
# Unique Identifier: 34984433|None_1440, Gene Names: CSF, 3/230
# Unique Identifier: 34591980|None_8140, Gene Names: L-type amino acid transporter 1, LAT1
# Unique Identifier: 34376622|None_3417, Gene Names: IDH
# Unique Identifier: 31625676|None_3630, Gene Names: insulin
# Unique Identifier: 30693650|None_282809, Gene Names: cord 20
# Unique Identifier: 29028584|None_7422, Gene Names: VEGF
# Unique Identifier: 27893285|None_3417, Gene Names: IDH
# Unique Identifier: 25646527|None_2335, Gene Names: fibronectin
# Unique Identifier: 33860759|None_10215, Gene Names: olig-2
# Unique Identifier: 33860759|None_546, Gene Names: ATRX
# Unique Identifier: 33860759|None_3417, Gene Names: IDH
# Unique Identifier: 33860759|None_673, Gene Names: BRAF
# Unique Identifier: 33860759|None_1956, Gene Names: EGFR
# Unique Identifier: 31375903|None_6469, Gene Names: sonic hedgehog, SHH
# Unique Identifier: 18288395|None_6657, Gene Names: Sox2
# Unique Identifier: 18288395|None_4440, Gene Names: Musashi-1
# Unique Identifier: 18288395|None_10763, Gene Names: nestin
# Unique Identifier: 18288395|None_5111, Gene Names: PCNA
# Unique Identifier: 14565163|None_1440, Gene Names: granulocyte colony-stimulating factor, G-CSF, G-CSF
# Unique Identifier: 10572718|None_57534, Gene Names: MIB-1, MIB-1, MIB-1, MIB-1, MIB-1, MIB-1
# Unique Identifier: 10572718|None_596, Gene Names: BCL-2
# Unique Identifier: 9100674|None_1906, Gene Names: endothelin-1, endothelin-1, ET-1, ET-1, ET-1, ET-1, ET-1, ET-1, ET-1, ET-1
# Unique Identifier: 9100674|None_7040, Gene Names: transforming growth factor beta 1, transforming growth factor beta 1, TGF-beta 1, TGF-beta 1, TGF-beta 1, TGF-beta 1, TGF-beta 1, TGF-beta 1, TGF-beta 1, TGF-beta 1
# Unique Identifier: 2697376|None_921, Gene Names: Leu 1, -Leu 2 a, -Leu 3a + 3b, -LeuM 5, -HLA-DR, Leu 1
# Unique Identifier: 2697376|None_3560, Gene Names: IL-2 receptor
# Unique Identifier: 2697376|None_3105, Gene Names: HLA-A
# Unique Identifier: 1919678|None_1956, Gene Names: EGFR
# Unique Identifier: 25105827|None_2147, Gene Names: Prothrombin, prothrombin
# Unique Identifier: 22104961|None_177, Gene Names: RAGE, RAGE, RAGE, RAGE, RAGE, RAGE, RAGE, RAGE, RAGE, RAGE
# Unique Identifier: 17503347|None_2475, Gene Names: Mammalian target of rapamycin, mammalian target of rapamycin, mTOR, mTOR, mTOR, mTOR, mTOR
# Unique Identifier: 17503347|None_4763, Gene Names: neurofibromatosis type 1
# Unique Identifier: 11095486|None_1734, Gene Names: type II iodothyronine deiodinase, Type II iodothyronine deiodinase
# Unique Identifier: 10201297|None_7422, Gene Names: Vascular endothelial growth factor, Vascular endothelial growth factor, VEGF, VEGF, VEGF, VEGF, VEGF, VEGF, VEGF, VEGF
# Unique Identifier: 9825943|None_7157, Gene Names: p53, p53, p53, p53
# Unique Identifier: 2415284|None_174, Gene Names: AFP
# Unique Identifier: 2180410|None_3458, Gene Names: IFN gamma
# Unique Identifier: 2180410|None_3553, Gene Names: IL 1
# Unique Identifier: 2180410|None_3562, Gene Names: IL 3
# Unique Identifier: 2180410|None_3569, Gene Names: IL 6
# Unique Identifier: 2180410|None_7042, Gene Names: TGF beta 2
# Unique Identifier: 2180410|None_3439, Gene Names: IFN beta 1
# Unique Identifier: 2180410|None_3558, Gene Names: IL 2, IL2
# Unique Identifier: 34427324|None_246734, Gene Names: NPCR, NPCR
# Unique Identifier: 34105205|None_57379, Gene Names: aid
# Unique Identifier: 33502214|None_57379, Gene Names: aid
# Unique Identifier: 29135108|None_5443, Gene Names: ACTH
# Unique Identifier: 29135108|None_5617, Gene Names: prolactin, PRL
# Unique Identifier: 24937369|None_20315, Gene Names: SDF-1, stromal-derived factor-1, SDF-1
# Unique Identifier: 24842956|None_4255, Gene Names: O6-methylguanine-DNA methyltransferase
# Unique Identifier: 19183852|None_6855, Gene Names: synaptophysin
# Unique Identifier: 3499584|None_362686, Gene Names: rCBF, rCBF, rCBF, rCBF, rCBF, rCBF
# Unique Identifier: 21674763|None_2956, Gene Names: MSH6, MSH6, MSH6
# Unique Identifier: 21674763|None_4292, Gene Names: MLH1
# Unique Identifier: 21674763|None_4436, Gene Names: MSH2
# Unique Identifier: 21674763|None_5395, Gene Names: PMS2
# Unique Identifier: 21129063|None_4609, Gene Names: MYC
# Unique Identifier: 17483310|None_13555, Gene Names: E2F1, E2F1, E2F1, E2F1, E2F1
# Unique Identifier: 17483310|None_1869, Gene Names: E2F1, E2F1, E2F1
# Unique Identifier: 17483310|None_14580, Gene Names: GFAP, GFAP
# Unique Identifier: 12814248|None_24387, Gene Names: GFAP
# Unique Identifier: 12814248|None_24932, Gene Names: CD4
# Unique Identifier: 10651020|None_8743, Gene Names: APO2L, TRAIL, APO2 ligand, APO2L, TRAIL, APO2L, APO2L, APO2L, APO2L, APO2L, APO2L, APO2L, APO2L, APO2L, APO2L, APO2L, APO2L, APO2L, APO2L, APO2L, APO2L, APO2L, APO2L, APO2L
# Unique Identifier: 10651020|None_55733, Gene Names: SKN
# Unique Identifier: 10651020|None_2670, Gene Names: glial fibrillary acidic protein, GFAP, GFAP
# Unique Identifier: 8418502|None_24482, Gene Names: insulin-like growth factor I, insulin-like growth factor I, IGF-I, IGF-I, IGF-I, IGF-I
# Unique Identifier: 8121549|None_5362, Gene Names: Oct, Oct, Oct, Oct, Oct, Oct, Oct
# Unique Identifier: 8121549|None_5451, Gene Names: Oct-1, Oct-1, Oct-1
# Unique Identifier: 8121549|None_5454, Gene Names: N-Oct-3, N-Oct-3
# Unique Identifier: 8121549|None_5452, Gene Names: Oct-2
# Unique Identifier: 2541957|None_213, Gene Names: albumin, albumin, albumin, albumin
# Unique Identifier: 26935297|None_3481, Gene Names: IGF2
# Unique Identifier: 26935297|None_7262, Gene Names: PHLDA2, TSSC3
# Unique Identifier: 26935297|None_10612, Gene Names: TRIM3
# Unique Identifier: 26935297|None_5002, Gene Names: SLC22A18
# Unique Identifier: 23625089|None_4233, Gene Names: c-Met, c-Met, c-Met, c-Met, c-Met, c-Met, c-Met, c-Met, c-Met
# Unique Identifier: 23625089|None_17295, Gene Names: c-Met
# Unique Identifier: 21879178|None_10058, Gene Names: ABC
# Unique Identifier: 21879178|None_440068, Gene Names: INCA, INCA
# Unique Identifier: 21879178|None_4363, Gene Names: multiple drugs resistance associated protein 1, Mrp1, Mrp1
# Unique Identifier: 21317885|None_10277, Gene Names: UBE4B, UBE4B, UBE4B
# Unique Identifier: 21317885|None_4193, Gene Names: Hdm2, Hdm2
# Unique Identifier: 21317885|None_7157, Gene Names: TP53
# Unique Identifier: 21317885|None_63958, Gene Names: ubiquitination factor E4B, UBE4B, UBE4B, UBE4B, UBE4B
# Unique Identifier: 21317885|None_17246, Gene Names: Mdm2
# Unique Identifier: 18396787|None_246100, Gene Names: NY-ESO-1, NY-ESO-1, NY-ESO-1, NY-ESO-1, NY-ESO-1, NY-ESO-1, NY-ESO-1, NY-ESO-1
# Unique Identifier: 2213114|None_250, Gene Names: Alkaline phosphatase, alkaline phosphatase, ALP, ALP, ALP, ALP, ALP, ALP, ALP
# Unique Identifier: 1738033|None_16183, Gene Names: interleukin-2, interleukin-2, IL-2, IL-2, IL-2, IL-2, IL-2, IL-2, IL-2, IL-2
# Unique Identifier: 1738033|None_7096, Gene Names: TIL, TIL, TIL
# Unique Identifier: 1738033|None_21897, Gene Names: TIL, TIL, TIL, TIL, TIL, TIL
# Unique Identifier: 1738033|None_3558, Gene Names: IL-2
# Unique Identifier: 51071|None_1437, Gene Names: CSF, CSF, CSF, CSF, CSF, CSF, CSF
# Unique Identifier: 22821382|None_3417, Gene Names: IDH1, IDH1, IDH1, IDH1, IDH1, IDH1, IDH1
# Unique Identifier: 22821382|None_3417;3418, Gene Names: IDH1/2
# Unique Identifier: 22821382|None_3418, Gene Names: IDH2
# Unique Identifier: 11837749|None_2670, Gene Names: GFAP
# Unique Identifier: 11837749|None_6855, Gene Names: synaptophysin
# Unique Identifier: 11837749|None_57534, Gene Names: MIB-1
# Unique Identifier: 7848917|None_24577, Gene Names: Myc, Myc, c-Myc, Myc, myc, myc, myc, c-myc, Myc
# Unique Identifier: 7848917|None_301300, Gene Names: p53, p53
# Unique Identifier: 7848917|None_4609, Gene Names: MYC

# %%
print(unique_identifiers)
# Out:
# {'33273172|None_57379': ['aid'], '33069197|None_4609': ['C-Myc', 'c-Myc', 'c-Myc', 'c-Myc', 'c-Myc', 'c-Myc'], '30239861|None_673': ['BRAF', 'proto-oncogene B-Raf'], '30239861|None_8743': ['TRAIL', 'tumor necrosis factor apoptosis inducing ligand'], '30239861|None_5159': ['PDGFR', 'platelet derived growth factor receptor'], '28516751|None_2688': ['Growth Hormone', 'growth hormone', 'GH', 'GH', 'GH', 'GH'], '17032559|None_4255': ['MGMT', 'MGMT'], '16778750|None_148398': ['MRS', 'MRS', 'MRS', 'MRS'], '15612600|None_84366': ['PRACTICE'], '1361524|None_5243': ['P-glycoprotein', 'P-glycoprotein', 'P-gp', 'P-gp', 'P-gp', 'P-gp', 'P-gp', 'P-gp', 'P-gp', 'P-gp', 'P-gp'], '19238661|None_1437': ['CSF', 'CSF', 'CSF'], '16245217|None_23405': ['DICER'], '16245217|None_59342': ['RISC'], '15993075|None_5881': ['Rac3', 'Rac3', 'Rac3', 'Rac3', 'Rac3', 'Rac3', 'Rac3', 'Rac3', 'Rac3', 'Rac3', 'Rac3', 'Rac3'], '12216107|None_79811': ['MET', 'MET', 'MET', 'MET', 'MET', 'MET'], '12216107|None_57534': ['MIB-1'], '11900859|None_7157': ['p53', 'p53', 'p53', 'p53', 'p53', 'p53', 'p53', 'p53', 'p53', 'p53'], '11051794|None_5364': ['SEP'], '11051794|None_29': ['ABR'], '10652582|None_808': ['CAM'], '9879457|None_338412': ['PS 2'], '34061562|None_43': ['acetylcholinesterase'], '30935361|None_3417': ['isocitrate dehydrogenase', 'IDH', 'IDH'], '27463526|None_2149': ['TR'], '25054358|None_7422': ['VEGF'], '20521177|None_3565': ['IL-4'], '20521177|None_8743': ['TRAIL'], '3729310|None_57379': ['aid'], '2643496|None_22915': ['ECM', 'ECM'], '2558501|None_24387': ['glial fibrillary acidic protein, S-100'], '2558501|None_81818': ['vimentin'], '17725214|None_23218': ['GPS'], '11816741|None_2936': ['glutathione reductase', 'glutathione reductase'], '11816741|None_6647': ['SOD-1'], '11408092|None_24609': ['ornithine decarboxylase', 'ornithine decarboxylase', 'ODC', 'ODC', 'ODC', 'ODC', 'ODC', 'ODC', 'ODC'], '11151727|None_799': ['CRT', 'CRT', 'CRT'], '10100707|None_1508': ['Cathepsin B', 'cathepsin (Cat) B', 'Cat B', 'Cat B', 'Cat B', 'Cat B', 'Cat B', 'Cat B', 'Cat B'], '6098128|None_24387': ['glial fibrillary acidic protein'], '4027919|None_174': ['alpha-fetoprotein'], '1016286|None_10309': ['CCNU', 'CCNU'], '25241806|None_57379': ['aid'], '23944103|None_3938': ['Lac', 'Lac'], '23944103|None_23049': ['Lip', 'Lip'], '16900783|None_5743': ['Cyclooxygenase-2', 'COX-2', 'COX-2', 'COX-2'], '9949905|None_5734': ['EP4', 'EP4'], '9949905|None_6855': ['synaptophysin'], '7793096|None_2495': ['ferritin heavy chain'], '7651591|None_1445': ['CSK'], '7582248|None_57534': ['MIB-1', 'MIB-1', 'MIB-1'], '3801549|None_2670': ['glial fibrillary acidic protein', 'GFAP', 'GFAP', 'GFAP'], '33711670|None_4842': ['nitric oxide synthase', 'nNOS'], '33711670|None_4843': ['iNOS'], '33711670|None_4846': ['eNOS'], '33711670|None_4953': ['ornithine decarboxylase'], '28844173|None_57120': ['GOPC'], '28844173|None_6098': ['ROS1'], '28844173|None_1019': ['CDK4'], '28844173|None_4763': ['NF1'], '28844173|None_57670': ['KIAA1549'], '28844173|None_673': ['BRAF'], '22497851|None_6598': ['INI-1', 'INI-1'], '19618856|None_2146': ['EZH2'], '8597115|None_7157': ['p53', 'p53'], '7546012|None_5443': ['Adrenocorticotropic hormone'], '2192793|None_1956': ['epidermal growth factor receptor'], '2192793|None_4609': ['c-myc'], '1798908|None_253260': ['pia'], '25783972|None_4255': ['O-6-methylguanine-DNA methyltransferase', 'MGMT'], '19587462|None_10178': ['TNM'], '15756927|None_4836': ['N-myristoyltransferase', 'N-myristoyltransferase', 'NMT', 'NMT', 'NMT', 'NMT1', 'NMT', 'NMT'], '15756927|None_9397': ['NMT2'], '7882284|None_7157': ['p53', 'p53', 'p53', 'p53', 'p53'], '7745467|None_5328': ['urokinase-type plasminogen activator', 'uPAR', 'uPAR', 'uPAR', 'uPA', 'uPA', 'uPAR', 'uPAR', 'uPA', 'uPAR'], '7745467|None_5340': ['plasmin', 'plasmin'], '3900810|None_1084': ['CEA', 'CEA', 'carcinoembryonic antigen', 'CEA', 'CEA'], '3808569|None_2670': ['Glial fibrillary acidic protein', 'Glial fibrillary acidic protein', 'glia ...

# %% [markdown]
# **This organizes the gene names and helps collect all the unquie names mentioned in each article/abstracts.**

# %%
import openpyxl
from openpyxl.styles import PatternFill

# Load the Excel workbook
file_path = 'Abstracts and full text.xlsx'
worksheet_name = 'AB_Gene_Names'  # Replace 'Sheet1' with the name of your worksheet
workbook = openpyxl.load_workbook(file_path)
worksheet = workbook[worksheet_name]

# Create an empty dictionary to store unique identifiers with gene names
unique_geneIDs = {}

# Iterate through the rows
for index, row in enumerate(worksheet.iter_rows(min_row=2, values_only=True), start=2):
    pmid = row[0]  # Assuming PMID is in the first column (column A)
    identifier = row[1]  # Assuming Identifier is in the second column (column B)
    gene_name = row[3]  # Assuming Gene Name is in the fourth column (column D)

    # Combine PMID and Identifier to create a unique identifier key
    unique_identifier = f"{pmid}_{identifier}"

    # Check if the unique identifier is already in the dictionary
    if unique_identifier not in unique_geneIDs:
        unique_geneIDs[unique_identifier] = [gene_name.upper()]  # Initialize a list with the capitalized gene name
    else:
        # If the key exists, append the capitalized gene name to the existing list
        unique_geneIDs[unique_identifier].append(gene_name.upper())

    # Highlight the current row with yellow fill color
    for cell in worksheet[index]:
        cell.fill = PatternFill(start_color='FFFF00', end_color='FFFF00', fill_type='solid')

# Sort the gene names within each dictionary section
for identifier, gene_names in unique_geneIDs.items():
    unique_geneIDs[identifier] = sorted(set(gene_names), key=lambda x: (len(x), x))

# Display the unique identifiers with their corresponding gene names
for identifier, gene_names in unique_geneIDs.items():
    print(f"Unique Identifier: {identifier}, Gene Names: {', '.join(gene_names)}")
    

# Save the modified workbook (overwriting the original file)
workbook.save(file_path)

# Close the workbook
workbook.close()
# Out:
# Unique Identifier: 33273172|None_57379, Gene Names: AID
# Unique Identifier: 33069197|None_4609, Gene Names: C-MYC
# Unique Identifier: 30239861|None_673, Gene Names: BRAF, PROTO-ONCOGENE B-RAF
# Unique Identifier: 30239861|None_8743, Gene Names: TRAIL, TUMOR NECROSIS FACTOR APOPTOSIS INDUCING LIGAND
# Unique Identifier: 30239861|None_5159, Gene Names: PDGFR, PLATELET DERIVED GROWTH FACTOR RECEPTOR
# Unique Identifier: 28516751|None_2688, Gene Names: GH, GROWTH HORMONE
# Unique Identifier: 17032559|None_4255, Gene Names: MGMT
# Unique Identifier: 16778750|None_148398, Gene Names: MRS
# Unique Identifier: 15612600|None_84366, Gene Names: PRACTICE
# Unique Identifier: 1361524|None_5243, Gene Names: P-GP, P-GLYCOPROTEIN
# Unique Identifier: 19238661|None_1437, Gene Names: CSF
# Unique Identifier: 16245217|None_23405, Gene Names: DICER
# Unique Identifier: 16245217|None_59342, Gene Names: RISC
# Unique Identifier: 15993075|None_5881, Gene Names: RAC3
# Unique Identifier: 12216107|None_79811, Gene Names: MET
# Unique Identifier: 12216107|None_57534, Gene Names: MIB-1
# Unique Identifier: 11900859|None_7157, Gene Names: P53
# Unique Identifier: 11051794|None_5364, Gene Names: SEP
# Unique Identifier: 11051794|None_29, Gene Names: ABR
# Unique Identifier: 10652582|None_808, Gene Names: CAM
# Unique Identifier: 9879457|None_338412, Gene Names: PS 2
# Unique Identifier: 34061562|None_43, Gene Names: ACETYLCHOLINESTERASE
# Unique Identifier: 30935361|None_3417, Gene Names: IDH, ISOCITRATE DEHYDROGENASE
# Unique Identifier: 27463526|None_2149, Gene Names: TR
# Unique Identifier: 25054358|None_7422, Gene Names: VEGF
# Unique Identifier: 20521177|None_3565, Gene Names: IL-4
# Unique Identifier: 20521177|None_8743, Gene Names: TRAIL
# Unique Identifier: 3729310|None_57379, Gene Names: AID
# Unique Identifier: 2643496|None_22915, Gene Names: ECM
# Unique Identifier: 2558501|None_24387, Gene Names: GLIAL FIBRILLARY ACIDIC PROTEIN, S-100
# Unique Identifier: 2558501|None_81818, Gene Names: VIMENTIN
# Unique Identifier: 17725214|None_23218, Gene Names: GPS
# Unique Identifier: 11816741|None_2936, Gene Names: GLUTATHIONE REDUCTASE
# Unique Identifier: 11816741|None_6647, Gene Names: SOD-1
# Unique Identifier: 11408092|None_24609, Gene Names: ODC, ORNITHINE DECARBOXYLASE
# Unique Identifier: 11151727|None_799, Gene Names: CRT
# Unique Identifier: 10100707|None_1508, Gene Names: CAT B, CATHEPSIN B, CATHEPSIN (CAT) B
# Unique Identifier: 6098128|None_24387, Gene Names: GLIAL FIBRILLARY ACIDIC PROTEIN
# Unique Identifier: 4027919|None_174, Gene Names: ALPHA-FETOPROTEIN
# Unique Identifier: 1016286|None_10309, Gene Names: CCNU
# Unique Identifier: 25241806|None_57379, Gene Names: AID
# Unique Identifier: 23944103|None_3938, Gene Names: LAC
# Unique Identifier: 23944103|None_23049, Gene Names: LIP
# Unique Identifier: 16900783|None_5743, Gene Names: COX-2, CYCLOOXYGENASE-2
# Unique Identifier: 9949905|None_5734, Gene Names: EP4
# Unique Identifier: 9949905|None_6855, Gene Names: SYNAPTOPHYSIN
# Unique Identifier: 7793096|None_2495, Gene Names: FERRITIN HEAVY CHAIN
# Unique Identifier: 7651591|None_1445, Gene Names: CSK
# Unique Identifier: 7582248|None_57534, Gene Names: MIB-1
# Unique Identifier: 3801549|None_2670, Gene Names: GFAP, GLIAL FIBRILLARY ACIDIC PROTEIN
# Unique Identifier: 33711670|None_4842, Gene Names: NNOS, NITRIC OXIDE SYNTHASE
# Unique Identifier: 33711670|None_4843, Gene Names: INOS
# Unique Identifier: 33711670|None_4846, Gene Names: ENOS
# Unique Identifier: 33711670|None_4953, Gene Names: ORNITHINE DECARBOXYLASE
# Unique Identifier: 28844173|None_57120, Gene Names: GOPC
# Unique Identifier: 28844173|None_6098, Gene Names: ROS1
# Unique Identifier: 28844173|None_1019, Gene Names: CDK4
# Unique Identifier: 28844173|None_4763, Gene Names: NF1
# Unique Identifier: 28844173|None_57670, Gene Names: KIAA1549
# Unique Identifier: 28844173|None_673, Gene Names: BRAF
# Unique Identifier: 22497851|None_6598, Gene Names: INI-1
# Unique Identifier: 19618856|None_2146, Gene Names: EZH2
# Unique Identifier: 8597115|None_7157, Gene Names: P53
# Unique Identifier: 7546012|None_5443, Gene Names: ADRENOCORTICOTROPIC HORMONE
# Unique Identifier: 2192793|None_1956, Gene Names: EPIDERMAL GROWTH FACTOR RECEPTOR
# Unique Identifier: 2192793|None_4609, Gene Names: C-MYC
# Unique Identifier: 1798908|None_253260, Gene Names: PIA
# Unique Identifier: 25783972|None_4255, Gene Names: MGMT, O-6-METHYLGUANINE-DNA METHYLTRANSFERASE
# Unique Identifier: 19587462|None_10178, Gene Names: TNM
# Unique Identifier: 15756927|None_4836, Gene Names: NMT, NMT1, N-MYRISTOYLTRANSFERASE
# Unique Identifier: 15756927|None_9397, Gene Names: NMT2
# Unique Identifier: 7882284|None_7157, Gene Names: P53
# Unique Identifier: 7745467|None_5328, Gene Names: UPA, UPAR, UROKINASE-TYPE PLASMINOGEN ACTIVATOR
# Unique Identifier: 7745467|None_5340, Gene Names: PLASMIN
# Unique Identifier: 3900810|None_1084, Gene Names: CEA, CARCINOEMBRYONIC ANTIGEN
# Unique Identifier: 3808569|None_2670, Gene Names: GLIAL FIBRILLARY ACIDIC PROTEIN
# Unique Identifier: 1608541|None_348, Gene Names: APOLIPOPROTEIN E, APOLIPOPROTEIN-E
# Unique Identifier: 31917601|None_139628, Gene Names: FOXR2
# Unique Identifier: 31917601|None_54880, Gene Names: BCOR
# Unique Identifier: 28493234|None_7157, Gene Names: P53
# Unique Identifier: 28493234|None_472, Gene Names: ATM
# Unique Identifier: 28493234|None_894, Gene Names: CYCLIN D2
# Unique Identifier: 28493234|None_1956, Gene Names: EGFR
# Unique Identifier: 28493234|None_207, Gene Names: AKT
# Unique Identifier: 28395087|None_7157, Gene Names: TP53
# Unique Identifier: 28395087|None_3417, Gene Names: IDH1
# Unique Identifier: 28395087|None_5290, Gene Names: PIK3CA
# Unique Identifier: 28395087|None_5728, Gene Names: PTEN
# Unique Identifier: 28395087|None_1956, Gene Names: EGFR
# Unique Identifier: 28395087|None_673, Gene Names: BRAF
# Unique Identifier: 28395087|None_1499, Gene Names: CTNNB1
# Unique Identifier: 18046441|None_207, Gene Names: AKT
# Unique Identifier: 18046441|None_5728, Gene Names: PTEN
# Unique Identifier: 18046441|None_57126, Gene Names: CELL SURFACE RECEPTOR
# Unique Identifier: 15877531|None_8658, Gene Names: PART 5
# Unique Identifier: 15877531|None_581, Gene Names: BAX
# Unique Identifier: 15877531|None_596, Gene Names: BCL-2
# Unique Identifier: 15877531|None_8837, Gene Names: CFLIP, EFFECTOR CASPASES
# Unique Identifier: 15877531|None_207, Gene Names: AKT
# Unique Identifier: 12456378|None_7124, Gene Names: TRANSFORMING GROWTH FACTOR BETA, TRANSFORMING GROWTH FACTOR-BETA
# Unique Identifier: 12456378|None_7039, Gene Names: TGF-BETA
# Unique Identifier: 7843802|None_259, Gene Names: BIKUNIN
# Unique Identifier: 2464270|None_2335, Gene Names: FIBRONECTIN
# Unique Identifier: 35715607|None_361, Gene Names: AQP4, AQUAPORIN 4, AQUAPORIN-4
# Unique Identifier: 35715607|None_54205, Gene Names: CYTOCHROME C
# Unique Identifier: 35715607|None_596, Gene Names: BCL-2
# Unique Identifier: 35715607|None_3620, Gene Names: IDO1
# Unique Identifier: 35715607|None_6999, Gene Names: TDO
# Unique Identifier: 35715607|None_196, Gene Names: AHR
# Unique Identifier: 35715607|None_645323, Gene Names: LINC00461
# Unique Identifier: 35715607|None_406998, Gene Names: MIR-216A
# Unique Identifier: 25792036|None_129807, Gene Names: NEU4
# Unique Identifier: 25792036|None_1486, Gene Names: CTBS
# Unique Identifier: 25792036|None_57704, Gene Names: GBA2
# Unique Identifier: 25792036|None_1075, Gene Names: CTSC
# Unique Identifier: 25792036|None_1513, Gene Names: CTSK
# Unique Identifier: 25792036|None_8722, Gene Names: CTSF
# Unique Identifier: 25139406|None_3075, Gene Names: ARMS 1P
# Unique Identifier: 25139406|None_3417, Gene Names: IDH1
# Unique Identifier: 25139406|None_3418, Gene Names: IDH2
# Unique Identifier: 25037494|None_4255, Gene Names: MGMT, O6-METHYLGUANINE-DNA METHYLTRANSFERASE
# Unique Identifier: 24169416|None_7422, Gene Names: VEGF, VASCULAR ENDOTHELIAL GROWTH FACTOR
# Unique Identifier: 24169416|None_1956, Gene Names: EGFR, EPIDERMAL GROWTH FACTOR RECEPTOR
# Unique Identifier: 16988585|None_1499, Gene Names: BETA-CATENIN
# Unique Identifier: 8367211|None_5788, Gene Names: CD45RO
# Unique Identifier: 3973708|None_2670, Gene Names: GFAP, GLIAL FIBRILLARY ACIDIC PROTEIN
# Unique Identifier: 35704146|None_5467, Gene Names: PPARDELTA
# Unique Identifier: 35704146|None_5468, Gene Names: PPARGAMMA
# Unique Identifier: 34739635|None_1029, Gene Names: CDKN2A
# Unique Identifier: 34739635|None_1956, Gene Names: EGFR
# Unique Identifier: 34739635|None_5156, Gene Names: PDGFRA
# Unique Identifier: 34739635|None_5728, Gene Names: PTEN
# Unique Identifier: 34739635|None_1019, Gene Names: CDK4
# Unique Identifier: 34739635|None_3815, Gene Names: KIT
# Unique Identifier: 34739635|None_5290, Gene Names: PIK3CA
# Unique Identifier: 34739635|None_4193, Gene Names: MDM2
# Unique Identifier: 27281939|None_3417, Gene Names: IDH, ISOCYTRATE DEHYDROGENASE
# Unique Identifier: 27281939|None_4255, Gene Names: MGMT
# Unique Identifier: 24896362|None_5243, Gene Names: ABCB1
# Unique Identifier: 20860895|None_3934, Gene Names: NGAL, NEUTROPHIL GELATINASE-ASSOCIATED LIPOCALIN
# Unique Identifier: 19107440|None_7157, Gene Names: TP53
# Unique Identifier: 19107440|None_4255, Gene Names: MGMT, O6 -METHYLGUANINE-DNA METHYLTRANSFERASE
# Unique Identifier: 11496317|None_990, Gene Names: CDC6
# Unique Identifier: 11496317|None_4174, Gene Names: MCM5
# Unique Identifier: 11496317|None_57534, Gene Names: MIB-1
# Unique Identifier: 11134091|None_2688, Gene Names: GROWTH HORMONE
# Unique Identifier: 11134091|None_8836, Gene Names: GH
# Unique Identifier: 36191126|None_9970, Gene Names: CAR, CHIMERIC ANTIGEN RECEPTOR
# Unique Identifier: 29429648|None_3702, Gene Names: ITK
# Unique Identifier: 25037493|None_4255, Gene Names: MGMT, O6-METHYLGUANINE-DNA METHYLTRANSFERASE
# Unique Identifier: 24881141|None_3417, Gene Names: IDH
# Unique Identifier: 20075834|None_7422, Gene Names: VEGF, VASCULAR ENDOTHELIAL GROWTH FACTOR
# Unique Identifier: 15816119|None_3371, Gene Names: TENASCIN
# Unique Identifier: 10895165|None_2670, Gene Names: GFAP
# Unique Identifier: 10895165|None_2026, Gene Names: NSE
# Unique Identifier: 10895165|None_4155, Gene Names: MBP
# Unique Identifier: 6964044|None_9344, Gene Names: PSK
# Unique Identifier: 6964044|None_4067, Gene Names: LYN
# Unique Identifier: 36841424|None_653108, Gene Names: CAR
# Unique Identifier: 31918786|None_546, Gene Names: ATRX
# Unique Identifier: 31918786|None_7157, Gene Names: TP53
# Unique Identifier: 15757449|None_7157, Gene Names: P53
# Unique Identifier: 15757449|None_4193, Gene Names: MDM2
# Unique Identifier: 15612598|None_84366, Gene Names: PRACTICE
# Unique Identifier: 13680293|None_4843, Gene Names: INOS, NO SYNTHASE, INDUCIBLE-FORM NOS
# Unique Identifier: 8402649|None_5443, Gene Names: MET-ENKEPHALIN
# Unique Identifier: 8402649|None_5179, Gene Names: PREPROENKEPHALIN
# Unique Identifier: 7931595|None_1511, Gene Names: HCG
# Unique Identifier: 7931595|None_2796, Gene Names: GONADOTROPIN-RELEASING HORMONE
# Unique Identifier: 2812355|None_10178, Gene Names: TNM
# Unique Identifier: 25175689|None_6892, Gene Names: TAPASIN
# Unique Identifier: 25175689|None_3458, Gene Names: IFNGAMMA
# Unique Identifier: 24061639|None_7517, Gene Names: XRCC3, X-RAY REPAIR CROSS-COMPLEMENTING GROUP 3
# Unique Identifier: 22528799|None_79811, Gene Names: MET
# Unique Identifier: 22238331|None_3417, Gene Names: IDH, ISOCITRATE DEHYDROGENASE
# Unique Identifier: 18384511|None_3958, Gene Names: GAL-3, GALECTIN-3
# Unique Identifier: 18384511|None_148003, Gene Names: BETA-GALACTOSIDE-BINDING LECTIN
# Unique Identifier: 7807193|None_5243, Gene Names: P-GLYCOPROTEIN
# Unique Identifier: 6384434|None_6236, Gene Names: RAD
# Unique Identifier: 3560451|None_1084, Gene Names: CEA
# Unique Identifier: 29791066|None_4591, Gene Names: MUL
# Unique Identifier: 17593388|None_5243, Gene Names: MDR1, P-GLYCOPROTEIN
# Unique Identifier: 17593388|None_283871, Gene Names: PGP
# Unique Identifier: 17157785|None_8842, Gene Names: CD133
# Unique Identifier: 17157785|None_1111, Gene Names: CHK1
# Unique Identifier: 17157785|None_11200, Gene Names: CHK2
# Unique Identifier: 15645005|None_80781, Gene Names: ENDOSTATIN
# Unique Identifier: 12722932|None_4193, Gene Names: MDM2
# Unique Identifier: 12722932|None_1029, Gene Names: INK4A
# Unique Identifier: 12271818|None_3479, Gene Names: IGF-I
# Unique Identifier: 11342692|None_3009, Gene Names: H15
# Unique Identifier: 11120864|None_12504, Gene Names: CD4
# Unique Identifier: 31749132|None_4914, Gene Names: TRK
# Unique Identifier: 19770657|None_1956, Gene Names: EPIDERMAL GROWTH FACTOR RECEPTOR
# Unique Identifier: 15612602|None_84366, Gene Names: PRACTICE
# Unique Identifier: 10597192|None_113829, Gene Names: TUMOR-REJECTION ANTIGEN
# Unique Identifier: 10597192|None_9092, Gene Names: SART1
# Unique Identifier: 7965140|None_3456, Gene Names: IFN-B, INTERFERON-BETA
# Unique Identifier: 3099535|None_2670, Gene Names: GFAP, GLIAL FIBRILLARY ACIDIC PROTEIN
# Unique Identifier: 2990597|None_2673, Gene Names: GFA
# Unique Identifier: 2288775|None_373156, Gene Names: GLUTATHIONE S-TRANSFERASE
# Unique Identifier: 36314394|None_57741, Gene Names: NIR
# Unique Identifier: 36314394|None_12484, Gene Names: HSA
# Unique Identifier: 36314394|None_15953, Gene Names: IRGD
# Unique Identifier: 36314394|None_11657, Gene Names: ALBUMIN
# Unique Identifier: 36154607|None_92737, Gene Names: BET, BROMODOMAIN AND EXTRATERMINAL
# Unique Identifier: 36154607|None_1025, Gene Names: CDK9, CYCLIN-DEPENDENT KINASE 9
# Unique Identifier: 36154607|None_558, Gene Names: AXL
# Unique Identifier: 36154607|None_648, Gene Names: BMI1
# Unique Identifier: 36154607|None_1387, Gene Names: CBP, CREB BINDING PROTEIN
# Unique Identifier: 10850867|None_1956, Gene Names: EGFR
# Unique Identifier: 10850867|None_1019, Gene Names: CDK4
# Unique Identifier: 10850867|None_1029, Gene Names: CDKN2A
# Unique Identifier: 10850867|None_7157, Gene Names: TP53
# Unique Identifier: 10850867|None_1755, Gene Names: DMBT1
# Unique Identifier: 10850867|None_4771, Gene Names: NF2
# Unique Identifier: 10850867|None_5728, Gene Names: PTEN
# Unique Identifier: 9241081|None_57534, Gene Names: MIB-1
# Unique Identifier: 8741689|None_596, Gene Names: BCL-2
# Unique Identifier: 8741689|None_598, Gene Names: BCL-X
# Unique Identifier: 8741689|None_581, Gene Names: BAX
# Unique Identifier: 8741689|None_8824, Gene Names: ICE
# Unique Identifier: 8741689|None_835, Gene Names: ICH-1
# Unique Identifier: 8741689|None_356, Gene Names: FAS LIGAND
# Unique Identifier: 8494908|None_7157, Gene Names: P53
# Unique Identifier: 8494908|None_4763, Gene Names: NF1, NEUROFIBROMATOSIS 1
# Unique Identifier: 8494908|None_1956, Gene Names: EPIDERMAL GROWTH FACTOR RECEPTOR
# Unique Identifier: 8494908|None_7124, Gene Names: TRANSFORMING GROWTH FACTOR-ALPHA AND -BETA
# Unique Identifier: 8494908|None_4609, Gene Names: C-MYC
# Unique Identifier: 8494908|None_2353, Gene Names: C-FOS
# Unique Identifier: 8494908|None_3479;3481, Gene Names: INSULIN-LIKE GROWTH FACTOR I AND II
# Unique Identifier: 8494908|None_2064, Gene Names: C-ERB B-2
# Unique Identifier: 8329302|None_6521, Gene Names: SAO
# Unique Identifier: 1648677|None_57379, Gene Names: AID
# Unique Identifier: 35419084|None_49860, Gene Names: CRNN
# Unique Identifier: 34806136|None_4763, Gene Names: NEUROFIBROMATOSIS 1
# Unique Identifier: 29890272|None_2521, Gene Names: FUS
# Unique Identifier: 29802595|None_2688, Gene Names: GROWTH HORMONE
# Unique Identifier: 28303493|None_4255, Gene Names: MGMT
# Unique Identifier: 28303493|None_1956, Gene Names: EGFR
# Unique Identifier: 28303493|None_546, Gene Names: ATRX
# Unique Identifier: 28303493|None_7015, Gene Names: TERT
# Unique Identifier: 28303493|None_673, Gene Names: BRAF
# Unique Identifier: 25142793|None_1786, Gene Names: DNMT, DNA METHYLTRANSFERASES
# Unique Identifier: 25142793|None_57348, Gene Names: TTYH1
# Unique Identifier: 25142793|None_1789, Gene Names: DNMT3B
# Unique Identifier: 19322535|None_4255, Gene Names: MGMT
# Unique Identifier: 15593389|None_361, Gene Names: AQP4, AQUAPORIN-4
# Unique Identifier: 36400017|None_3417, Gene Names: IDH
# Unique Identifier: 35067500|None_2475, Gene Names: MAMMALIAN TARGET OF RAPAMYCIN
# Unique Identifier: 21533813|None_1401, Gene Names: C-REACTIVE PROTEIN
# Unique Identifier: 21533813|None_213, Gene Names: ALBUMIN
# Unique Identifier: 17538177|None_5243, Gene Names: P-GP, P-GLYCOPROTEIN
# Unique Identifier: 9503517|None_84366, Gene Names: PRACTICE
# Unique Identifier: 7794250|None_6298, Gene Names: MTS1
# Unique Identifier: 3213427|None_2670, Gene Names: GFAP, GLIAL FIBRILLARY ACIDIC PROTEIN
# Unique Identifier: 3213427|None_7431, Gene Names: VIMENTIN
# Unique Identifier: 3213427|None_5265, Gene Names: ALPHA-1-ANTITRYPSIN
# Unique Identifier: 3213427|None_12, Gene Names: ALPHA-1-ANTICHYMOTRYPSIN
# Unique Identifier: 2262373|None_8836, Gene Names: GH
# Unique Identifier: 37743328|None_9644, Gene Names: SH3PXD2A
# Unique Identifier: 37743328|None_5654, Gene Names: HTRA1
# Unique Identifier: 37743328|None_4771, Gene Names: NF2
# Unique Identifier: 37743328|None_84231, Gene Names: TRAF7
# Unique Identifier: 37743328|None_9314, Gene Names: KLF4
# Unique Identifier: 37743328|None_207, Gene Names: AKT1
# Unique Identifier: 37743328|None_6608, Gene Names: SMO
# Unique Identifier: 37743328|None_7015, Gene Names: TERT
# Unique Identifier: 37743328|None_1029;1030, Gene Names: CDKN2A/B
# Unique Identifier: 29391205|None_1493, Gene Names: CTLA4, CYTOTOXIC T-LYMPHOCYTE PROTEIN 4
# Unique Identifier: 29391205|None_5133, Gene Names: PROGRAMMED CELL DEATH 1
# Unique Identifier: 29391205|None_29126, Gene Names: PDL1
# Unique Identifier: 20402394|None_100855519, Gene Names: KEL
# Unique Identifier: 6761344|None_847, Gene Names: CAT
# Unique Identifier: 3496430|None_5265, Gene Names: ALPHA 1-AT, ALPHA-1-ANTITRYPSIN
# Unique Identifier: 3496430|None_2, Gene Names: ALPHA 2-MACROGLOBULIN
# Unique Identifier: 3496430|None_2244, Gene Names: FIBRINOGEN
# Unique Identifier: 2395512|None_1476, Gene Names: PME
# Unique Identifier: 1695101|None_2670, Gene Names: GFAP, GLIAL FIBRILLARY ACIDIC PROTEIN
# Unique Identifier: 1695101|None_7431, Gene Names: VIMENTIN
# Unique Identifier: 1695101|None_2335, Gene Names: FIBRONECTIN
# Unique Identifier: 28967635|None_8842, Gene Names: CD133
# Unique Identifier: 28339700|None_3417, Gene Names: IDH
# Unique Identifier: 28339700|None_7015, Gene Names: TERT
# Unique Identifier: 28339700|None_673, Gene Names: BRAF
# Unique Identifier: 28339700|None_3020, Gene Names: H3F3A
# Unique Identifier: 24328865|None_673, Gene Names: BRAF
# Unique Identifier: 24328865|None_3417, Gene Names: IDH1
# Unique Identifier: 12724228|None_3596, Gene Names: IL-13, INTERLEUKIN 13
# Unique Identifier: 12724228|None_3598, Gene Names: IL-13RALPHA2
# Unique Identifier: 12724228|None_2277, Gene Names: VEGF-D, VASCULAR ENDOTHELIAL GROWTH FACTOR-D
# Unique Identifier: 12724228|None_3727, Gene Names: AP-1, ACTIVATING PROTEIN-1
# Unique Identifier: 8393842|None_4255, Gene Names: MGMT, O6-METHYLGUANINE-DNA METHYLTRANSFERASE
# Unique Identifier: 3729448|None_13982, Gene Names: ESTROGEN RECEPTOR
# Unique Identifier: 2080375|None_84539, Gene Names: SLT
# Unique Identifier: 1583854|None_4580, Gene Names: MTX
# Unique Identifier: 26948345|None_3417, Gene Names: IDH
# Unique Identifier: 26948345|None_7157, Gene Names: TP53
# Unique Identifier: 25382612|None_57670, Gene Names: KIAA1549
# Unique Identifier: 25382612|None_673, Gene Names: BRAF
# Unique Identifier: 23037605|None_1956, Gene Names: EGFR
# Unique Identifier: 23037605|None_7157, Gene Names: TP53
# Unique Identifier: 19357959|None_768, Gene Names: CARBONIC ANHYDRASE IX
# Unique Identifier: 19357959|None_7422, Gene Names: VASCULAR ENDOTHELIAL GROWTH FACTOR
# Unique Identifier: 15612603|None_84366, Gene Names: PRACTICE
# Unique Identifier: 10667228|None_4313;4318;4321, Gene Names: MMP, MMPS
# Unique Identifier: 10667228|None_4313, Gene Names: MMP-2
# Unique Identifier: 10667228|None_4318, Gene Names: MMP-9
# Unique Identifier: 10667228|None_4321, Gene Names: MMP-12
# Unique Identifier: 10667228|None_7076, Gene Names: TIMP, TIMP-1
# Unique Identifier: 10667228|None_7077, Gene Names: TIMP-2
# Unique Identifier: 9482679|None_7422, Gene Names: VEGF
# Unique Identifier: 6303729|None_2006, Gene Names: ELASTIN
# Unique Identifier: 29687323|None_9306, Gene Names: CIS-4
# Unique Identifier: 22520479|None_79811, Gene Names: MET
# Unique Identifier: 20536289|None_361, Gene Names: AQP-4, AQUAPORIN-4
# Unique Identifier: 16551993|None_4137, Gene Names: TAU, TAURINE
# Unique Identifier: 9407934|None_7157, Gene Names: TP53
# Unique Identifier: 9407934|None_1956, Gene Names: EGFR
# Unique Identifier: 1743696|None_2670, Gene Names: GLIAL FIBRILLARY ACIDIC PROTEIN
# Unique Identifier: 1456739|None_5973, Gene Names: AGE
# Unique Identifier: 189021|None_5443, Gene Names: ACTH
# Unique Identifier: 31162240|None_10927, Gene Names: SPIN
# Unique Identifier: 28748347|None_2475, Gene Names: MAMMALIAN TARGET OF RAPAMYCIN
# Unique Identifier: 28453743|None_54880, Gene Names: BCOR
# Unique Identifier: 28453743|None_5894, Gene Names: RAF1
# Unique Identifier: 28453743|None_673, Gene Names: BRAF
# Unique Identifier: 28453743|None_171023, Gene Names: ASXL1
# Unique Identifier: 28453743|None_5604, Gene Names: MAP2K1
# Unique Identifier: 22294272|None_1956, Gene Names: EGFR, EPIDERMAL GROWTH FACTOR RECEPTOR
# Unique Identifier: 22294272|None_5159, Gene Names: PDGFR, PLATELET DERIVED GROWTH FACTOR RECEPTOR
# Unique Identifier: 22294272|None_7422, Gene Names: VEGF, VASCULAR ENDOTHELIAL GROWTH FACTOR
# Unique Identifier: 22294272|None_207, Gene Names: AKT
# Unique Identifier: 22294272|None_2475, Gene Names: MTOR
# Unique Identifier: 21129060|None_1956, Gene Names: EGFR, EPIDERMAL GROWTH FACTOR RECEPTOR
# Unique Identifier: 21129060|None_673, Gene Names: BRAF
# Unique Identifier: 18521796|None_18591, Gene Names: PDGF-B
# Unique Identifier: 2667588|None_7276, Gene Names: TTR, TRANSTHYRETIN
# Unique Identifier: 2274129|None_5973, Gene Names: AGE
# Unique Identifier: 17244552|None_8842, Gene Names: CD133
# Unique Identifier: 10928105|None_920, Gene Names: CD4
# Unique Identifier: 10928105|None_5788, Gene Names: LCA, LEUKOCYTE COMMON ANTIGEN
# Unique Identifier: 10896208|None_4313, Gene Names: MMP-2, 72 KDA TYPE IV COLLAGENASE, MATRIX METALLOPROTEINASE 2
# Unique Identifier: 10049993|None_2688, Gene Names: GROWTH HORMONE
# Unique Identifier: 9804370|None_7157, Gene Names: TP53
# Unique Identifier: 8657489|None_5973, Gene Names: AGE
# Unique Identifier: 7538161|None_5328, Gene Names: UPA, UROKINASE TYPE PLASMINOGEN ACTIVATOR
# Unique Identifier: 7538161|None_5054, Gene Names: PAI-1, PLASMINOGEN ACTIVATOR INHIBITOR-1
# Unique Identifier: 7538161|None_5327, Gene Names: TPA, TISSUE-TYPE PLASMINOGEN ACTIVATOR
# Unique Identifier: 2750486|None_112476, Gene Names: PKC, PROTEIN KINASE C
# Unique Identifier: 34092558|None_3417, Gene Names: IDH1
# Unique Identifier: 34092558|None_673, Gene Names: BRAF
# Unique Identifier: 34092558|None_7015, Gene Names: TERT
# Unique Identifier: 31123752|None_348, Gene Names: APOE
# Unique Identifier: 31123752|None_1312, Gene Names: COMT
# Unique Identifier: 31123752|None_627, Gene Names: BDNF
# Unique Identifier: 31123752|None_5150, Gene Names: PDE7A
# Unique Identifier: 31123752|None_3569, Gene Names: IL-6
# Unique Identifier: 31123752|None_1812, Gene Names: DRD1
# Unique Identifier: 31123752|None_6925, Gene Names: TCF4
# Unique Identifier: 31123752|None_5888, Gene Names: RAD51
# Unique Identifier: 31123752|None_27244, Gene Names: SESN1
# Unique Identifier: 31123752|None_2950, Gene Names: GSTP1
# Unique Identifier: 25976260|None_2670, Gene Names: GFAP, GLIAL FIBRILLARY ACIDIC PROTEIN
# Unique Identifier: 25976260|None_9118, Gene Names: ALPHA-INTERNEXIN
# Unique Identifier: 25976260|None_5630, Gene Names: PERIPHERIN
# Unique Identifier: 25976260|None_7431, Gene Names: VIMENTIN
# Unique Identifier: 25976260|None_10763, Gene Names: NESTIN
# Unique Identifier: 25976260|None_23336, Gene Names: SYNEMIN
# Unique Identifier: 7692323|None_3558, Gene Names: IL-2, INTERLEUKIN-2
# Unique Identifier: 6086852|None_22978, Gene Names: GMP
# Unique Identifier: 2997416|None_2670, Gene Names: GFAP, GLIAL FIBRILLARY ACIDIC PROTEIN
# Unique Identifier: 2997416|None_6271, Gene Names: S-100
# Unique Identifier: 1020546|None_213, Gene Names: HSA
# Unique Identifier: 522954|None_23584, Gene Names: CT-H
# Unique Identifier: 34509751|None_6598, Gene Names: SMARCB1
# Unique Identifier: 26459515|None_4763, Gene Names: NEUROFIBROMATOSIS TYPE 1
# Unique Identifier: 18374501|None_351, Gene Names: A, ALPHA/BETA
# Unique Identifier: 17447046|None_10178, Gene Names: TNM
# Unique Identifier: 15485315|None_100616101, Gene Names: PROTEINASE
# Unique Identifier: 12357552|None_57534, Gene Names: MIB.1
# Unique Identifier: 12168843|None_2064, Gene Names: NEU, HER-2, HER-2/NEU
# Unique Identifier: 7523634|None_7422, Gene Names: VPF, VASCULAR PERMEABILITY FACTOR
# Unique Identifier: 31853548|None_2521, Gene Names: FUS
# Unique Identifier: 30993541|None_857, Gene Names: CAV-1, CAVEOLIN-1
# Unique Identifier: 26376741|None_3417, Gene Names: IDH1
# Unique Identifier: 26376741|None_3598, Gene Names: IL-13RALPHA2
# Unique Identifier: 26376741|None_2064, Gene Names: HER2
# Unique Identifier: 26376741|None_7039, Gene Names: TGFBETA
# Unique Identifier: 22632886|None_7040, Gene Names: TGF-BETA1, TRANSFORMING GROWTH FACTOR (TGF) BETA1
# Unique Identifier: 21768887|None_4139, Gene Names: MARK
# Unique Identifier: 21768887|None_4140, Gene Names: MARK 3
# Unique Identifier: 19409045|None_9173, Gene Names: T1/B1
# Unique Identifier: 19409045|None_292;7905, Gene Names: T2/B2
# Unique Identifier: 17987960|None_5728, Gene Names: PTEN, 10Q/PHOSPHATE AND TENSIN HOMOLOG
# Unique Identifier: 17939769|None_4255, Gene Names: METHYLGUANINE-DNA METHYLTRANSFERASE
# Unique Identifier: 35768633|None_1956, Gene Names: EGFR
# Unique Identifier: 35768633|None_3417, Gene Names: IDH
# Unique Identifier: 35768633|None_4255, Gene Names: MGMT
# Unique Identifier: 34623468|None_6469, Gene Names: SHH
# Unique Identifier: 34092569|None_3417, Gene Names: IDH
# Unique Identifier: 34054040|None_5443, Gene Names: ADRENOCORTICOTROPIC HORMONE
# Unique Identifier: 28691414|None_7422, Gene Names: VEGF, VASCULAR ENDOTHELIAL GROWTH FACTOR
# Unique Identifier: 28691414|None_2247, Gene Names: BFGF, BASIC FIBROBLAST GROWTH FACTOR
# Unique Identifier: 22821367|None_8279783, Gene Names: PROLIFERATING CELL NUCLEAR ANTIGEN
# Unique Identifier: 17636068|None_5973, Gene Names: AGE
# Unique Identifier: 1882640|None_6271, Gene Names: S-100 BETA, S-100 ALPHA
# Unique Identifier: 22350668|None_10763, Gene Names: NESTIN
# Unique Identifier: 19430698|None_207, Gene Names: AKT
# Unique Identifier: 19430698|None_2475, Gene Names: MTOR
# Unique Identifier: 19430698|None_5591, Gene Names: DNA-PK
# Unique Identifier: 19159078|None_406991, Gene Names: MIR-21, MIRNA-21
# Unique Identifier: 19159078|None_407006, Gene Names: MIRNA-221
# Unique Identifier: 15328205|None_14069, Gene Names: FACTOR VIII
# Unique Identifier: 15328205|None_12367, Gene Names: CASPASE-3
# Unique Identifier: 15328205|None_11545, Gene Names: POLY(ADP-RIBOSE) POLYMERASE
# Unique Identifier: 15328205|None_16000, Gene Names: INSULIN-LIKE GROWTH FACTOR I
# Unique Identifier: 9205070|None_2272, Gene Names: FHIT
# Unique Identifier: 8008171|None_1956, Gene Names: EPIDERMAL GROWTH FACTOR RECEPTOR
# Unique Identifier: 8008171|None_1950, Gene Names: EPIDERMAL GROWTH FACTOR
# Unique Identifier: 8008171|None_7124, Gene Names: TRANSFORMING GROWTH FACTOR-ALPHA
# Unique Identifier: 8008171|None_7422, Gene Names: VASCULAR ENDOTHELIAL GROWTH FACTOR
# Unique Identifier: 7509461|None_4155, Gene Names: MBP, MYELIN BASIC PROTEIN
# Unique Identifier: 7509461|None_3054, Gene Names: VP-16
# Unique Identifier: 3812039|None_2670, Gene Names: GFAP, GLIAL FIBRILLARY ACIDIC PROTEIN
# Unique Identifier: 29464548|None_3952, Gene Names: LEPTIN
# Unique Identifier: 26026669|None_3417, Gene Names: IDH
# Unique Identifier: 26026669|None_673, Gene Names: BRAF
# Unique Identifier: 26026669|None_4255, Gene Names: MGMT
# Unique Identifier: 25866320|None_113451, Gene Names: ADC
# Unique Identifier: 25468226|None_3417, Gene Names: IDH1, ISOCITRATE DEHYDROGENASE 1
# Unique Identifier: 23909061|None_3417, Gene Names: IDH, ISOCITRATE DEHYDROGENASE
# Unique Identifier: 20175962|None_7422, Gene Names: VEGF, VASCULAR ENDOTHELIAL GROWTH FACTOR
# Unique Identifier: 20175962|None_1956, Gene Names: EGFR, EPIDERMAL GROWTH FACTOR RECEPTOR
# Unique Identifier: 20175962|None_7039, Gene Names: TGFBETA
# Unique Identifier: 20175962|None_7040, Gene Names: TGFBETA1
# Unique Identifier: 20175962|None_7042, Gene Names: TGFBETA2
# Unique Identifier: 20175962|None_7043, Gene Names: TGFBETA3
# Unique Identifier: 12705813|None_5775, Gene Names: MEG
# Unique Identifier: 3572470|None_3054, Gene Names: VP-16
# Unique Identifier: 29322427|None_29126, Gene Names: PDL1
# Unique Identifier: 12241105|None_373156, Gene Names: GST, GLUTATHIONE S-TRANSFERASE
# Unique Identifier: 12241105|None_2944, Gene Names: GSTM1
# Unique Identifier: 12241105|None_2952, Gene Names: GSTT1
# Unique Identifier: 12241105|None_2950, Gene Names: GSTP1
# Unique Identifier: 12140754|None_5599, Gene Names: JNK
# Unique Identifier: 12140754|None_5594, Gene Names: ERK
# Unique Identifier: 12140754|None_1956, Gene Names: EGF RECEPTOR
# Unique Identifier: 6401866|None_3456, Gene Names: FIBROBLAST INTERFERON
# Unique Identifier: 2992677|None_6714, Gene Names: SRC
# Unique Identifier: 2992677|None_2673, Gene Names: GFA
# Unique Identifier: 1789685|None_3848, Gene Names: K1, K2
# Unique Identifier: 1710320|None_362686, Gene Names: RCBF
# Unique Identifier: 1407435|None_117189, Gene Names: GD3
# Unique Identifier: 19182242|None_4255, Gene Names: MGMT
# Unique Identifier: 18648328|None_4852, Gene Names: NPY, NEUROPEPTIDE Y
# Unique Identifier: 16030117|None_373156, Gene Names: GST, GLUTATHIONE S-TRANSFERASES
# Unique Identifier: 16030117|None_2944, Gene Names: GSTM1
# Unique Identifier: 16030117|None_2952, Gene Names: GSTT1
# Unique Identifier: 16030117|None_2950, Gene Names: GSTP1
# Unique Identifier: 14727688|None_5663, Gene Names: PS1
# Unique Identifier: 9818841|None_7157, Gene Names: P53
# Unique Identifier: 9818841|None_1029, Gene Names: P16
# Unique Identifier: 9818841|None_5728, Gene Names: PTEN, MMAC1
# Unique Identifier: 9503511|None_84366, Gene Names: PRACTICE
# Unique Identifier: 9252700|None_3315, Gene Names: HSP-27, HEAT SHOCK PROTEIN-27
# Unique Identifier: 6577813|None_9344, Gene Names: PSK
# Unique Identifier: 32377829|None_673, Gene Names: BRAF
# Unique Identifier: 32377829|None_1029, Gene Names: CDKN2A
# Unique Identifier: 32377829|None_3020, Gene Names: H3F3A
# Unique Identifier: 22528793|None_387, Gene Names: RHOA
# Unique Identifier: 22528793|None_388, Gene Names: RHOB
# Unique Identifier: 22528793|None_5879, Gene Names: RAC1
# Unique Identifier: 22528793|None_8976, Gene Names: N-WASP
# Unique Identifier: 22528793|None_5728, Gene Names: PTEN
# Unique Identifier: 19804368|None_2925, Gene Names: GRPR, GASTRIN-RELEASING PEPTIDE RECEPTOR
# Unique Identifier: 18000980|None_649, Gene Names: BONE MORPHOGENETIC PROTEIN
# Unique Identifier: 17721931|None_4763, Gene Names: NF1, NEUROFIBROMATOSIS 1
# Unique Identifier: 17721931|None_4771, Gene Names: NF2
# Unique Identifier: 15236125|None_3048, Gene Names: METHEMOGLOBIN
# Unique Identifier: 15015671|None_57534, Gene Names: MIB-1
# Unique Identifier: 12722674|None_7248, Gene Names: TUMOR SUPPRESSOR
# Unique Identifier: 34613491|None_673, Gene Names: BRAF
# Unique Identifier: 34303558|None_673, Gene Names: BRAF
# Unique Identifier: 34303558|None_2260, Gene Names: FGFR1
# Unique Identifier: 34303558|None_3417;3418, Gene Names: IDH1/2
# Unique Identifier: 34303558|None_5609, Gene Names: MEK
# Unique Identifier: 29478614|None_2475, Gene Names: MECHANISTIC TARGET OF RAPAMYCIN
# Unique Identifier: 29478614|None_6469, Gene Names: SONIC HEDGEHOG
# Unique Identifier: 22702213|None_2690, Gene Names: GHR, GH RECEPTOR, GROWTH HORMONE RECEPTOR
# Unique Identifier: 22702213|None_2688, Gene Names: GROWTH HORMONE
# Unique Identifier: 22702213|None_8836, Gene Names: GH
# Unique Identifier: 8621248|None_1030, Gene Names: P15
# Unique Identifier: 8621248|None_1029, Gene Names: P16
# Unique Identifier: 8621248|None_1019, Gene Names: CDK4
# Unique Identifier: 8621248|None_595, Gene Names: CYCLIN D1
# Unique Identifier: 7007589|None_8658, Gene Names: PART 5
# Unique Identifier: 1967302|None_5422, Gene Names: DNA POLYMERASE ALPHA, DEOXYRIBONUCLEIC ACID (DNA) POLYMERASE ALPHA
# Unique Identifier: 1967302|None_5111, Gene Names: PCNA/CYCLIN, PROLIFERATING CELL NUCLEAR ANTIGEN
# Unique Identifier: 37488051|None_4513, Gene Names: CYCLOOXYGENASE (COX)-2
# Unique Identifier: 37488051|None_240, Gene Names: LOX, 5-LIPOXYGENASE
# Unique Identifier: 10023002|None_2272, Gene Names: FHIT
# Unique Identifier: 8699239|None_79811, Gene Names: MET
# Unique Identifier: 8699239|None_3848;58164, Gene Names: K1, K2, K3
# Unique Identifier: 7443176|None_3054, Gene Names: VP-16
# Unique Identifier: 4005831|None_847, Gene Names: CATALASE
# Unique Identifier: 3488031|None_3558, Gene Names: IL-2, INTERLEUKIN 2
# Unique Identifier: 3488031|None_403989, Gene Names: IL-2, INTERLEUKIN-2
# Unique Identifier: 3488031|None_116562, Gene Names: RIL-2
# Unique Identifier: 2396538|None_448843, Gene Names: ALBUMIN
# Unique Identifier: 2352372|None_23657, Gene Names: X-CT
# Unique Identifier: 18831033|None_4051, Gene Names: CYP, CYTOCHROME P450
# Unique Identifier: 17825381|None_796, Gene Names: CALCITONIN
# Unique Identifier: 17262828|None_51053, Gene Names: GEMININ
# Unique Identifier: 17262828|None_81620, Gene Names: CDT1
# Unique Identifier: 16330944|None_3769, Gene Names: KIR7.1
# Unique Identifier: 16330944|None_6781, Gene Names: STANNIOCALCIN-1
# Unique Identifier: 16330944|None_7276, Gene Names: TRANSTHYRETIN
# Unique Identifier: 16330944|None_2153, Gene Names: COAGULATION FACTOR V
# Unique Identifier: 16330944|None_2878, Gene Names: GLUTATHIONE PEROXIDASE 3
# Unique Identifier: 16330944|None_2192, Gene Names: FIBULIN-1
# Unique Identifier: 16330944|None_5357, Gene Names: PLASTIN-1
# Unique Identifier: 16330944|None_3875, Gene Names: CYTOKERATIN 18
# Unique Identifier: 15140402|None_113451, Gene Names: ADC
# Unique Identifier: 12564764|None_7431, Gene Names: VIMENTIN
# Unique Identifier: 12564764|None_1674, Gene Names: DESMIN
# Unique Identifier: 12564764|None_2670, Gene Names: GFAP
# Unique Identifier: 12564764|None_6855, Gene Names: SYNAPTOPHYSIN
# Unique Identifier: 11064393|None_3559, Gene Names: IL-2RALPHA, INTERLEUKIN-2 RECEPTOR ALPHA
# Unique Identifier: 11064393|None_3558, Gene Names: IL-2
# Unique Identifier: 10885653|None_2670, Gene Names: GFAP
# Unique Identifier: 10885653|None_7431, Gene Names: VIMENTIN
# Unique Identifier: 33270865|None_139628, Gene Names: FOXR2
# Unique Identifier: 33270865|None_6855, Gene Names: SYNAPTOPHYSIN
# Unique Identifier: 33270865|None_4133, Gene Names: MAP2
# Unique Identifier: 33270865|None_10215, Gene Names: OLIG2
# Unique Identifier: 26328970|None_2180, Gene Names: LACS
# Unique Identifier: 23775285|None_4255, Gene Names: MGMT
# Unique Identifier: 22138445|None_2729, Gene Names: GCL, GLUTAMATE CYSTEINE LIGASE
# Unique Identifier: 22138445|None_2937, Gene Names: GS, GLUTATHIONE SYNTHETASE
# Unique Identifier: 22138445|None_2936, Gene Names: GR, GLUTATHIONE REDUCTASE
# Unique Identifier: 22138445|None_4363, Gene Names: GS-X
# Unique Identifier: 21577129|None_6046, Gene Names: NAT
# Unique Identifier: 20425041|None_57534, Gene Names: MIB-1
# Unique Identifier: 20336349|None_3717, Gene Names: JAK, JAK-2, JANUS KINASE 2
# Unique Identifier: 20336349|None_6776, Gene Names: STAT-5
# Unique Identifier: 20336349|None_2057, Gene Names: EPOR, ERYTHROPOIETIN RECEPTOR
# Unique Identifier: 20336349|None_2056, Gene Names: EPO, ERYTHROPOIETIN
# Unique Identifier: 1407341|None_373156, Gene Names: GST, GLUTATHIONE S-TRANSFERASE
# Unique Identifier: 1407341|None_2950, Gene Names: GST-P
# Unique Identifier: 33239357|None_4904, Gene Names: YB-1, Y-BOX BINDING PROTEIN 1, Y-BOX BINDING PROTEIN-1
# Unique Identifier: 30629215|None_1956, Gene Names: EPIDERMAL GROWTH FACTOR RECEPTOR
# Unique Identifier: 30629215|None_673, Gene Names: BRAF
# Unique Identifier: 30629215|None_2064, Gene Names: HER2
# Unique Identifier: 30629215|None_7422, Gene Names: VASCULAR ENDOTHELIAL GROWTH FACTOR
# Unique Identifier: 27526097|None_6469, Gene Names: SHH, SONIC HEDGEHOG
# Unique Identifier: 3020865|None_24387, Gene Names: GLIAL FIBRILLARY ACIDIC PROTEIN
# Unique Identifier: 3001488|None_2670, Gene Names: GFAP
# Unique Identifier: 2409734|None_480495, Gene Names: GFAP, GLIAL FIBRILLARY ACIDIC PROTEIN
# Unique Identifier: 2409734|None_476160, Gene Names: MBP, MYELIN BASIC PROTEIN
# Unique Identifier: 2409734|None_611884, Gene Names: MAG, MYELIN-ASSOCIATED GLYCOPROTEIN
# Unique Identifier: 1992913|None_1950, Gene Names: EGF, EPIDERMAL GROWTH FACTOR
# Unique Identifier: 1450489|None_3558, Gene Names: IL-2, INTERLEUKIN-2
# Unique Identifier: 1450489|None_7124, Gene Names: TNF-ALPHA, TUMOR NECROSIS FACTOR-ALPHA
# Unique Identifier: 1450489|None_116562, Gene Names: RIL-2
# Unique Identifier: 1450489|None_24835, Gene Names: TNF-ALPHA
# Unique Identifier: 11136998|None_6696, Gene Names: OSTEOPONTIN
# Unique Identifier: 11126911|None_780, Gene Names: DDR1, DISCOIDIN DOMAIN RECEPTOR-1
# Unique Identifier: 11126911|None_12305, Gene Names: DDR1
# Unique Identifier: 11055797|None_4613, Gene Names: N-MYC
# Unique Identifier: 11055797|None_4609, Gene Names: C-MYC
# Unique Identifier: 10746685|None_10608, Gene Names: MAD-4
# Unique Identifier: 8621289|None_9622;51155, Gene Names: ARMS 1, 2 AND 3
# Unique Identifier: 8287355|None_183, Gene Names: ANGIOTENSIN II
# Unique Identifier: 8113867|None_3558, Gene Names: IL-2, INTERLEUKIN-2
# Unique Identifier: 8113867|None_3560, Gene Names: IL-2 RECEPTOR
# Unique Identifier: 8113867|None_116562, Gene Names: IL-2
# Unique Identifier: 8113867|None_16183, Gene Names: IL-2
# Unique Identifier: 3976624|None_2688, Gene Names: GROWTH HORMONE
# Unique Identifier: 24453059|None_55511, Gene Names: SAGE
# Unique Identifier: 23211553|None_177, Gene Names: RAGE
# Unique Identifier: 21082387|None_24186, Gene Names: ALBUMIN
# Unique Identifier: 19369008|None_8842, Gene Names: CD133
# Unique Identifier: 18412241|None_24224, Gene Names: BCL-2
# Unique Identifier: 18412241|None_24248, Gene Names: CATALASE
# Unique Identifier: 18412241|None_24786, Gene Names: SOD-1
# Unique Identifier: 18412241|None_24787, Gene Names: SOD-2
# Unique Identifier: 15249715|None_7422, Gene Names: VASCULAR ENDOTHELIAL GROWTH FACTOR
# Unique Identifier: 15249715|None_5743, Gene Names: CYCLOOXYGENASE-2
# Unique Identifier: 12197239|None_7018, Gene Names: TRANSFERRIN
# Unique Identifier: 12092682|None_2688, Gene Names: GROWTH HORMONE
# Unique Identifier: 34433223|None_261726, Gene Names: TIP
# Unique Identifier: 32725495|None_653108, Gene Names: CAR
# Unique Identifier: 30528355|None_7248;7249, Gene Names: TSC, TSC1/2
# Unique Identifier: 28993028|None_3417, Gene Names: IDH, IDH1
# Unique Identifier: 28993028|None_546, Gene Names: ATRX
# Unique Identifier: 27935156|None_842, Gene Names: CASP9, CASPASE-9
# Unique Identifier: 27935156|None_3417, Gene Names: IDH1
# Unique Identifier: 27935156|None_7157, Gene Names: TP53
# Unique Identifier: 26002233|None_103937, Gene Names: NANOLUC
# Unique Identifier: 16132504|None_3815, Gene Names: C-KIT, CD117
# Unique Identifier: 1690593|None_24387, Gene Names: GLIAL FIBRILLARY ACIDIC PROTEIN
# Unique Identifier: 35641277|None_5286, Gene Names: PI3KC2BETA
# Unique Identifier: 11358858|None_7157, Gene Names: P53
# Unique Identifier: 9703825|None_9788, Gene Names: MIM
# Unique Identifier: 9447625|None_7157, Gene Names: P53
# Unique Identifier: 9210058|None_7124, Gene Names: TUMOR NECROSIS FACTOR-ALPHA
# Unique Identifier: 8005794|None_1728, Gene Names: DT-DIAPHORASE
# Unique Identifier: 8005794|None_5447, Gene Names: NADPH CYTOCHROME P-450 REDUCTASE
# Unique Identifier: 7900450|None_30818, Gene Names: DREAM
# Unique Identifier: 7808603|None_8011, Gene Names: MRS
# Unique Identifier: 21955925|None_3417, Gene Names: IDH, IDH1, ISOCITRATE DEHYDROGENASE 1
# Unique Identifier: 21955925|None_7157, Gene Names: TP53
# Unique Identifier: 21955925|None_4255, Gene Names: MGMT
# Unique Identifier: 21416251|None_57534, Gene Names: MIB-1
# Unique Identifier: 21416251|None_7345, Gene Names: UCHL-1
# Unique Identifier: 21416251|None_2670, Gene Names: GFAP
# Unique Identifier: 21416251|None_174, Gene Names: AFP
# Unique Identifier: 21416251|None_9373, Gene Names: PLAP
# Unique Identifier: 21165751|None_80835, Gene Names: TR 1
# Unique Identifier: 20192643|None_4609, Gene Names: C-MYC
# Unique Identifier: 19076777|None_11628, Gene Names: AID
# Unique Identifier: 16266053|None_6513, Gene Names: GLUT-1
# Unique Identifier: 16266053|None_283871, Gene Names: PGP
# Unique Identifier: 11831641|None_5243, Gene Names: MDR1, P-GP, P-GLYCOPROTEIN
# Unique Identifier: 11780459|None_404663, Gene Names: TAG, TUMOR ANTIGEN
# Unique Identifier: 11780459|None_5925, Gene Names: PRB
# Unique Identifier: 29071695|None_3417, Gene Names: IDH
# Unique Identifier: 28431179|None_4763, Gene Names: NEUROFIBROMATOSIS TYPE 1
# Unique Identifier: 28431179|None_5728, Gene Names: PTEN
# Unique Identifier: 28431179|None_406991, Gene Names: MIR-21
# Unique Identifier: 28431179|None_406900, Gene Names: MIR-106B
# Unique Identifier: 28431179|None_407015, Gene Names: MIR-26A
# Unique Identifier: 28431179|None_5979, Gene Names: RECEPTOR TYROSINE KINASE
# Unique Identifier: 28431179|None_407002, Gene Names: MIR-219
# Unique Identifier: 28431179|None_442906, Gene Names: MIR-338
# Unique Identifier: 27834580|None_22914, Gene Names: NKG2D
# Unique Identifier: 25529918|None_2744, Gene Names: KGA, GLUTAMINASE
# Unique Identifier: 25529918|None_27165, Gene Names: GLS2
# Unique Identifier: 25529918|None_1, Gene Names: GAB
# Unique Identifier: 25529918|None_4609, Gene Names: C-MYC
# Unique Identifier: 25017328|None_1437, Gene Names: CSF
# Unique Identifier: 24481542|None_7157, Gene Names: TP53
# Unique Identifier: 23789953|None_9429, Gene Names: BCRP, BREAST CANCER RESISTANCE PROTEIN
# Unique Identifier: 23550771|None_3091, Gene Names: HIF-1, HYPOXIA-INDUCIBLE FACTOR-1
# Unique Identifier: 34591198|None_7442, Gene Names: TRPV1
# Unique Identifier: 34591198|None_8989, Gene Names: TRPA1
# Unique Identifier: 34591198|None_3297, Gene Names: HSF1, HEAT-SHOCK FACTOR 1
# Unique Identifier: 29931654|None_3417;3418, Gene Names: IDH1/2
# Unique Identifier: 29931654|None_3020, Gene Names: H3F3A
# Unique Identifier: 29931654|None_673, Gene Names: BRAF
# Unique Identifier: 29931654|None_1029, Gene Names: CDKN2A
# Unique Identifier: 29931654|None_7015, Gene Names: TERT
# Unique Identifier: 6097099|None_2670, Gene Names: GLIAL FIBRILLARY ACIDIC PROTEIN
# Unique Identifier: 2679824|None_4609, Gene Names: C-MYC
# Unique Identifier: 2527972|None_3458, Gene Names: INTERFERON-GAMMA
# Unique Identifier: 2113427|None_2670, Gene Names: GFAP
# Unique Identifier: 2113427|None_2026, Gene Names: NSE
# Unique Identifier: 2113427|None_7431, Gene Names: VIMENTIN
# Unique Identifier: 2113427|None_6855, Gene Names: SYNAPTOPHYSIN
# Unique Identifier: 1423198|None_2247, Gene Names: BFGF, BASIC FIBROBLAST GROWTH FACTOR
# Unique Identifier: 1374918|None_1351, Gene Names: VIII
# Unique Identifier: 1374918|None_55511, Gene Names: SAGE
# Unique Identifier: 18405078|None_117189, Gene Names: GD3
# Unique Identifier: 17912447|None_2057, Gene Names: EPOR, ERYTHROPOIETIN RECEPTOR
# Unique Identifier: 17912447|None_2056, Gene Names: EPO, ERYTHROPOIETIN
# Unique Identifier: 17912447|None_207, Gene Names: AKT
# Unique Identifier: 17912447|None_5594, Gene Names: ERK
# Unique Identifier: 17912447|None_3725, Gene Names: C-JUN
# Unique Identifier: 17912447|None_5599, Gene Names: JNK
# Unique Identifier: 17912447|None_596, Gene Names: BCL-2
# Unique Identifier: 17912447|None_598, Gene Names: BCL-XL
# Unique Identifier: 10581847|None_2670, Gene Names: GFAP
# Unique Identifier: 10581847|None_7431, Gene Names: VIMENTIN
# Unique Identifier: 10581847|None_7157, Gene Names: P53
# Unique Identifier: 9427964|None_581, Gene Names: BAX
# Unique Identifier: 9427964|None_596, Gene Names: BCL-2
# Unique Identifier: 9293789|None_57534, Gene Names: MIB 1
# Unique Identifier: 8974619|None_3383, Gene Names: ICAM-1, INTERCELLULAR ADHESION MOLECULE-1
# Unique Identifier: 8898288|None_7124, Gene Names: TNF
# Unique Identifier: 8898288|None_24835, Gene Names: TNF
# Unique Identifier: 8898288|None_25464, Gene Names: ICAM-1, INTERCELLULAR ADHESION MOLECULE-1
# Unique Identifier: 8725198|None_177, Gene Names: RAGE
# Unique Identifier: 27029475|None_10882, Gene Names: CANCER-RELATED FATIGUE
# Unique Identifier: 24944262|None_348, Gene Names: APOE
# Unique Identifier: 24599439|None_2152, Gene Names: TISSUE FACTOR
# Unique Identifier: 24599439|None_2147, Gene Names: THROMBIN
# Unique Identifier: 24599439|None_2159, Gene Names: FACTOR XA
# Unique Identifier: 23052697|None_4255, Gene Names: O(6)-METHYLGUANINE-DNA METHYLTRANSFERASE
# Unique Identifier: 23052697|None_3417, Gene Names: IDH1
# Unique Identifier: 23052697|None_673, Gene Names: BRAF
# Unique Identifier: 23052697|None_1956, Gene Names: EGFR
# Unique Identifier: 21999731|None_133, Gene Names: ADRENOMEDULLIN
# Unique Identifier: 18390424|None_847, Gene Names: CATALASE
# Unique Identifier: 17250431|None_28, Gene Names: ABO, ABO BLOOD GROUP
# Unique Identifier: 10964598|None_5775, Gene Names: MEG
# Unique Identifier: 35984480|None_57670, Gene Names: KIAA1549
# Unique Identifier: 35984480|None_673, Gene Names: BRAF
# Unique Identifier: 32691644|None_673, Gene Names: BRAF
# Unique Identifier: 32691644|None_57670, Gene Names: KIAA1549
# Unique Identifier: 30693642|None_5781, Gene Names: PTPN11
# Unique Identifier: 30478893|None_2956, Gene Names: MSH6
# Unique Identifier: 30478893|None_6774, Gene Names: STAT3
# Unique Identifier: 30478893|None_2475, Gene Names: MTOR
# Unique Identifier: 30478893|None_142, Gene Names: PARP-1
# Unique Identifier: 29158366|None_4591, Gene Names: MUL
# Unique Identifier: 25003486|None_7422, Gene Names: VASCULAR ENDOTHELIAL GROWTH FACTOR
# Unique Identifier: 2980514|None_6695, Gene Names: TIC1
# Unique Identifier: 2296651|None_529, Gene Names: P-31
# Unique Identifier: 7745469|None_2147, Gene Names: SERINE PROTEASE
# Unique Identifier: 7139569|None_6236, Gene Names: RAD
# Unique Identifier: 6738895|None_8836, Gene Names: GH
# Unique Identifier: 6259745|None_2673, Gene Names: GFA
# Unique Identifier: 3359443|None_4758, Gene Names: NEU
# Unique Identifier: 3259730|None_567, Gene Names: BETA 2-MICROGLOBULIN
# Unique Identifier: 2697177|None_100129528;727897;10071;56667;51705;143662;94025;140453;4162;283463;200958;394263;100507679, Gene Names: MUC 8-22
# Unique Identifier: 2442448|None_2670, Gene Names: GFAP
# Unique Identifier: 2442448|None_7431, Gene Names: VIMENTIN
# Unique Identifier: 2442448|None_2026, Gene Names: NSE, NEURON-SPECIFIC ENOLASE
# Unique Identifier: 2442448|None_1084, Gene Names: CEA, CARCINOEMBRYONIC ANTIGEN
# Unique Identifier: 2442448|None_4099, Gene Names: MYELIN-ASSOCIATED GLYCOPROTEIN
# Unique Identifier: 2442448|None_27087, Gene Names: LEU 7
# Unique Identifier: 2442448|None_6855, Gene Names: SYNAPTOPHYSIN
# Unique Identifier: 10541237|None_4233, Gene Names: CMET
# Unique Identifier: 10440107|None_213, Gene Names: ALBUMIN
# Unique Identifier: 9657495|None_6770, Gene Names: FACSTAR
# Unique Identifier: 9264362|None_3958, Gene Names: GALECTIN-3
# Unique Identifier: 9080351|None_57379, Gene Names: AID
# Unique Identifier: 8883072|None_84366, Gene Names: PRACTICE
# Unique Identifier: 8629400|None_1084, Gene Names: CEA, CARCINOEMBRYONIC ANTIGEN
# Unique Identifier: 8239906|None_3558, Gene Names: IL-2
# Unique Identifier: 8239906|None_925, Gene Names: CD8
# Unique Identifier: 8239906|None_920, Gene Names: CD4
# Unique Identifier: 18665745|None_649, Gene Names: BONE MORPHOGENETIC PROTEIN
# Unique Identifier: 18665745|None_652, Gene Names: BMP4
# Unique Identifier: 18095136|None_7422, Gene Names: VEGF
# Unique Identifier: 18095136|None_947, Gene Names: CD34
# Unique Identifier: 18095136|None_57534, Gene Names: MIB-1
# Unique Identifier: 18095136|None_361, Gene Names: AQP 4
# Unique Identifier: 17239827|None_1269, Gene Names: CB2
# Unique Identifier: 17239827|None_1268, Gene Names: CB1
# Unique Identifier: 16440698|None_28935, Gene Names: A 20
# Unique Identifier: 16244591|None_575, Gene Names: BAI1, BRAIN-SPECIFIC ANGIOGENESIS INHIBITOR 1
# Unique Identifier: 16244591|None_7422, Gene Names: VASCULAR ENDOTHELIAL GROWTH FACTOR
# Unique Identifier: 15113479|None_15978, Gene Names: INTERFERON-GAMMA
# Unique Identifier: 14977201|None_5775, Gene Names: MEG
# Unique Identifier: 12963964|None_1956, Gene Names: EPIDERMAL GROWTH FACTOR RECEPTOR
# Unique Identifier: 25899850|None_4137, Gene Names: TAU
# Unique Identifier: 24859855|None_3490, Gene Names: PSF
# Unique Identifier: 22816225|None_1509, Gene Names: CATH D, CATHEPSIN D
# ...
# Unique Identifier: 7198835|None_847, Gene Names: CAT
# Unique Identifier: 6544119|None_847, Gene Names: CAT
# Unique Identifier: 3902206|None_5617, Gene Names: PROLACTIN
# Unique Identifier: 3902206|None_2688, Gene Names: GH
# Unique Identifier: 21786247|None_8842, Gene Names: CD133
# Unique Identifier: 20814658|None_4233, Gene Names: C-MET
# Unique Identifier: 19633924|None_8312, Gene Names: AXIN, AXIN1, AXIN-1
# Unique Identifier: 19633924|None_1499, Gene Names: CTNNB1, BETA-CATENIN
# Unique Identifier: 17562554|None_6962, Gene Names: TCR
# Unique Identifier: 16475710|None_1559, Gene Names: CYP2C9
# Unique Identifier: 16475710|None_9360, Gene Names: CYP
# Unique Identifier: 16198917|None_57534, Gene Names: MIB-1
# Unique Identifier: 15897582|None_3558, Gene Names: HIL2, IL-2, HIL-2, INTERLEUKIN 2, INTERLEUKIN-2
# Unique Identifier: 15897582|None_920, Gene Names: CD4
# Unique Identifier: 15897582|None_925, Gene Names: CD8
# Unique Identifier: 12456339|None_7422, Gene Names: VEGF, VASCULAR ENDOTHELIAL GROWTH FACTOR
# Unique Identifier: 12456339|None_3091, Gene Names: HIF-1, HYPOXIA-INDUCIBLE FACTOR-1
# Unique Identifier: 12456339|None_5728, Gene Names: PTEN
# Unique Identifier: 12456339|None_7157, Gene Names: TP53
# Unique Identifier: 12456339|None_1029, Gene Names: P16, CDKN2A, P14ARF
# Unique Identifier: 12456339|None_1956, Gene Names: EGFR
# Unique Identifier: 12456339|None_5159, Gene Names: PDGFR
# Unique Identifier: 12456339|None_2247, Gene Names: BFGF, BASIC FIBROBLAST GROWTH FACTOR
# Unique Identifier: 12456339|None_7057, Gene Names: TSP-1, THROMBOSPONDIN-1
# Unique Identifier: 30681550|None_29126, Gene Names: PD-L1
# Unique Identifier: 30060998|None_5970, Gene Names: RELA
# Unique Identifier: 29930212|None_1357, Gene Names: CPA
# Unique Identifier: 27115743|None_2688, Gene Names: GROWTH HORMONE
# Unique Identifier: 25868602|None_24628, Gene Names: PDGF-B
# Unique Identifier: 24445767|None_3417, Gene Names: IDH, IDH1
# Unique Identifier: 24445767|None_7157, Gene Names: TP53
# Unique Identifier: 24445767|None_546, Gene Names: ATRX
# Unique Identifier: 24445767|None_23152, Gene Names: CIC
# Unique Identifier: 24445767|None_8880, Gene Names: FUBP1
# Unique Identifier: 24445767|None_7015, Gene Names: TERT
# Unique Identifier: 24445767|None_5156, Gene Names: PDGFRA
# Unique Identifier: 24445767|None_5728, Gene Names: PTEN
# Unique Identifier: 24445767|None_4763, Gene Names: NF1
# Unique Identifier: 24445767|None_1029;1030, Gene Names: CDKN2A/B
# Unique Identifier: 24445767|None_3020, Gene Names: H3F3A
# Unique Identifier: 24445767|None_1616, Gene Names: DAXX
# Unique Identifier: 24445767|None_673, Gene Names: BRAF
# Unique Identifier: 23918147|None_3091, Gene Names: HIF-1ALPHA
# Unique Identifier: 23412799|None_1956, Gene Names: EGFR
# Unique Identifier: 23412799|None_5728, Gene Names: PTEN
# Unique Identifier: 23412799|None_4771, Gene Names: NF2
# Unique Identifier: 37743337|None_6469, Gene Names: SHH
# Unique Identifier: 37743337|None_7157, Gene Names: TP53
# Unique Identifier: 9876472|None_25819, Gene Names: NOC
# Unique Identifier: 8876132|None_17872, Gene Names: MYD116
# Unique Identifier: 8586464|None_1956, Gene Names: EGFR
# Unique Identifier: 8586464|None_1019, Gene Names: CDK4
# Unique Identifier: 8586464|None_6302, Gene Names: SAS
# Unique Identifier: 8586464|None_4193, Gene Names: MDM2
# Unique Identifier: 8586464|None_2735, Gene Names: GLI
# Unique Identifier: 8586464|None_4609, Gene Names: MYC
# Unique Identifier: 8586464|None_4613, Gene Names: N MYC
# Unique Identifier: 8586464|None_4610, Gene Names: MYCL1
# Unique Identifier: 8586464|None_79811, Gene Names: MET
# Unique Identifier: 8586464|None_1649, Gene Names: GADD153
# Unique Identifier: 8586464|None_3815, Gene Names: KIT
# Unique Identifier: 8586464|None_4035, Gene Names: A2MR
# Unique Identifier: 8213081|None_4137, Gene Names: TAU
# Unique Identifier: 6174892|None_3439, Gene Names: IFN, IFN-ALPHA
# Unique Identifier: 2759715|None_567, Gene Names: BETA 2-MICROGLOBULIN
# Unique Identifier: 2605041|None_2026, Gene Names: NSE, NEURON SPECIFIC ENOLASE
# Unique Identifier: 16872076|None_3976, Gene Names: LIF
# Unique Identifier: 16804715|None_7157, Gene Names: P53
# Unique Identifier: 15853207|None_4255, Gene Names: MGMT, O6-METHYLGUANINE-DNA METHYLTRANSFERASE
# Unique Identifier: 15853207|None_1956, Gene Names: EGFR
# Unique Identifier: 15853207|None_3791, Gene Names: VEGFR
# Unique Identifier: 12002056|None_4287, Gene Names: JOS
# Unique Identifier: 11310919|None_7422, Gene Names: VEGF, VASCULAR ENDOTHELIAL GROWTH FACTOR
# Unique Identifier: 11310919|None_57534, Gene Names: MIB-1
# Unique Identifier: 11197866|None_3438, Gene Names: IFN-BETA
# Unique Identifier: 10401596|None_8011, Gene Names: MRS
# Unique Identifier: 10206462|None_174, Gene Names: ALPHA-FETOPROTEIN
# Unique Identifier: 28104717|None_673, Gene Names: BRAF
# Unique Identifier: 28104717|None_4602, Gene Names: MYB
# Unique Identifier: 28104717|None_9444, Gene Names: QKI
# Unique Identifier: 28104717|None_4603, Gene Names: MYBL1
# Unique Identifier: 28104717|None_2260, Gene Names: FGFR1
# Unique Identifier: 26022855|None_4255, Gene Names: MGMT, O-6-METHYLGUANINE-DNA METHYLTRANSFERASE
# Unique Identifier: 26022855|None_3075, Gene Names: ARMS 1P
# Unique Identifier: 26022855|None_1956, Gene Names: EPIDERMAL GROWTH FACTOR RECEPTOR
# Unique Identifier: 26022855|None_3417, Gene Names: IDH-1, ISOCITRATE DEHYDROGENASE 1
# Unique Identifier: 24857135|None_673, Gene Names: BRAF
# Unique Identifier: 24857135|None_57670, Gene Names: KIAA1549
# Unique Identifier: 23948902|None_2475, Gene Names: MTOR, MAMMALIAN TARGET OF RAPAMYCIN
# Unique Identifier: 19249579|None_8842, Gene Names: CD133
# Unique Identifier: 16961139|None_12504, Gene Names: CD4
# Unique Identifier: 16961139|None_20371, Gene Names: FOXP3
# Unique Identifier: 16961139|None_12477, Gene Names: CTLA-4
# Unique Identifier: 16961139|None_20343, Gene Names: CD62L
# Unique Identifier: 16389943|None_22339, Gene Names: VEGF, VASCULAR ENDOTHELIAL GROWTH FACTOR
# Unique Identifier: 15565811|None_2064, Gene Names: NEU, HER-2, HER-2/NEU
# Unique Identifier: 35830573|None_1593, Gene Names: CTX
# Unique Identifier: 35347632|None_1993, Gene Names: HUB
# Unique Identifier: 35347632|None_3071, Gene Names: NCKAP1L
# Unique Identifier: 35347632|None_9283, Gene Names: GPR37L1
# Unique Identifier: 35347632|None_1464, Gene Names: CSPG4
# Unique Identifier: 35347632|None_8497, Gene Names: PPFIA4
# Unique Identifier: 35347632|None_254778, Gene Names: C8ORF46
# Unique Identifier: 32553924|None_4613, Gene Names: MYCN
# Unique Identifier: 28499219|None_7157, Gene Names: TP53
# Unique Identifier: 10374339|None_5111, Gene Names: PROLIFERATING CELL NUCLEAR ANTIGEN
# Unique Identifier: 2141872|None_212541, Gene Names: ROD-OPSIN
# Unique Identifier: 2141872|None_13807, Gene Names: NEURON-SPECIFIC ENOLASE
# Unique Identifier: 2141872|None_14580, Gene Names: GLIAL FIBRILLARY ACIDIC PROTEIN
# Unique Identifier: 1383844|None_2670, Gene Names: GFAP, GLIAL FIBRILLARY ACIDIC PROTEIN
# Unique Identifier: 1286726|None_968, Gene Names: CD 68
# Unique Identifier: 35179708|None_3417, Gene Names: IDH
# Unique Identifier: 35179708|None_10630, Gene Names: PODOPLANIN
# Unique Identifier: 33349075|None_3569, Gene Names: IL-6, INTERLEUKIN (IL)-6
# Unique Identifier: 33349075|None_7124, Gene Names: TNF-ALPHA, TNF- ALPHA, TUMOR NECROSIS FACTOR (TNF)- ALPHA
# Unique Identifier: 33349075|None_3586, Gene Names: IL-10
# Unique Identifier: 31820275|None_24855, Gene Names: TSC, TSC2
# Unique Identifier: 20167814|None_9900, Gene Names: SV2A, SYNAPTIC VESICLE PROTEIN 2A
# Unique Identifier: 20167814|None_64051, Gene Names: SV2A
# Unique Identifier: 20118657|None_3371, Gene Names: TN-C, TENASCIN-C
# Unique Identifier: 8740561|None_7018, Gene Names: TRANSFERRIN
# Unique Identifier: 8740561|None_1950, Gene Names: EPIDERMAL GROWTH FACTOR
# Unique Identifier: 8509820|None_11224, Gene Names: L3-5
# Unique Identifier: 2681875|None_3456, Gene Names: INTERFERON-BETA
# Unique Identifier: 2681875|None_3451, Gene Names: IFN-BETA, INF-BETA
# Unique Identifier: 18768229|None_79811, Gene Names: MET
# Unique Identifier: 18647264|None_10585, Gene Names: POMT1, PROTEIN-O-MANNOSYLTRANSFERASE-1
# Unique Identifier: 17909991|None_4613, Gene Names: MYCN
# Unique Identifier: 14522905|None_8842, Gene Names: CD133
# Unique Identifier: 12567456|None_8836, Gene Names: GH
# Unique Identifier: 12403562|None_4763, Gene Names: NEUROFIBROMATOSIS 1
# Unique Identifier: 11152340|None_16410, Gene Names: ALPHA(V) INTEGRIN
# Unique Identifier: 10531783|None_175, Gene Names: AGA
# Unique Identifier: 25022336|None_26198, Gene Names: COX-2
# Unique Identifier: 25022336|None_29527, Gene Names: CYCLOOXYGENASE-2
# Unique Identifier: 25022336|None_25712, Gene Names: INTERFERON-GAMMA
# Unique Identifier: 24640739|None_7422, Gene Names: VEGF
# Unique Identifier: 24640739|None_3791, Gene Names: VEGFR2
# Unique Identifier: 24640739|None_7422;5281;3091, Gene Names: VEGF,-PIGF,-HIF1ALPHA
# Unique Identifier: 24374326|None_6863, Gene Names: SP, SUBSTANCE P
# Unique Identifier: 24374326|None_6869, Gene Names: NK1 RECEPTOR
# Unique Identifier: 23700325|None_5366, Gene Names: APR
# Unique Identifier: 17541421|None_8743, Gene Names: TRAIL, TUMOR NECROSIS FACTOR-RELATED APOPTOSIS-INDUCING LIGAND
# Unique Identifier: 17541421|None_1958, Gene Names: EGR-1
# Unique Identifier: 17541421|None_22035, Gene Names: TRAIL
# Unique Identifier: 15624764|None_57124, Gene Names: ENDOSIALIN, TUMOR ENDOTHELIAL MARKER 1
# Unique Identifier: 15624764|None_7056, Gene Names: CD141, THROMBOMODULIN
# Unique Identifier: 15624764|None_7070, Gene Names: THY-1
# Unique Identifier: 11826363|None_2670, Gene Names: GFAP
# Unique Identifier: 11563634|None_5743, Gene Names: PHS-2, PROSTAGLANDIN H SYNTHASE-2
# Unique Identifier: 11563634|None_5092, Gene Names: PHS
# Unique Identifier: 11563634|None_5742, Gene Names: PHS-1
# Unique Identifier: 34984433|None_1440, Gene Names: CSF, 3/230
# Unique Identifier: 34591980|None_8140, Gene Names: LAT1, L-TYPE AMINO ACID TRANSPORTER 1
# Unique Identifier: 34376622|None_3417, Gene Names: IDH
# Unique Identifier: 31625676|None_3630, Gene Names: INSULIN
# Unique Identifier: 30693650|None_282809, Gene Names: CORD 20
# Unique Identifier: 29028584|None_7422, Gene Names: VEGF
# Unique Identifier: 27893285|None_3417, Gene Names: IDH
# Unique Identifier: 25646527|None_2335, Gene Names: FIBRONECTIN
# Unique Identifier: 33860759|None_10215, Gene Names: OLIG-2
# Unique Identifier: 33860759|None_546, Gene Names: ATRX
# Unique Identifier: 33860759|None_3417, Gene Names: IDH
# Unique Identifier: 33860759|None_673, Gene Names: BRAF
# Unique Identifier: 33860759|None_1956, Gene Names: EGFR
# Unique Identifier: 31375903|None_6469, Gene Names: SHH, SONIC HEDGEHOG
# Unique Identifier: 18288395|None_6657, Gene Names: SOX2
# Unique Identifier: 18288395|None_4440, Gene Names: MUSASHI-1
# Unique Identifier: 18288395|None_10763, Gene Names: NESTIN
# Unique Identifier: 18288395|None_5111, Gene Names: PCNA
# Unique Identifier: 14565163|None_1440, Gene Names: G-CSF, GRANULOCYTE COLONY-STIMULATING FACTOR
# Unique Identifier: 10572718|None_57534, Gene Names: MIB-1
# Unique Identifier: 10572718|None_596, Gene Names: BCL-2
# Unique Identifier: 9100674|None_1906, Gene Names: ET-1, ENDOTHELIN-1
# Unique Identifier: 9100674|None_7040, Gene Names: TGF-BETA 1, TRANSFORMING GROWTH FACTOR BETA 1
# Unique Identifier: 2697376|None_921, Gene Names: LEU 1, LEU 1, -LEU 2 A, -LEU 3A + 3B, -LEUM 5, -HLA-DR
# Unique Identifier: 2697376|None_3560, Gene Names: IL-2 RECEPTOR
# Unique Identifier: 2697376|None_3105, Gene Names: HLA-A
# Unique Identifier: 1919678|None_1956, Gene Names: EGFR
# Unique Identifier: 25105827|None_2147, Gene Names: PROTHROMBIN
# Unique Identifier: 22104961|None_177, Gene Names: RAGE
# Unique Identifier: 17503347|None_2475, Gene Names: MTOR, MAMMALIAN TARGET OF RAPAMYCIN
# Unique Identifier: 17503347|None_4763, Gene Names: NEUROFIBROMATOSIS TYPE 1
# Unique Identifier: 11095486|None_1734, Gene Names: TYPE II IODOTHYRONINE DEIODINASE
# Unique Identifier: 10201297|None_7422, Gene Names: VEGF, VASCULAR ENDOTHELIAL GROWTH FACTOR
# Unique Identifier: 9825943|None_7157, Gene Names: P53
# Unique Identifier: 2415284|None_174, Gene Names: AFP
# Unique Identifier: 2180410|None_3458, Gene Names: IFN GAMMA
# Unique Identifier: 2180410|None_3553, Gene Names: IL 1
# Unique Identifier: 2180410|None_3562, Gene Names: IL 3
# Unique Identifier: 2180410|None_3569, Gene Names: IL 6
# Unique Identifier: 2180410|None_7042, Gene Names: TGF BETA 2
# Unique Identifier: 2180410|None_3439, Gene Names: IFN BETA 1
# Unique Identifier: 2180410|None_3558, Gene Names: IL2, IL 2
# Unique Identifier: 34427324|None_246734, Gene Names: NPCR
# Unique Identifier: 34105205|None_57379, Gene Names: AID
# Unique Identifier: 33502214|None_57379, Gene Names: AID
# Unique Identifier: 29135108|None_5443, Gene Names: ACTH
# Unique Identifier: 29135108|None_5617, Gene Names: PRL, PROLACTIN
# Unique Identifier: 24937369|None_20315, Gene Names: SDF-1, STROMAL-DERIVED FACTOR-1
# Unique Identifier: 24842956|None_4255, Gene Names: O6-METHYLGUANINE-DNA METHYLTRANSFERASE
# Unique Identifier: 19183852|None_6855, Gene Names: SYNAPTOPHYSIN
# Unique Identifier: 3499584|None_362686, Gene Names: RCBF
# Unique Identifier: 21674763|None_2956, Gene Names: MSH6
# Unique Identifier: 21674763|None_4292, Gene Names: MLH1
# Unique Identifier: 21674763|None_4436, Gene Names: MSH2
# Unique Identifier: 21674763|None_5395, Gene Names: PMS2
# Unique Identifier: 21129063|None_4609, Gene Names: MYC
# Unique Identifier: 17483310|None_13555, Gene Names: E2F1
# Unique Identifier: 17483310|None_1869, Gene Names: E2F1
# Unique Identifier: 17483310|None_14580, Gene Names: GFAP
# Unique Identifier: 12814248|None_24387, Gene Names: GFAP
# Unique Identifier: 12814248|None_24932, Gene Names: CD4
# Unique Identifier: 10651020|None_8743, Gene Names: APO2L, TRAIL, APO2 LIGAND
# Unique Identifier: 10651020|None_55733, Gene Names: SKN
# Unique Identifier: 10651020|None_2670, Gene Names: GFAP, GLIAL FIBRILLARY ACIDIC PROTEIN
# Unique Identifier: 8418502|None_24482, Gene Names: IGF-I, INSULIN-LIKE GROWTH FACTOR I
# Unique Identifier: 8121549|None_5362, Gene Names: OCT
# Unique Identifier: 8121549|None_5451, Gene Names: OCT-1
# Unique Identifier: 8121549|None_5454, Gene Names: N-OCT-3
# Unique Identifier: 8121549|None_5452, Gene Names: OCT-2
# Unique Identifier: 2541957|None_213, Gene Names: ALBUMIN
# Unique Identifier: 26935297|None_3481, Gene Names: IGF2
# Unique Identifier: 26935297|None_7262, Gene Names: TSSC3, PHLDA2
# Unique Identifier: 26935297|None_10612, Gene Names: TRIM3
# Unique Identifier: 26935297|None_5002, Gene Names: SLC22A18
# Unique Identifier: 23625089|None_4233, Gene Names: C-MET
# Unique Identifier: 23625089|None_17295, Gene Names: C-MET
# Unique Identifier: 21879178|None_10058, Gene Names: ABC
# Unique Identifier: 21879178|None_440068, Gene Names: INCA
# Unique Identifier: 21879178|None_4363, Gene Names: MRP1, MULTIPLE DRUGS RESISTANCE ASSOCIATED PROTEIN 1
# Unique Identifier: 21317885|None_10277, Gene Names: UBE4B
# Unique Identifier: 21317885|None_4193, Gene Names: HDM2
# Unique Identifier: 21317885|None_7157, Gene Names: TP53
# Unique Identifier: 21317885|None_63958, Gene Names: UBE4B, UBIQUITINATION FACTOR E4B
# Unique Identifier: 21317885|None_17246, Gene Names: MDM2
# Unique Identifier: 18396787|None_246100, Gene Names: NY-ESO-1
# Unique Identifier: 2213114|None_250, Gene Names: ALP, ALKALINE PHOSPHATASE
# Unique Identifier: 1738033|None_16183, Gene Names: IL-2, INTERLEUKIN-2
# Unique Identifier: 1738033|None_7096, Gene Names: TIL
# Unique Identifier: 1738033|None_21897, Gene Names: TIL
# Unique Identifier: 1738033|None_3558, Gene Names: IL-2
# Unique Identifier: 51071|None_1437, Gene Names: CSF
# Unique Identifier: 22821382|None_3417, Gene Names: IDH1
# Unique Identifier: 22821382|None_3417;3418, Gene Names: IDH1/2
# Unique Identifier: 22821382|None_3418, Gene Names: IDH2
# Unique Identifier: 11837749|None_2670, Gene Names: GFAP
# Unique Identifier: 11837749|None_6855, Gene Names: SYNAPTOPHYSIN
# Unique Identifier: 11837749|None_57534, Gene Names: MIB-1
# Unique Identifier: 7848917|None_24577, Gene Names: MYC, C-MYC
# Unique Identifier: 7848917|None_301300, Gene Names: P53
# Unique Identifier: 7848917|None_4609, Gene Names: MYC

# %% [markdown]
# ### <span style="color:red">Full-text</span>

# %%
import openpyxl

# Load the Excel workbook
file_path = 'Abstracts and full text.xlsx'
worksheet_name = 'fullT_Gene_Names'  # Replace 'Sheet1' with the name of your worksheet
workbook = openpyxl.load_workbook(file_path)
worksheet = workbook[worksheet_name]

# Create an empty dictionary to store unique identifiers with gene names
unique_ids_2 = {}

# Iterate through the rows, limit to 10 rows for testing purposes
for index, row in enumerate(worksheet.iter_rows(min_row=2, max_row=worksheet.max_row, values_only=True), start=2):
    pmid = row[0]  # Assuming PMID is in the first column (column A)
    identifier = row[1]  # Assuming Identifier is in the second column (column B)
    gene_name = row[3]  # Assuming Gene Name is in the fourth column (column D)

    # Combine PMID and Identifier to create a unique identifier key
    unique_identifier = f"{pmid}_{identifier}"

    # Check if the unique identifier is already in the dictionary
    if unique_identifier not in unique_ids_2:
        unique_ids_2[unique_identifier] = [gene_name]  # Initialize a list with the gene name
    else:
        # If the key exists, append the gene name to the existing list
        unique_ids_2[unique_identifier].append(gene_name)

    # Highlight the current row with yellow fill color
    for cell in worksheet[index]:
        cell.fill = openpyxl.styles.PatternFill(start_color='0000FF', end_color='0000FF', fill_type='solid')

# Display the unique identifiers with their corresponding gene names
for identifier, gene_names in unique_ids_2.items():
    print(f"Unique Identifier: {identifier}, Gene Names: {', '.join(gene_names)}")

# Save the modified workbook to a new file
workbook.save(file_path)

# Close the workbook
workbook.close()
# Out:
# Unique Identifier: 33071276|None_1956, Gene Names: EGFR
# Unique Identifier: 33071276|None_3417;3418, Gene Names: IDH1/2
# Unique Identifier: 33071276|None_673, Gene Names: BRAF
# Unique Identifier: 33071276|None_695, Gene Names: Bruton tyrosine kinase, BTK
# Unique Identifier: 25398846|None_6469, Gene Names: SHH
# Unique Identifier: 25398846|None_6608, Gene Names: SMO
# Unique Identifier: 32325928|None_196, Gene Names: Aryl Hydrocarbon Receptor, AhR, AhR, aryl hydrocarbon receptor, AhR, AhR, AhR, AhR, AhR
# Unique Identifier: 37071297|None_3417, Gene Names: IDH1
# Unique Identifier: 37071297|None_4255, Gene Names: MGMT
# Unique Identifier: 32648041|None_673, Gene Names: BRAF, BRAF, BRAF, BRAF, BRAF, BRAF, BRAF, BRAF, BRAF, BRAF, BRAF
# Unique Identifier: 32648041|None_22882, Gene Names: RAF, RAF
# Unique Identifier: 32648041|None_5609, Gene Names: MEK
# Unique Identifier: 32648041|None_1956, Gene Names: EGFR
# Unique Identifier: 34864569|None_4763, Gene Names: NF1
# Unique Identifier: 34864569|None_1029, Gene Names: CDKN2A
# Unique Identifier: 34864569|None_894, Gene Names: CCND2
# Unique Identifier: 34864569|None_1956, Gene Names: EGFR
# Unique Identifier: 34864569|None_4613, Gene Names: MYCN
# Unique Identifier: 28445970|None_427, Gene Names: Acid ceramidase, acid ceramidase, acid ceramidase, acid ceramidase, acid ceramidase, acid ceramidase
# Unique Identifier: 29676036|None_3417, Gene Names: isocitrate dehydrogenase 1, IDH1, IDH1, IDH1, IDH1, isocitrate dehydrogenase 1, IDH1, IDH1, IDH1, IDH1, IDH1, IDH1, IDH1, IDH1, IDH1, IDH1
# Unique Identifier: 29676036|None_10630, Gene Names: podoplanin, podoplanin, podoplanin, podoplanin, podoplanin, podoplanin, podoplanin, podoplanin, podoplanin, podoplanin, podoplanin, podoplanin, podoplanin
# Unique Identifier: 32681571|None_79811, Gene Names: MET
# Unique Identifier: 32681571|None_238, Gene Names: ALK
# Unique Identifier: 22815729|None_4255, Gene Names: MGMT
# Unique Identifier: 26269128|None_3939, Gene Names: Lactate Dehydrogenase A, Lactate dehydrogenase A, LDHA, LDHA, LDHA, LDHA, LDHA
# Unique Identifier: 35526519|None_4916, Gene Names: NTRK3, NTRK3
# Unique Identifier: 25519303|None_3620, Gene Names: IDO, indoleamine 2,3 dioxygenase 1, IDO1, IDO1, IDO1, IDO1, IDO1, IDO1
# Unique Identifier: 25519303|None_50943, Gene Names: FoxP3
# Unique Identifier: 23121055|None_4763, Gene Names: neurofibromatosis type 1
# Unique Identifier: 23121055|None_673, Gene Names: BRAF
# Unique Identifier: 28327649|None_64399, Gene Names: hip
# Unique Identifier: 36720920|None_1022, Gene Names: cyclin-dependent kinase 7
# Unique Identifier: 21914837|None_373156, Gene Names: glutathione S-transferases, glutathione S-transferases, GSTs
# Unique Identifier: 21914837|None_2944, Gene Names: GSTM1
# Unique Identifier: 21914837|None_2952, Gene Names: GSTT1, GSTT1, GSTT1
# Unique Identifier: 21914837|None_2950, Gene Names: GSTP1, GSTP1
# Unique Identifier: 21914837|None_2947, Gene Names: GSTM3, GSTM3, GSTM3
# Unique Identifier: 28073783|None_10630, Gene Names: Podoplanin, podoplanin, podoplanin, podoplanin, podoplanin, Podoplanin, podoplanin, podoplanin, Podoplanin, podoplanin
# Unique Identifier: 19333441|None_4255, Gene Names: MGMT
# Unique Identifier: 19333441|None_3075, Gene Names: arms 1p
# Unique Identifier: 22533851|None_7039, Gene Names: TGF-beta
# Unique Identifier: 22533851|None_1493, Gene Names: CTLA-4
# Unique Identifier: 22533851|None_3620, Gene Names: IDO
# Unique Identifier: 23302230|None_2064, Gene Names: HER2, HER2
# Unique Identifier: 23302230|None_652070, Gene Names: scFv
# Unique Identifier: 29558958|None_6469, Gene Names: Sonic hedgehog, Sonic hedgehog, Shh, Shh, Shh, Shh, Shh, Shh
# Unique Identifier: 33632416|None_3417, Gene Names: isocitrate dehydrogenase 1, IDH1, IDH
# Unique Identifier: 33673696|None_9970, Gene Names: Chimeric Antigen Receptor, chimeric antigen receptor, CAR, CAR, CAR, CAR, CAR, CAR
# Unique Identifier: 24509903|None_8795, Gene Names: DR5, DR5, DR5, DR5, DR5
# Unique Identifier: 27835870|None_66141, Gene Names: IFITM3, IFITM3, IFITM3, IFITM3, IFITM3, IFITM3
# Unique Identifier: 27835870|None_10410, Gene Names: interferon-inducible transmembrane protein 3, IFITM3, IFITM3, IFITM3, IFITM3
# Unique Identifier: 35098162|None_14081, Gene Names: FACS
# Unique Identifier: 19957013|None_1956, Gene Names: epidermal growth factor receptor
# Unique Identifier: 15469606|None_18008, Gene Names: nestin
# Unique Identifier: 15469606|None_19211, Gene Names: PTEN
# Unique Identifier: 15469606|None_12578, Gene Names: CDKN2A
# Unique Identifier: 28707595|None_3783, Gene Names: KCa3.1, KCa3.1, KCa3.1, KCa3.1, KCa3.1, KCa3.1, KCa3.1, KCa3.1
# Unique Identifier: 22385786|None_673, Gene Names: BRAF, BRAF, BRAF, BRAF, BRAF, BRAF, BRAF, BRAF, BRAF, BRAF, BRAF
# Unique Identifier: 22385786|None_110157, Gene Names: v-RAF
# Unique Identifier: 22385786|None_109880, Gene Names: BRAF
# Unique Identifier: 24839957|None_79727, Gene Names: LIN28, LIN28, LIN28, LIN28, LIN28, LIN28, LIN28, LIN28, LIN28
# Unique Identifier: 24839957|None_389421, Gene Names: LIN28B
# Unique Identifier: 24839957|None_1789, Gene Names: DNMT3B, DNMT3B
# Unique Identifier: 24839957|None_2475, Gene Names: mTOR
# Unique Identifier: 27493954|None_9048, Gene Names: Art
# Unique Identifier: 34210107|None_4255, Gene Names: O6-methylguanine-DNA methyltransferase
# Unique Identifier: 34210107|None_1956, Gene Names: epidermal growth factor receptor
# Unique Identifier: 34681949|None_10919, Gene Names: EHMT2, G9a, histone methyltransferase G9a (euchromatic histone lysine methyltransferase 2, EHMT2, G9a, G9a, G9a, G9a, G9a
# Unique Identifier: 19948061|None_57124, Gene Names: TEM1, endosialin, TEM1, endosialin, TEM1, endosialin, TEM1, endosialin, TEM1, endosialin, TEM1, endosialin, TEM1, endosialin, TEM1, endosialin, TEM1, endosialin, TEM1, endosialin, TEM1, endosialin, TEM1, endosialin, TEM1, endosialin
# Unique Identifier: 19948061|None_70445, Gene Names: TEM1, endosialin, TEM1, endosialin, Tem1, endosialin, Tem1, endosialin, Tem1, endosialin
# Unique Identifier: 19948061|None_58, Gene Names: alphaSMA
# Unique Identifier: 19948061|None_2335, Gene Names: fibronectin
# Unique Identifier: 20882288|None_4609, Gene Names: MYC
# Unique Identifier: 20882288|None_4613, Gene Names: MYCN
# Unique Identifier: 20882288|None_1499, Gene Names: beta-catenin
# Unique Identifier: 20882288|None_6598, Gene Names: SMARCB1, INI1, hSNF5, SMARCB1
# Unique Identifier: 29124520|None_3417, Gene Names: isocitrate dehydrogenase, IDH
# Unique Identifier: 30855176|None_2064, Gene Names: ERBB2
# Unique Identifier: 30855176|None_79811, Gene Names: MET
# Unique Identifier: 30855176|None_1956, Gene Names: EGFR
# Unique Identifier: 34663805|None_57082, Gene Names: KNL1
# Unique Identifier: 34663805|None_259266, Gene Names: ASPM
# Unique Identifier: 34663805|None_1062, Gene Names: CENPE
# Unique Identifier: 34663805|None_11113, Gene Names: CITK
# Unique Identifier: 34663805|None_9928, Gene Names: KIF14
# Unique Identifier: 35409080|None_2735;2736;2737, Gene Names: GLI-1/2/3
# Unique Identifier: 35409080|None_1869;1870;1871;1874;1875;1876;144455;79733, Gene Names: E2F1-8
# Unique Identifier: 35409080|None_6774, Gene Names: STAT3
# Unique Identifier: 35409080|None_3091, Gene Names: HIF-1/2
# Unique Identifier: 35409080|None_4774;4781, Gene Names: NFI-A/B
# Unique Identifier: 35409080|None_4661, Gene Names: MYT1
# Unique Identifier: 35409080|None_23040, Gene Names: MYT1L
# Unique Identifier: 25742877|None_4763, Gene Names: neurofibromatosis type 1
# Unique Identifier: 32652442|None_11545, Gene Names: PARP, Poly (ADP-ribose) polymerase, PARP, PARP1, PARP
# Unique Identifier: 32652442|None_11546, Gene Names: PARP2
# Unique Identifier: 32652442|None_12189;12190, Gene Names: BRCA1/2
# Unique Identifier: 32652442|None_12189, Gene Names: BRCA1
# Unique Identifier: 33931452|None_6608, Gene Names: Smoothened, SMO, SMO, SMO
# Unique Identifier: 34229297|None_1193, Gene Names: Chloride intracellular channel protein 2, chloride intracellular channel protein 2, CLIC2, CLIC2, CLIC2, CLIC2, CLIC2, CLIC2, CLIC2, CLIC2, CLIC2
# Unique Identifier: 34229297|None_4323, Gene Names: MMP14, matrix metalloproteinase (MMP) 14, MMP14, MMP14
# Unique Identifier: 34229297|None_294141, Gene Names: CLIC2, CLIC2
# Unique Identifier: 21533524|None_641648, Gene Names: U87, U87
# Unique Identifier: 22504484|None_71904, Gene Names: MPR, MPR, MPR
# Unique Identifier: 23691191|None_7015, Gene Names: TERT
# Unique Identifier: 23691191|None_7013;7014, Gene Names: Telomere Repeat-binding Factor (TRF) 1 and 2, TRF1 and 2, TRF1 and 2
# Unique Identifier: 23691191|None_142, Gene Names: PARP, PARP, PARP, PARP
# Unique Identifier: 23691191|None_7013, Gene Names: TRF1, TRF1, TRF1
# Unique Identifier: 23691191|None_7014, Gene Names: TRF2, TRF2
# Unique Identifier: 25970776|None_6657, Gene Names: SOX2
# Unique Identifier: 25970776|None_5290, Gene Names: PIK3CA
# Unique Identifier: 25970776|None_4914, Gene Names: NTRK1
# Unique Identifier: 25970776|None_2778, Gene Names: GNAS
# Unique Identifier: 25970776|None_1499, Gene Names: CTNNB1
# Unique Identifier: 25970776|None_2260, Gene Names: FGFR1
# Unique Identifier: 26439689|None_1116, Gene Names: YKL-40, YKL-40, CHI3L1, YKL-40, YKL-40
# Unique Identifier: 31041803|None_3417, Gene Names: isocitrate dehydrogenase 1, IDH1, IDH1, IDH1
# Unique Identifier: 35408879|None_3417, Gene Names: isocitrate dehydrogenase, IDH
# Unique Identifier: 18624795|None_693235, Gene Names: MiR-92b, hsa-miR-92b, hsa-miR-92b
# Unique Identifier: 22528798|None_362686, Gene Names: rCBF, rCBF, rCBF
# Unique Identifier: 23690717|None_501, Gene Names: PDE, PDE, PDE, PDE, PDE, PDE, PDE, PDE, PDE, PDE, PDE, PDE, PDE, PDE, PDE
# Unique Identifier: 28816956|None_100034703, Gene Names: anaplastic astrocytoma (AA) 2
# Unique Identifier: 28816956|None_57192, Gene Names: malignant lymphoma (ML) 4
# Unique Identifier: 31187845|None_2335, Gene Names: fibronectin
# Unique Identifier: 17500046|None_4255, Gene Names: O6-methylguanine-DNA methyltransferase, MGMT, MGMT, MGMT, MGMT, MGMT, MGMT, MGMT, MGMT, MGMT, MGMT, MGMT, MGMT
# Unique Identifier: 17500046|None_5423, Gene Names: DNA polymerase beta
# Unique Identifier: 24260161|None_2052, Gene Names: EPHX1, EPHX1
# Unique Identifier: 32051289|None_5133, Gene Names: programmed cell death protein 1
# Unique Identifier: 33066121|None_3082;79811, Gene Names: HGF/MET
# Unique Identifier: 33066121|None_3082, Gene Names: Hepatocyte growth factor, HGF, HGF, HGF
# Unique Identifier: 33066121|None_5979, Gene Names: receptor tyrosine kinase, RTK, RTK
# Unique Identifier: 33066121|None_79811, Gene Names: mesenchymal-epithelial transition factor, MET, MET, MET
# Unique Identifier: 34534142|None_653639, Gene Names: APT
# Unique Identifier: 37074422|None_4255, Gene Names: O6-methylguanine-DNA methyltransferase, MGMT, MGMT, MGMT
# Unique Identifier: 19333229|None_7422, Gene Names: VEGF, vascular endothelial growth factor, VEGF, VEGF, VEGF
# Unique Identifier: 23889991|None_92140, Gene Names: AEG-1, MTDH, LYRIC, Astrocyte-elevated gene-1, AEG-1, MTDH, LYRIC, AEG-1, MTDH, LYRIC, AEG-1, MTDH, LYRIC, AEG-1, MTDH, LYRIC, AEG-1, MTDH, LYRIC, AEG-1, MTDH, LYRIC, AEG-1, MTDH, LYRIC
# Unique Identifier: 23889991|None_7124, Gene Names: TNF
# Unique Identifier: 24337497|None_79727, Gene Names: LIN28A
# Unique Identifier: 33813026|None_3620, Gene Names: IDO, indoleamine-2,3-dioxygenase 1, IDO1
# Unique Identifier: 35986378|None_4763, Gene Names: NF1
# Unique Identifier: 35986378|None_57670, Gene Names: KIAA1549
# Unique Identifier: 35986378|None_673, Gene Names: BRAF
# Unique Identifier: 35986378|None_920, Gene Names: CD4
# Unique Identifier: 35986378|None_3627, Gene Names: Cxcl10, Cxcl10
# Unique Identifier: 35986378|None_5609, Gene Names: MEK
# Unique Identifier: 18607344|None_1474, Gene Names: cystatin E, CST6, cystatin E, CST6, Cystatin E, cystatin E, CST6, cystatin E, CST6, CST6, CST6, CST6, cystatin E, CST6, CST6
# Unique Identifier: 18607344|None_1508, Gene Names: cathepsin B
# Unique Identifier: 22781957|None_84366, Gene Names: PRACTICE
# Unique Identifier: 23771511|None_79811, Gene Names: MET, MET, MET, MET, MET, MET
# Unique Identifier: 23984324|None_648, Gene Names: bmi-1, Bmi-1, Bmi-1, Bmi-1, Bmi-1, Bmi-1, Bmi-1
# Unique Identifier: 24857059|None_1493, Gene Names: cytotoxic T-lymphocyte antigen (CTLA)-4
# Unique Identifier: 24857059|None_5133, Gene Names: programmed cell death 1/programmed cell death 1 ligand
# Unique Identifier: 24857059|None_29126, Gene Names: PDL1
# Unique Identifier: 7516104|None_7422, Gene Names: vascular permeability factor, Vascular permeability factor, vascular endothelial growth factor, VPF, VEGF, VPF, VPF
# Unique Identifier: 33693781|None_3417, Gene Names: isocitrate dehydrogenase 1, IDH1
# Unique Identifier: 22139378|None_51029, Gene Names: DESI, DESI
# Unique Identifier: 23618424|None_4255, Gene Names: MGMT
# Unique Identifier: 23618424|None_3417, Gene Names: IDH1, IDH1
# Unique Identifier: 23618424|None_4609, Gene Names: MYCC
# Unique Identifier: 23618424|None_4613, Gene Names: MYCN
# Unique Identifier: 23618424|None_1499, Gene Names: beta-catenin
# Unique Identifier: 26197301|None_2243, Gene Names: FGA, FGA, FGA, FGA
# Unique Identifier: 26197301|None_2244, Gene Names: FGB, FGB
# Unique Identifier: 26411769|None_26570, Gene Names: xCT, SLC7a11, xCT, xCT, xCT, xCT, xCT
# Unique Identifier: 27134530|None_4233, Gene Names: C-Met, C-Met, C-Met, C-Met, C-Met
# Unique Identifier: 30267146|None_1956, Gene Names: EGFR, EGFR, EGFR
# Unique Identifier: 36577872|None_3417, Gene Names: IDH, IDH, IDH, IDH, IDH, IDH
# Unique Identifier: 19273072|None_3480, Gene Names: IGF-IR, IGF-IR, IGF-IR, IGF-IR, IGF-IR, IGF-IR, IGF-IR, IGF-IR
# Unique Identifier: 19273072|None_3479, Gene Names: IGF-I, IGF-I
# Unique Identifier: 22569092|None_5978, Gene Names: NRSF
# Unique Identifier: 23143294|None_1613, Gene Names: zip
# Unique Identifier: 23621605|None_2670, Gene Names: glial fibrillary acidic protein, GFAP, GFAP, GFAP, GFAP, GFAP, GFAP
# Unique Identifier: 23621605|None_361, Gene Names: aquaporin 4, AQ4, AQ4, AQ4, AQ4, AQ4, AQ4
# Unique Identifier: 24328868|None_4255, Gene Names: O(6)-methylguanine methyltranferase, MGMT
# Unique Identifier: 24328868|None_3417, Gene Names: IDH1
# Unique Identifier: 24328868|None_3418, Gene Names: IDH2
# Unique Identifier: 28030635|None_5460, Gene Names: Oct-4, Oct-4, Oct-4, Oct-4, Oct-4, Oct-4, Oct-4, Oct-4, Oct-4, Oct-4, Oct-4, Oct-4
# Unique Identifier: 28030635|None_3417, Gene Names: IDH1
# Unique Identifier: 28030635|None_8842, Gene Names: CD133, CD133
# Unique Identifier: 33342004|None_348, Gene Names: APOE, APOE, APOE, APOE
# Unique Identifier: 34424912|None_4255, Gene Names: methylguanine-methyltransferase, MGMT, MGMT
# Unique Identifier: 36167467|None_221914, Gene Names: GPC2, Glypican 2, GPC2, GPC2, GPC2, GPC2, GPC2, GPC2, GPC2, GPC2, GPC2, GPC2, GPC2, GPC2, GPC2, GPC2
# Unique Identifier: 36290819|None_3417, Gene Names: IDH, isocitrate dehydrogenase, IDH, IDH, IDH, IDH, IDH, IDH
# Unique Identifier: 18768900|None_15978, Gene Names: IFN-gamma
# Unique Identifier: 18768900|None_21926, Gene Names: TNF-alpha
# Unique Identifier: 36717507|None_3417, Gene Names: IDH, IDH, IDH, IDH, IDH

# %%
print(unique_ids_2)
# Out:
# {'33071276|None_1956': ['EGFR'], '33071276|None_3417;3418': ['IDH1/2'], '33071276|None_673': ['BRAF'], '33071276|None_695': ['Bruton tyrosine kinase', 'BTK'], '25398846|None_6469': ['SHH'], '25398846|None_6608': ['SMO'], '32325928|None_196': ['Aryl Hydrocarbon Receptor', 'AhR', 'AhR', 'aryl hydrocarbon receptor', 'AhR', 'AhR', 'AhR', 'AhR', 'AhR'], '37071297|None_3417': ['IDH1'], '37071297|None_4255': ['MGMT'], '32648041|None_673': ['BRAF', 'BRAF', 'BRAF', 'BRAF', 'BRAF', 'BRAF', 'BRAF', 'BRAF', 'BRAF', 'BRAF', 'BRAF'], '32648041|None_22882': ['RAF', 'RAF'], '32648041|None_5609': ['MEK'], '32648041|None_1956': ['EGFR'], '34864569|None_4763': ['NF1'], '34864569|None_1029': ['CDKN2A'], '34864569|None_894': ['CCND2'], '34864569|None_1956': ['EGFR'], '34864569|None_4613': ['MYCN'], '28445970|None_427': ['Acid ceramidase', 'acid ceramidase', 'acid ceramidase', 'acid ceramidase', 'acid ceramidase', 'acid ceramidase'], '29676036|None_3417': ['isocitrate dehydrogenase 1', 'IDH1', 'IDH1', 'IDH1', 'IDH1', 'isocitrate dehydrogenase 1', 'IDH1', 'IDH1', 'IDH1', 'IDH1', 'IDH1', 'IDH1', 'IDH1', 'IDH1', 'IDH1', 'IDH1'], '29676036|None_10630': ['podoplanin', 'podoplanin', 'podoplanin', 'podoplanin', 'podoplanin', 'podoplanin', 'podoplanin', 'podoplanin', 'podoplanin', 'podoplanin', 'podoplanin', 'podoplanin', 'podoplanin'], '32681571|None_79811': ['MET'], '32681571|None_238': ['ALK'], '22815729|None_4255': ['MGMT'], '26269128|None_3939': ['Lactate Dehydrogenase A', 'Lactate dehydrogenase A', 'LDHA', 'LDHA', 'LDHA', 'LDHA', 'LDHA'], '35526519|None_4916': ['NTRK3', 'NTRK3'], '25519303|None_3620': ['IDO', 'indoleamine 2,3 dioxygenase 1', 'IDO1', 'IDO1', 'IDO1', 'IDO1', 'IDO1', 'IDO1'], '25519303|None_50943': ['FoxP3'], '23121055|None_4763': ['neurofibromatosis type 1'], '23121055|None_673': ['BRAF'], '28327649|None_64399': ['hip'], '36720920|None_1022': ['cyclin-dependent kinase 7'], '21914837|None_373156': ['glutathione S-transferases', 'glutathione S-transferases', 'GSTs'], '21914837|None_2944': ['GSTM1'], '21914837|None_2952': ['GSTT1', 'GSTT1', 'GSTT1'], '21914837|None_2950': ['GSTP1', 'GSTP1'], '21914837|None_2947': ['GSTM3', 'GSTM3', 'GSTM3'], '28073783|None_10630': ['Podoplanin', 'podoplanin', 'podoplanin', 'podoplanin', 'podoplanin', 'Podoplanin', 'podoplanin', 'podoplanin', 'Podoplanin', 'podoplanin'], '19333441|None_4255': ['MGMT'], '19333441|None_3075': ['arms 1p'], '22533851|None_7039': ['TGF-beta'], '22533851|None_1493': ['CTLA-4'], '22533851|None_3620': ['IDO'], '23302230|None_2064': ['HER2', 'HER2'], '23302230|None_652070': ['scFv'], '29558958|None_6469': ['Sonic hedgehog', 'Sonic hedgehog', 'Shh', 'Shh', 'Shh', 'Shh', 'Shh', 'Shh'], '33632416|None_3417': ['isocitrate dehydrogenase 1', 'IDH1', 'IDH'], '33673696|None_9970': ['Chimeric Antigen Receptor', 'chimeric antigen receptor', 'CAR', 'CAR', 'CAR', 'CAR', 'CAR', 'CAR'], '24509903|None_8795': ['DR5', 'DR5', 'DR5', 'DR5', 'DR5'], '27835870|None_66141': ['IFITM3', 'IFITM3', 'IFITM3', 'IFITM3', 'IFITM3', 'IFITM3'], '27835870|None_10410': ['interferon-inducible transmembrane protein 3', 'IFITM3', 'IFITM3', 'IFITM3', 'IFITM3'], '35098162|None_14081': ['FACS'], '19957013|None_1956': ['epidermal growth factor receptor'], '15469606|None_18008': ['nestin'], '15469606|None_19211': ['PTEN'], '15469606|None_12578': ['CDKN2A'], '28707595|None_3783': ['KCa3.1', 'KCa3.1', 'KCa3.1', 'KCa3.1', 'KCa3.1', 'KCa3.1', 'KCa3.1', 'KCa3.1'], '22385786|None_673': ['BRAF', 'BRAF', 'BRAF', 'BRAF', 'BRAF', 'BRAF', 'BRAF', 'BRAF', 'BRAF', 'BRAF', 'BRAF'], '22385786|None_110157': ['v-RAF'], '22385786|None_109880': ['BRAF'], '24839957|None_79727': ['LIN28', 'LIN28', 'LIN28', 'LIN28', 'LIN28', 'LIN28', 'LIN28', 'LIN28', 'LIN28'], '24839957|None_389421': ['LIN28B'], '24839957|None_1789': ['DNMT3B', 'DNMT3B'], '24839957|None_2475': ['mTOR'], '27493954|None_9048': ['Art'], '34210107|None_4255': ['O6-methylguanine-DNA methyltransferase'], '34210107|None_1956': ['epidermal growth factor receptor'], '34681949|None_109 ...

# %% [markdown]
# **This organizes the gene names and helps collect all the unquie names mentioned in each article/abstracts.**

# %%
import openpyxl
from openpyxl.styles import PatternFill

# Load the Excel workbook
file_path = 'Abstracts and full text.xlsx'
worksheet_name = 'fullT_Gene_Names'  # Replace 'Sheet1' with the name of your worksheet
workbook = openpyxl.load_workbook(file_path)
worksheet = workbook[worksheet_name]

# Create an empty dictionary to store unique identifiers with gene names
unique_geneIDs_2 = {}

# Iterate through the rows
for index, row in enumerate(worksheet.iter_rows(min_row=2, values_only=True), start=2):
    pmid_FT = row[0]  # Assuming PMID is in the first column (column A)
    identifier_FT = row[1]  # Assuming Identifier is in the second column (column B)
    gene_name_FT = row[3]  # Assuming Gene Name is in the fourth column (column D)

    # Combine PMID and Identifier to create a unique identifier key
    unique_identifier = f"{pmid_FT}_{identifier_FT}"

    # Check if the unique identifier is already in the dictionary
    if unique_identifier not in unique_geneIDs_2:
        unique_geneIDs_2[unique_identifier] = [gene_name_FT.upper()]  # Initialize a list with the capitalized gene name
    else:
        # If the key exists, append the capitalized gene name to the existing list
        unique_geneIDs_2[unique_identifier].append(gene_name_FT.upper())

    # Highlight the current row with yellow fill color
    for cell in worksheet[index]:
        cell.fill = PatternFill(start_color='0000FF', end_color='0000FF', fill_type='solid')

# Sort the gene names within each dictionary section
for identifier_FT, gene_names_FT in unique_geneIDs_2.items():
    unique_geneIDs_2[identifier_FT] = sorted(set(gene_names_FT), key=lambda x: (len(x), x))

# Display the unique identifiers with their corresponding gene names
for identifier_FT, gene_names_FT in unique_geneIDs_2.items():
    print(f"Unique Identifier: {identifier_FT}, Gene Names: {', '.join(gene_names_FT)}")
   # worksheet.cell(row=index, column=4).value = ', '.join(gene_names)

# Save the modified workbook (overwriting the original file)
workbook.save(file_path)

# Close the workbook
workbook.close()
# Out:
# Unique Identifier: 33071276|None_1956, Gene Names: EGFR
# Unique Identifier: 33071276|None_3417;3418, Gene Names: IDH1/2
# Unique Identifier: 33071276|None_673, Gene Names: BRAF
# Unique Identifier: 33071276|None_695, Gene Names: BTK, BRUTON TYROSINE KINASE
# Unique Identifier: 25398846|None_6469, Gene Names: SHH
# Unique Identifier: 25398846|None_6608, Gene Names: SMO
# Unique Identifier: 32325928|None_196, Gene Names: AHR, ARYL HYDROCARBON RECEPTOR
# Unique Identifier: 37071297|None_3417, Gene Names: IDH1
# Unique Identifier: 37071297|None_4255, Gene Names: MGMT
# Unique Identifier: 32648041|None_673, Gene Names: BRAF
# Unique Identifier: 32648041|None_22882, Gene Names: RAF
# Unique Identifier: 32648041|None_5609, Gene Names: MEK
# Unique Identifier: 32648041|None_1956, Gene Names: EGFR
# Unique Identifier: 34864569|None_4763, Gene Names: NF1
# Unique Identifier: 34864569|None_1029, Gene Names: CDKN2A
# Unique Identifier: 34864569|None_894, Gene Names: CCND2
# Unique Identifier: 34864569|None_1956, Gene Names: EGFR
# Unique Identifier: 34864569|None_4613, Gene Names: MYCN
# Unique Identifier: 28445970|None_427, Gene Names: ACID CERAMIDASE
# Unique Identifier: 29676036|None_3417, Gene Names: IDH1, ISOCITRATE DEHYDROGENASE 1
# Unique Identifier: 29676036|None_10630, Gene Names: PODOPLANIN
# Unique Identifier: 32681571|None_79811, Gene Names: MET
# Unique Identifier: 32681571|None_238, Gene Names: ALK
# Unique Identifier: 22815729|None_4255, Gene Names: MGMT
# Unique Identifier: 26269128|None_3939, Gene Names: LDHA, LACTATE DEHYDROGENASE A
# Unique Identifier: 35526519|None_4916, Gene Names: NTRK3
# Unique Identifier: 25519303|None_3620, Gene Names: IDO, IDO1, INDOLEAMINE 2,3 DIOXYGENASE 1
# Unique Identifier: 25519303|None_50943, Gene Names: FOXP3
# Unique Identifier: 23121055|None_4763, Gene Names: NEUROFIBROMATOSIS TYPE 1
# Unique Identifier: 23121055|None_673, Gene Names: BRAF
# Unique Identifier: 28327649|None_64399, Gene Names: HIP
# Unique Identifier: 36720920|None_1022, Gene Names: CYCLIN-DEPENDENT KINASE 7
# Unique Identifier: 21914837|None_373156, Gene Names: GSTS, GLUTATHIONE S-TRANSFERASES
# Unique Identifier: 21914837|None_2944, Gene Names: GSTM1
# Unique Identifier: 21914837|None_2952, Gene Names: GSTT1
# Unique Identifier: 21914837|None_2950, Gene Names: GSTP1
# Unique Identifier: 21914837|None_2947, Gene Names: GSTM3
# Unique Identifier: 28073783|None_10630, Gene Names: PODOPLANIN
# Unique Identifier: 19333441|None_4255, Gene Names: MGMT
# Unique Identifier: 19333441|None_3075, Gene Names: ARMS 1P
# Unique Identifier: 22533851|None_7039, Gene Names: TGF-BETA
# Unique Identifier: 22533851|None_1493, Gene Names: CTLA-4
# Unique Identifier: 22533851|None_3620, Gene Names: IDO
# Unique Identifier: 23302230|None_2064, Gene Names: HER2
# Unique Identifier: 23302230|None_652070, Gene Names: SCFV
# Unique Identifier: 29558958|None_6469, Gene Names: SHH, SONIC HEDGEHOG
# Unique Identifier: 33632416|None_3417, Gene Names: IDH, IDH1, ISOCITRATE DEHYDROGENASE 1
# Unique Identifier: 33673696|None_9970, Gene Names: CAR, CHIMERIC ANTIGEN RECEPTOR
# Unique Identifier: 24509903|None_8795, Gene Names: DR5
# Unique Identifier: 27835870|None_66141, Gene Names: IFITM3
# Unique Identifier: 27835870|None_10410, Gene Names: IFITM3, INTERFERON-INDUCIBLE TRANSMEMBRANE PROTEIN 3
# Unique Identifier: 35098162|None_14081, Gene Names: FACS
# Unique Identifier: 19957013|None_1956, Gene Names: EPIDERMAL GROWTH FACTOR RECEPTOR
# Unique Identifier: 15469606|None_18008, Gene Names: NESTIN
# Unique Identifier: 15469606|None_19211, Gene Names: PTEN
# Unique Identifier: 15469606|None_12578, Gene Names: CDKN2A
# Unique Identifier: 28707595|None_3783, Gene Names: KCA3.1
# Unique Identifier: 22385786|None_673, Gene Names: BRAF
# Unique Identifier: 22385786|None_110157, Gene Names: V-RAF
# Unique Identifier: 22385786|None_109880, Gene Names: BRAF
# Unique Identifier: 24839957|None_79727, Gene Names: LIN28
# Unique Identifier: 24839957|None_389421, Gene Names: LIN28B
# Unique Identifier: 24839957|None_1789, Gene Names: DNMT3B
# Unique Identifier: 24839957|None_2475, Gene Names: MTOR
# Unique Identifier: 27493954|None_9048, Gene Names: ART
# Unique Identifier: 34210107|None_4255, Gene Names: O6-METHYLGUANINE-DNA METHYLTRANSFERASE
# Unique Identifier: 34210107|None_1956, Gene Names: EPIDERMAL GROWTH FACTOR RECEPTOR
# Unique Identifier: 34681949|None_10919, Gene Names: G9A, EHMT2, HISTONE METHYLTRANSFERASE G9A (EUCHROMATIC HISTONE LYSINE METHYLTRANSFERASE 2
# Unique Identifier: 19948061|None_57124, Gene Names: TEM1, ENDOSIALIN
# Unique Identifier: 19948061|None_70445, Gene Names: TEM1, ENDOSIALIN
# Unique Identifier: 19948061|None_58, Gene Names: ALPHASMA
# Unique Identifier: 19948061|None_2335, Gene Names: FIBRONECTIN
# Unique Identifier: 20882288|None_4609, Gene Names: MYC
# Unique Identifier: 20882288|None_4613, Gene Names: MYCN
# Unique Identifier: 20882288|None_1499, Gene Names: BETA-CATENIN
# Unique Identifier: 20882288|None_6598, Gene Names: INI1, HSNF5, SMARCB1
# Unique Identifier: 29124520|None_3417, Gene Names: IDH, ISOCITRATE DEHYDROGENASE
# Unique Identifier: 30855176|None_2064, Gene Names: ERBB2
# Unique Identifier: 30855176|None_79811, Gene Names: MET
# Unique Identifier: 30855176|None_1956, Gene Names: EGFR
# Unique Identifier: 34663805|None_57082, Gene Names: KNL1
# Unique Identifier: 34663805|None_259266, Gene Names: ASPM
# Unique Identifier: 34663805|None_1062, Gene Names: CENPE
# Unique Identifier: 34663805|None_11113, Gene Names: CITK
# Unique Identifier: 34663805|None_9928, Gene Names: KIF14
# Unique Identifier: 35409080|None_2735;2736;2737, Gene Names: GLI-1/2/3
# Unique Identifier: 35409080|None_1869;1870;1871;1874;1875;1876;144455;79733, Gene Names: E2F1-8
# Unique Identifier: 35409080|None_6774, Gene Names: STAT3
# Unique Identifier: 35409080|None_3091, Gene Names: HIF-1/2
# Unique Identifier: 35409080|None_4774;4781, Gene Names: NFI-A/B
# Unique Identifier: 35409080|None_4661, Gene Names: MYT1
# Unique Identifier: 35409080|None_23040, Gene Names: MYT1L
# Unique Identifier: 25742877|None_4763, Gene Names: NEUROFIBROMATOSIS TYPE 1
# Unique Identifier: 32652442|None_11545, Gene Names: PARP, PARP1, POLY (ADP-RIBOSE) POLYMERASE
# Unique Identifier: 32652442|None_11546, Gene Names: PARP2
# Unique Identifier: 32652442|None_12189;12190, Gene Names: BRCA1/2
# Unique Identifier: 32652442|None_12189, Gene Names: BRCA1
# Unique Identifier: 33931452|None_6608, Gene Names: SMO, SMOOTHENED
# Unique Identifier: 34229297|None_1193, Gene Names: CLIC2, CHLORIDE INTRACELLULAR CHANNEL PROTEIN 2
# Unique Identifier: 34229297|None_4323, Gene Names: MMP14, MATRIX METALLOPROTEINASE (MMP) 14
# Unique Identifier: 34229297|None_294141, Gene Names: CLIC2
# Unique Identifier: 21533524|None_641648, Gene Names: U87
# Unique Identifier: 22504484|None_71904, Gene Names: MPR
# Unique Identifier: 23691191|None_7015, Gene Names: TERT
# Unique Identifier: 23691191|None_7013;7014, Gene Names: TRF1 AND 2, TELOMERE REPEAT-BINDING FACTOR (TRF) 1 AND 2
# Unique Identifier: 23691191|None_142, Gene Names: PARP
# Unique Identifier: 23691191|None_7013, Gene Names: TRF1
# Unique Identifier: 23691191|None_7014, Gene Names: TRF2
# Unique Identifier: 25970776|None_6657, Gene Names: SOX2
# Unique Identifier: 25970776|None_5290, Gene Names: PIK3CA
# Unique Identifier: 25970776|None_4914, Gene Names: NTRK1
# Unique Identifier: 25970776|None_2778, Gene Names: GNAS
# Unique Identifier: 25970776|None_1499, Gene Names: CTNNB1
# Unique Identifier: 25970776|None_2260, Gene Names: FGFR1
# Unique Identifier: 26439689|None_1116, Gene Names: CHI3L1, YKL-40
# Unique Identifier: 31041803|None_3417, Gene Names: IDH1, ISOCITRATE DEHYDROGENASE 1
# Unique Identifier: 35408879|None_3417, Gene Names: IDH, ISOCITRATE DEHYDROGENASE
# Unique Identifier: 18624795|None_693235, Gene Names: MIR-92B, HSA-MIR-92B
# Unique Identifier: 22528798|None_362686, Gene Names: RCBF
# Unique Identifier: 23690717|None_501, Gene Names: PDE
# Unique Identifier: 28816956|None_100034703, Gene Names: ANAPLASTIC ASTROCYTOMA (AA) 2
# Unique Identifier: 28816956|None_57192, Gene Names: MALIGNANT LYMPHOMA (ML) 4
# Unique Identifier: 31187845|None_2335, Gene Names: FIBRONECTIN
# Unique Identifier: 17500046|None_4255, Gene Names: MGMT, O6-METHYLGUANINE-DNA METHYLTRANSFERASE
# Unique Identifier: 17500046|None_5423, Gene Names: DNA POLYMERASE BETA
# Unique Identifier: 24260161|None_2052, Gene Names: EPHX1
# Unique Identifier: 32051289|None_5133, Gene Names: PROGRAMMED CELL DEATH PROTEIN 1
# Unique Identifier: 33066121|None_3082;79811, Gene Names: HGF/MET
# Unique Identifier: 33066121|None_3082, Gene Names: HGF, HEPATOCYTE GROWTH FACTOR
# Unique Identifier: 33066121|None_5979, Gene Names: RTK, RECEPTOR TYROSINE KINASE
# Unique Identifier: 33066121|None_79811, Gene Names: MET, MESENCHYMAL-EPITHELIAL TRANSITION FACTOR
# Unique Identifier: 34534142|None_653639, Gene Names: APT
# Unique Identifier: 37074422|None_4255, Gene Names: MGMT, O6-METHYLGUANINE-DNA METHYLTRANSFERASE
# Unique Identifier: 19333229|None_7422, Gene Names: VEGF, VASCULAR ENDOTHELIAL GROWTH FACTOR
# Unique Identifier: 23889991|None_92140, Gene Names: MTDH, AEG-1, LYRIC, ASTROCYTE-ELEVATED GENE-1
# Unique Identifier: 23889991|None_7124, Gene Names: TNF
# Unique Identifier: 24337497|None_79727, Gene Names: LIN28A
# Unique Identifier: 33813026|None_3620, Gene Names: IDO, IDO1, INDOLEAMINE-2,3-DIOXYGENASE 1
# Unique Identifier: 35986378|None_4763, Gene Names: NF1
# Unique Identifier: 35986378|None_57670, Gene Names: KIAA1549
# Unique Identifier: 35986378|None_673, Gene Names: BRAF
# Unique Identifier: 35986378|None_920, Gene Names: CD4
# Unique Identifier: 35986378|None_3627, Gene Names: CXCL10
# Unique Identifier: 35986378|None_5609, Gene Names: MEK
# Unique Identifier: 18607344|None_1474, Gene Names: CST6, CYSTATIN E
# Unique Identifier: 18607344|None_1508, Gene Names: CATHEPSIN B
# Unique Identifier: 22781957|None_84366, Gene Names: PRACTICE
# Unique Identifier: 23771511|None_79811, Gene Names: MET
# Unique Identifier: 23984324|None_648, Gene Names: BMI-1
# Unique Identifier: 24857059|None_1493, Gene Names: CYTOTOXIC T-LYMPHOCYTE ANTIGEN (CTLA)-4
# Unique Identifier: 24857059|None_5133, Gene Names: PROGRAMMED CELL DEATH 1/PROGRAMMED CELL DEATH 1 LIGAND
# Unique Identifier: 24857059|None_29126, Gene Names: PDL1
# Unique Identifier: 7516104|None_7422, Gene Names: VPF, VEGF, VASCULAR PERMEABILITY FACTOR, VASCULAR ENDOTHELIAL GROWTH FACTOR
# Unique Identifier: 33693781|None_3417, Gene Names: IDH1, ISOCITRATE DEHYDROGENASE 1
# Unique Identifier: 22139378|None_51029, Gene Names: DESI
# Unique Identifier: 23618424|None_4255, Gene Names: MGMT
# Unique Identifier: 23618424|None_3417, Gene Names: IDH1
# Unique Identifier: 23618424|None_4609, Gene Names: MYCC
# Unique Identifier: 23618424|None_4613, Gene Names: MYCN
# Unique Identifier: 23618424|None_1499, Gene Names: BETA-CATENIN
# Unique Identifier: 26197301|None_2243, Gene Names: FGA
# Unique Identifier: 26197301|None_2244, Gene Names: FGB
# Unique Identifier: 26411769|None_26570, Gene Names: XCT, SLC7A11
# Unique Identifier: 27134530|None_4233, Gene Names: C-MET
# Unique Identifier: 30267146|None_1956, Gene Names: EGFR
# Unique Identifier: 36577872|None_3417, Gene Names: IDH
# Unique Identifier: 19273072|None_3480, Gene Names: IGF-IR
# Unique Identifier: 19273072|None_3479, Gene Names: IGF-I
# Unique Identifier: 22569092|None_5978, Gene Names: NRSF
# Unique Identifier: 23143294|None_1613, Gene Names: ZIP
# Unique Identifier: 23621605|None_2670, Gene Names: GFAP, GLIAL FIBRILLARY ACIDIC PROTEIN
# Unique Identifier: 23621605|None_361, Gene Names: AQ4, AQUAPORIN 4
# Unique Identifier: 24328868|None_4255, Gene Names: MGMT, O(6)-METHYLGUANINE METHYLTRANFERASE
# Unique Identifier: 24328868|None_3417, Gene Names: IDH1
# Unique Identifier: 24328868|None_3418, Gene Names: IDH2
# Unique Identifier: 28030635|None_5460, Gene Names: OCT-4
# Unique Identifier: 28030635|None_3417, Gene Names: IDH1
# Unique Identifier: 28030635|None_8842, Gene Names: CD133
# Unique Identifier: 33342004|None_348, Gene Names: APOE
# Unique Identifier: 34424912|None_4255, Gene Names: MGMT, METHYLGUANINE-METHYLTRANSFERASE
# Unique Identifier: 36167467|None_221914, Gene Names: GPC2, GLYPICAN 2
# Unique Identifier: 36290819|None_3417, Gene Names: IDH, ISOCITRATE DEHYDROGENASE
# Unique Identifier: 18768900|None_15978, Gene Names: IFN-GAMMA
# Unique Identifier: 18768900|None_21926, Gene Names: TNF-ALPHA
# Unique Identifier: 36717507|None_3417, Gene Names: IDH

# %% [markdown]
# ### Placing Gene Names into List

# %%
# Abstracts
ab_geneNames = [next(iter(gene_name), None) for gene_name in unique_geneIDs.values()]
print(ab_geneNames)

print()

# Full Text
ft_geneNames = [next(iter(gene_name), None) for gene_name in unique_geneIDs_2.values()]

print(ft_geneNames)

# Gene names in total (Abstract + Full-text)
geneNames_TOTAL = ab_geneNames + ft_geneNames
# Out:
# ['AID', 'C-MYC', 'BRAF', 'TRAIL', 'PDGFR', 'GH', 'MGMT', 'MRS', 'PRACTICE', 'P-GP', 'CSF', 'DICER', 'RISC', 'RAC3', 'MET', 'MIB-1', 'P53', 'SEP', 'ABR', 'CAM', 'PS 2', 'ACETYLCHOLINESTERASE', 'IDH', 'TR', 'VEGF', 'IL-4', 'TRAIL', 'AID', 'ECM', 'GLIAL FIBRILLARY ACIDIC PROTEIN, S-100', 'VIMENTIN', 'GPS', 'GLUTATHIONE REDUCTASE', 'SOD-1', 'ODC', 'CRT', 'CAT B', 'GLIAL FIBRILLARY ACIDIC PROTEIN', 'ALPHA-FETOPROTEIN', 'CCNU', 'AID', 'LAC', 'LIP', 'COX-2', 'EP4', 'SYNAPTOPHYSIN', 'FERRITIN HEAVY CHAIN', 'CSK', 'MIB-1', 'GFAP', 'NNOS', 'INOS', 'ENOS', 'ORNITHINE DECARBOXYLASE', 'GOPC', 'ROS1', 'CDK4', 'NF1', 'KIAA1549', 'BRAF', 'INI-1', 'EZH2', 'P53', 'ADRENOCORTICOTROPIC HORMONE', 'EPIDERMAL GROWTH FACTOR RECEPTOR', 'C-MYC', 'PIA', 'MGMT', 'TNM', 'NMT', 'NMT2', 'P53', 'UPA', 'PLASMIN', 'CEA', 'GLIAL FIBRILLARY ACIDIC PROTEIN', 'APOLIPOPROTEIN E', 'FOXR2', 'BCOR', 'P53', 'ATM', 'CYCLIN D2', 'EGFR', 'AKT', 'TP53', 'IDH1', 'PIK3CA', 'PTEN', 'EGFR', 'BRAF', 'CTNNB1', 'AKT', 'PTEN', 'CELL SURFACE RECEPTOR', 'PART 5', 'BAX', 'BCL-2', 'CFLIP, EFFECTOR CASPASES', 'AKT', 'TRANSFORMING GROWTH FACTOR BETA', 'TGF-BETA', 'BIKUNIN', 'FIBRONECTIN', 'AQP4', 'CYTOCHROME C', 'BCL-2', 'IDO1', 'TDO', 'AHR', 'LINC00461', 'MIR-216A', 'NEU4', 'CTBS', 'GBA2', 'CTSC', 'CTSK', 'CTSF', 'ARMS 1P', 'IDH1', 'IDH2', 'MGMT', 'VEGF', 'EGFR', 'BETA-CATENIN', 'CD45RO', 'GFAP', 'PPARDELTA', 'PPARGAMMA', 'CDKN2A', 'EGFR', 'PDGFRA', 'PTEN', 'CDK4', 'KIT', 'PIK3CA', 'MDM2', 'IDH', 'MGMT', 'ABCB1', 'NGAL', 'TP53', 'MGMT', 'CDC6', 'MCM5', 'MIB-1', 'GROWTH HORMONE', 'GH', 'CAR', 'ITK', 'MGMT', 'IDH', 'VEGF', 'TENASCIN', 'GFAP', 'NSE', 'MBP', 'PSK', 'LYN', 'CAR', 'ATRX', 'TP53', 'P53', 'MDM2', 'PRACTICE', 'INOS', 'MET-ENKEPHALIN', 'PREPROENKEPHALIN', 'HCG', 'GONADOTROPIN-RELEASING HORMONE', 'TNM', 'TAPASIN', 'IFNGAMMA', 'XRCC3', 'MET', 'IDH', 'GAL-3', 'BETA-GALACTOSIDE-BINDING LECTIN', 'P-GLYCOPROTEIN', 'RAD', 'CEA', 'MUL', 'MDR1', 'PGP', 'CD133', 'CHK1', 'CHK2', 'ENDOSTATIN', 'MDM2', 'INK4A', 'IGF-I', 'H15', 'CD4', 'TRK', 'EPIDERMAL GROWTH FACTOR RECEPTOR', 'PRACTICE', 'TUMOR-REJECTION ANTIGEN', 'SART1', 'IFN-B', 'GFAP', 'GFA', 'GLUTATHIONE S-TRANSFERASE', 'NIR', 'HSA', 'IRGD', 'ALBUMIN', 'BET', 'CDK9', 'AXL', 'BMI1', 'CBP', 'EGFR', 'CDK4', 'CDKN2A', 'TP53', 'DMBT1', 'NF2', 'PTEN', 'MIB-1', 'BCL-2', 'BCL-X', 'BAX', 'ICE', 'ICH-1', 'FAS LIGAND', 'P53', 'NF1', 'EPIDERMAL GROWTH FACTOR RECEPTOR', 'TRANSFORMING GROWTH FACTOR-ALPHA AND -BETA', 'C-MYC', 'C-FOS', 'INSULIN-LIKE GROWTH FACTOR I AND II', 'C-ERB B-2', 'SAO', 'AID', 'CRNN', 'NEUROFIBROMATOSIS 1', 'FUS', 'GROWTH HORMONE', 'MGMT', 'EGFR', 'ATRX', 'TERT', 'BRAF', 'DNMT', 'TTYH1', 'DNMT3B', 'MGMT', 'AQP4', 'IDH', 'MAMMALIAN TARGET OF RAPAMYCIN', 'C-REACTIVE PROTEIN', 'ALBUMIN', 'P-GP', 'PRACTICE', 'MTS1', 'GFAP', 'VIMENTIN', 'ALPHA-1-ANTITRYPSIN', 'ALPHA-1-ANTICHYMOTRYPSIN', 'GH', 'SH3PXD2A', 'HTRA1', 'NF2', 'TRAF7', 'KLF4', 'AKT1', 'SMO', 'TERT', 'CDKN2A/B', 'CTLA4', 'PROGRAMMED CELL DEATH 1', 'PDL1', 'KEL', 'CAT', 'ALPHA 1-AT', 'ALPHA 2-MACROGLOBULIN', 'FIBRINOGEN', 'PME', 'GFAP', 'VIMENTIN', 'FIBRONECTIN', 'CD133', 'IDH', 'TERT', 'BRAF', 'H3F3A', 'BRAF', 'IDH1', 'IL-13', 'IL-13RALPHA2', 'VEGF-D', 'AP-1', 'MGMT', 'ESTROGEN RECEPTOR', 'SLT', 'MTX', 'IDH', 'TP53', 'KIAA1549', 'BRAF', 'EGFR', 'TP53', 'CARBONIC ANHYDRASE IX', 'VASCULAR ENDOTHELIAL GROWTH FACTOR', 'PRACTICE', 'MMP', 'MMP-2', 'MMP-9', 'MMP-12', 'TIMP', 'TIMP-2', 'VEGF', 'ELASTIN', 'CIS-4', 'MET', 'AQP-4', 'TAU', 'TP53', 'EGFR', 'GLIAL FIBRILLARY ACIDIC PROTEIN', 'AGE', 'ACTH', 'SPIN', 'MAMMALIAN TARGET OF RAPAMYCIN', 'BCOR', 'RAF1', 'BRAF', 'ASXL1', 'MAP2K1', 'EGFR', 'PDGFR', 'VEGF', 'AKT', 'MTOR', 'EGFR', 'BRAF', 'PDGF-B', 'TTR', 'AGE', 'CD133', 'CD4', 'LCA', 'MMP-2', 'GROWTH HORMONE', 'TP53', 'AGE', 'UPA', 'PAI-1', 'TPA', 'PKC', 'IDH1', 'BRAF', 'TERT', 'APOE', 'COMT', 'BDNF', 'PDE7A', 'IL-6', 'DRD1', 'TCF4', 'RAD51', 'SESN1', 'GSTP1', 'GFAP', 'ALPHA-INTERNEXIN', 'PERIPHERIN', 'VIMENTIN', 'NESTIN', 'SYNEMIN', 'IL-2', 'GMP', 'GFAP', 'S-100', 'HSA', 'CT-H', 'S ...
#
# ['EGFR', 'IDH1/2', 'BRAF', 'BTK', 'SHH', 'SMO', 'AHR', 'IDH1', 'MGMT', 'BRAF', 'RAF', 'MEK', 'EGFR', 'NF1', 'CDKN2A', 'CCND2', 'EGFR', 'MYCN', 'ACID CERAMIDASE', 'IDH1', 'PODOPLANIN', 'MET', 'ALK', 'MGMT', 'LDHA', 'NTRK3', 'IDO', 'FOXP3', 'NEUROFIBROMATOSIS TYPE 1', 'BRAF', 'HIP', 'CYCLIN-DEPENDENT KINASE 7', 'GSTS', 'GSTM1', 'GSTT1', 'GSTP1', 'GSTM3', 'PODOPLANIN', 'MGMT', 'ARMS 1P', 'TGF-BETA', 'CTLA-4', 'IDO', 'HER2', 'SCFV', 'SHH', 'IDH', 'CAR', 'DR5', 'IFITM3', 'IFITM3', 'FACS', 'EPIDERMAL GROWTH FACTOR RECEPTOR', 'NESTIN', 'PTEN', 'CDKN2A', 'KCA3.1', 'BRAF', 'V-RAF', 'BRAF', 'LIN28', 'LIN28B', 'DNMT3B', 'MTOR', 'ART', 'O6-METHYLGUANINE-DNA METHYLTRANSFERASE', 'EPIDERMAL GROWTH FACTOR RECEPTOR', 'G9A', 'TEM1', 'TEM1', 'ALPHASMA', 'FIBRONECTIN', 'MYC', 'MYCN', 'BETA-CATENIN', 'INI1', 'IDH', 'ERBB2', 'MET', 'EGFR', 'KNL1', 'ASPM', 'CENPE', 'CITK', 'KIF14', 'GLI-1/2/3', 'E2F1-8', 'STAT3', 'HIF-1/2', 'NFI-A/B', 'MYT1', 'MYT1L', 'NEUROFIBROMATOSIS TYPE 1', 'PARP', 'PARP2', 'BRCA1/2', 'BRCA1', 'SMO', 'CLIC2', 'MMP14', 'CLIC2', 'U87', 'MPR', 'TERT', 'TRF1 AND 2', 'PARP', 'TRF1', 'TRF2', 'SOX2', 'PIK3CA', 'NTRK1', 'GNAS', 'CTNNB1', 'FGFR1', 'CHI3L1', 'IDH1', 'IDH', 'MIR-92B', 'RCBF', 'PDE', 'ANAPLASTIC ASTROCYTOMA (AA) 2', 'MALIGNANT LYMPHOMA (ML) 4', 'FIBRONECTIN', 'MGMT', 'DNA POLYMERASE BETA', 'EPHX1', 'PROGRAMMED CELL DEATH PROTEIN 1', 'HGF/MET', 'HGF', 'RTK', 'MET', 'APT', 'MGMT', 'VEGF', 'MTDH', 'TNF', 'LIN28A', 'IDO', 'NF1', 'KIAA1549', 'BRAF', 'CD4', 'CXCL10', 'MEK', 'CST6', 'CATHEPSIN B', 'PRACTICE', 'MET', 'BMI-1', 'CYTOTOXIC T-LYMPHOCYTE ANTIGEN (CTLA)-4', 'PROGRAMMED CELL DEATH 1/PROGRAMMED CELL DEATH 1 LIGAND', 'PDL1', 'VPF', 'IDH1', 'DESI', 'MGMT', 'IDH1', 'MYCC', 'MYCN', 'BETA-CATENIN', 'FGA', 'FGB', 'XCT', 'C-MET', 'EGFR', 'IDH', 'IGF-IR', 'IGF-I', 'NRSF', 'ZIP', 'GFAP', 'AQ4', 'MGMT', 'IDH1', 'IDH2', 'OCT-4', 'IDH1', 'CD133', 'APOE', 'MGMT', 'GPC2', 'IDH', 'IFN-GAMMA', 'TNF-ALPHA', 'IDH']

# %% [markdown]
# testing if the gene names total works

# %%
# checking the lengths of the lists
print("length of abstracts list:", len(ab_geneNames))
print("Length of full-text list:", len(ft_geneNames))
print()
print("Do the numbers of total match to the combinination of the abstacts and full-text: ", (len(ab_geneNames) + len(ft_geneNames)) == len(geneNames_TOTAL))
print()
print("total gene names length:", len(geneNames_TOTAL))
print(geneNames_TOTAL)
# Out:
# length of abstracts list: 1256
# Length of full-text list: 185
#
# Do the numbers of total match to the combinination of the abstacts and full-text:  True
#
# total gene names length: 1441
# ['AID', 'C-MYC', 'BRAF', 'TRAIL', 'PDGFR', 'GH', 'MGMT', 'MRS', 'PRACTICE', 'P-GP', 'CSF', 'DICER', 'RISC', 'RAC3', 'MET', 'MIB-1', 'P53', 'SEP', 'ABR', 'CAM', 'PS 2', 'ACETYLCHOLINESTERASE', 'IDH', 'TR', 'VEGF', 'IL-4', 'TRAIL', 'AID', 'ECM', 'GLIAL FIBRILLARY ACIDIC PROTEIN, S-100', 'VIMENTIN', 'GPS', 'GLUTATHIONE REDUCTASE', 'SOD-1', 'ODC', 'CRT', 'CAT B', 'GLIAL FIBRILLARY ACIDIC PROTEIN', 'ALPHA-FETOPROTEIN', 'CCNU', 'AID', 'LAC', 'LIP', 'COX-2', 'EP4', 'SYNAPTOPHYSIN', 'FERRITIN HEAVY CHAIN', 'CSK', 'MIB-1', 'GFAP', 'NNOS', 'INOS', 'ENOS', 'ORNITHINE DECARBOXYLASE', 'GOPC', 'ROS1', 'CDK4', 'NF1', 'KIAA1549', 'BRAF', 'INI-1', 'EZH2', 'P53', 'ADRENOCORTICOTROPIC HORMONE', 'EPIDERMAL GROWTH FACTOR RECEPTOR', 'C-MYC', 'PIA', 'MGMT', 'TNM', 'NMT', 'NMT2', 'P53', 'UPA', 'PLASMIN', 'CEA', 'GLIAL FIBRILLARY ACIDIC PROTEIN', 'APOLIPOPROTEIN E', 'FOXR2', 'BCOR', 'P53', 'ATM', 'CYCLIN D2', 'EGFR', 'AKT', 'TP53', 'IDH1', 'PIK3CA', 'PTEN', 'EGFR', 'BRAF', 'CTNNB1', 'AKT', 'PTEN', 'CELL SURFACE RECEPTOR', 'PART 5', 'BAX', 'BCL-2', 'CFLIP, EFFECTOR CASPASES', 'AKT', 'TRANSFORMING GROWTH FACTOR BETA', 'TGF-BETA', 'BIKUNIN', 'FIBRONECTIN', 'AQP4', 'CYTOCHROME C', 'BCL-2', 'IDO1', 'TDO', 'AHR', 'LINC00461', 'MIR-216A', 'NEU4', 'CTBS', 'GBA2', 'CTSC', 'CTSK', 'CTSF', 'ARMS 1P', 'IDH1', 'IDH2', 'MGMT', 'VEGF', 'EGFR', 'BETA-CATENIN', 'CD45RO', 'GFAP', 'PPARDELTA', 'PPARGAMMA', 'CDKN2A', 'EGFR', 'PDGFRA', 'PTEN', 'CDK4', 'KIT', 'PIK3CA', 'MDM2', 'IDH', 'MGMT', 'ABCB1', 'NGAL', 'TP53', 'MGMT', 'CDC6', 'MCM5', 'MIB-1', 'GROWTH HORMONE', 'GH', 'CAR', 'ITK', 'MGMT', 'IDH', 'VEGF', 'TENASCIN', 'GFAP', 'NSE', 'MBP', 'PSK', 'LYN', 'CAR', 'ATRX', 'TP53', 'P53', 'MDM2', 'PRACTICE', 'INOS', 'MET-ENKEPHALIN', 'PREPROENKEPHALIN', 'HCG', 'GONADOTROPIN-RELEASING HORMONE', 'TNM', 'TAPASIN', 'IFNGAMMA', 'XRCC3', 'MET', 'IDH', 'GAL-3', 'BETA-GALACTOSIDE-BINDING LECTIN', 'P-GLYCOPROTEIN', 'RAD', 'CEA', 'MUL', 'MDR1', 'PGP', 'CD133', 'CHK1', 'CHK2', 'ENDOSTATIN', 'MDM2', 'INK4A', 'IGF-I', 'H15', 'CD4', 'TRK', 'EPIDERMAL GROWTH FACTOR RECEPTOR', 'PRACTICE', 'TUMOR-REJECTION ANTIGEN', 'SART1', 'IFN-B', 'GFAP', 'GFA', 'GLUTATHIONE S-TRANSFERASE', 'NIR', 'HSA', 'IRGD', 'ALBUMIN', 'BET', 'CDK9', 'AXL', 'BMI1', 'CBP', 'EGFR', 'CDK4', 'CDKN2A', 'TP53', 'DMBT1', 'NF2', 'PTEN', 'MIB-1', 'BCL-2', 'BCL-X', 'BAX', 'ICE', 'ICH-1', 'FAS LIGAND', 'P53', 'NF1', 'EPIDERMAL GROWTH FACTOR RECEPTOR', 'TRANSFORMING GROWTH FACTOR-ALPHA AND -BETA', 'C-MYC', 'C-FOS', 'INSULIN-LIKE GROWTH FACTOR I AND II', 'C-ERB B-2', 'SAO', 'AID', 'CRNN', 'NEUROFIBROMATOSIS 1', 'FUS', 'GROWTH HORMONE', 'MGMT', 'EGFR', 'ATRX', 'TERT', 'BRAF', 'DNMT', 'TTYH1', 'DNMT3B', 'MGMT', 'AQP4', 'IDH', 'MAMMALIAN TARGET OF RAPAMYCIN', 'C-REACTIVE PROTEIN', 'ALBUMIN', 'P-GP', 'PRACTICE', 'MTS1', 'GFAP', 'VIMENTIN', 'ALPHA-1-ANTITRYPSIN', 'ALPHA-1-ANTICHYMOTRYPSIN', 'GH', 'SH3PXD2A', 'HTRA1', 'NF2', 'TRAF7', 'KLF4', 'AKT1', 'SMO', 'TERT', 'CDKN2A/B', 'CTLA4', 'PROGRAMMED CELL DEATH 1', 'PDL1', 'KEL', 'CAT', 'ALPHA 1-AT', 'ALPHA 2-MACROGLOBULIN', 'FIBRINOGEN', 'PME', 'GFAP', 'VIMENTIN', 'FIBRONECTIN', 'CD133', 'IDH', 'TERT', 'BRAF', 'H3F3A', 'BRAF', 'IDH1', 'IL-13', 'IL-13RALPHA2', 'VEGF-D', 'AP-1', 'MGMT', 'ESTROGEN RECEPTOR', 'SLT', 'MTX', 'IDH', 'TP53', 'KIAA1549', 'BRAF', 'EGFR', 'TP53', 'CARBONIC ANHYDRASE IX', 'VASCULAR ENDOTHELIAL GROWTH FACTOR', 'PRACTICE', 'MMP', 'MMP-2', 'MMP-9', 'MMP-12', 'TIMP', 'TIMP-2', 'VEGF', 'ELASTIN', 'CIS-4', 'MET', 'AQP-4', 'TAU', 'TP53', 'EGFR', 'GLIAL FIBRILLARY ACIDIC PROTEIN', 'AGE', 'ACTH', 'SPIN', 'MAMMALIAN TARGET OF RAPAMYCIN', 'BCOR', 'RAF1', 'BRAF', 'ASXL1', 'MAP2K1', 'EGFR', 'PDGFR', 'VEGF', 'AKT', 'MTOR', 'EGFR', 'BRAF', 'PDGF-B', 'TTR', 'AGE', 'CD133', 'CD4', 'LCA', 'MMP-2', 'GROWTH HORMONE', 'TP53', 'AGE', 'UPA', 'PAI-1', 'TPA', 'PKC', 'IDH1', 'BRAF', 'TERT', 'APOE', 'COMT', 'BDNF', 'PDE7A', 'IL-6', 'DRD1', 'TCF4', 'RAD51', 'SESN1', 'GSTP1', 'GFAP', 'ALPHA-INTERNEXIN', 'PERIPHERIN', 'VIMENTIN', 'NESTIN', 'SYNEMIN', 'IL-2', 'GMP', 'GFAP', 'S-100', 'HSA', 'CT-H', 'S ...

# %% [markdown]
# ## Analyzing the Data

# %% [markdown]
# ### <span style="color:red">Frequency Table of Abstracts</span>

# %%
# Full Frequency Table for Abstracts
import pandas as pd

# Create a DataFrame and count number of times of each gene name
ab_df = pd.DataFrame({'Gene Names': ab_geneNames})
ab_freq_table = ab_df['Gene Names'].value_counts().reset_index()
ab_freq_table.columns = ['Gene Names', 'Frequency']

# Display the frequency table
pd.set_option('display.max_rows', None)
print(ab_freq_table)
# Out:
#                                            Gene Names  Frequency
# 0                                                GFAP         29
# 1                                                BRAF         27
# 2                                                EGFR         26
# 3                                                MGMT         25
# 4                                                 IDH         25
# 5                                                 P53         21
# 6                                               MIB-1         18
# 7                                                TP53         17
# 8                                                VEGF         15
# 9                                                PTEN         15
# 10                                               IDH1         11
# 11                                               IL-2         11
# 12                                           VIMENTIN         10
# 13                   EPIDERMAL GROWTH FACTOR RECEPTOR          9
# 14                                              BCL-2          9
# 15                                      SYNAPTOPHYSIN          9
# 16                                                AID          9
# 17                                              CD133          9
# 18                                              C-MYC          8
# 19                                                NF1          8
# 20                    GLIAL FIBRILLARY ACIDIC PROTEIN          8
# 21                                                 GH          7
# 22                                               MTOR          7
# 23                 VASCULAR ENDOTHELIAL GROWTH FACTOR          7
# 24                                           PRACTICE          7
# 25                                                AKT          7
# 26                                     GROWTH HORMONE          7
# 27                                            ALBUMIN          6
# 28                                                CEA          6
# 29                                               ATRX          6
# 30                                               TERT          6
# 31                                                CD4          6
# 32                                              H3F3A          6
# 33                                             CDKN2A          6
# 34                                                MET          6
# 35                                          TNF-ALPHA          5
# 36                                           KIAA1549          5
# 37                                               CDK4          5
# 38                                               MDM2          5
# 39                                                NF2          5
# 40                                                TNF          4
# 41                                              OLIG2          4
# 42                                              TRAIL          4
# 43                                                AGE          4
# 44                                               ACTH          4
# 45                                             NESTIN          4
# 46                                                NSE          4
# 47                                                MYC          4
# 48                                                SHH          4
# 49                                               BFGF          4
# 50                                                MEG          4
# 51                                                P16          4
# 52                                               AQP4          4
# 53                                             IDH1/2          4
# 54                                               PCNA          4
# 55                                           CATALASE          4
# 56                                   INTERFERON-GAMMA          4
# 57                                                GST          3
# 58                                        TRANSFERRIN          3
# 59                                                BAX          3
# 60                                                TAU          3
# 61                                        FIBRONECTIN          3
# 62                                               RAC1          3
# 63                                              PAI-1          3
# 64                                                ERK          3
# 65                                              GSTP1          3
# 66                                                ADC          3
# 67                                              RIL-2          3
# 68                                               IDH2          3
# 69                                       BETA-CATENIN          3
# 70                                              VP-16          3
# 71                            EPIDERMAL GROWTH FACTOR          3
# 72                                                MBP          3
# 73                                              C-MET          3
# 74                           NEUROFIBROMATOSIS TYPE 1          3
# 75                                                NEU          3
# 76                                                CSF          3
# 77                                                RAD          3
# 78                                               RAGE          3
# 79                                         FIBRINOGEN          3
# 80                                                TNM          3
# 81                                              PDGFR          3
# 82                                                UPA          3
# 83                                                GFA          3
# 84                                                CAT          3
# 85                                                MRS          3
# 86                                                CAR          3
# 87                                             PIK3CA          3
# 88                                             MAP2K1          2
# 89                                              UBE4B          2
# 90                                      TISSUE FACTOR          2
# 91                                NEUROFIBROMATOSIS 1          2
# 92                           RECEPTOR TYROSINE KINASE          2
# 93                                                FUS          2
# 94                                            SMARCB1          2
# 95                                              S-100          2
# 96                                           IFN-BETA          2
# 97                                               E2F1          2
# 98                                       IL-13RALPHA2          2
# 99                      MAMMALIAN TARGET OF RAPAMYCIN          2
# 100                                C-REACTIVE PROTEIN          2
# 101                                              SV2A          2
# 102                                          CDKN2A/B          2
# 103                                              MYCN          2
# 104                                               ABO          2
# 105                                             MMP-2          2
# 106                                             RAD51          2
# 107                                              PDL1          2
# 108                                              IL-6          2
# 109                                              APOE          2
# 110                                             HIF-1          2
# 111                                            GLUT-1          2
# 112                                            PDGF-B          2
# 113                                 ESTROGEN RECEPTOR          2
# 114                                              SAGE          2
# 115                                              HER2          2
# 116                                               MEK          2
# 117                                         CYCLIN D1          2
# 118                                              BMI1          2
# 119                                              C-11          2
# 120                                             EGR-1          2
# 121                                               MER          2
# 122                                               FLT          2
# 123                                               CD8          2
# 124                                               CYP          2
# 125                                              NEUN          2
# 126                                              EPOR          2
# 127                                               EPO          2
# 128                                           INSULIN          2
# 129                                               EGF          2
# 130                                                PH          2
# 131                                              DDR1          2
# 132                                    ANGIOTENSIN II          2
# 133                                               PSF          2
# 134                                              RELA          2
# 135                              BETA 2-MICROGLOBULIN          2
# 136                                           TGFBETA          2
# 137                                             FGFR1          2
# 138                                               AFP          2
# 139                                               TSC          2
# 140                PROLIFERATING CELL NUCLEAR ANTIGEN          2
# 141                                            MIR-21          2
# 142                                     IL-2 RECEPTOR          2
# 143                                              FHIT          2
# 144                                            ICAM-1          2
# 145                                             GSTM1          2
# 146                                             GSTT1          2
# 147                                               JNK          2
# 148                                              RCBF          2
# 149                                               GD3          2
# 150                                  CYCLOOXYGENASE-2          2
# 151                                              GRPR          2
# 152                        BONE MORPHOGENETIC PROTEIN          2
# 153                                              MSH6          2
# 154                                     METHEMOGLOBIN          2
# 155                                                TF          2
# 156                                               TIL          2
# 157                                             COX-2          2
# 158                                               PSK          2
# 159                                             IGF-I          2
# 160                       ADRENOCORTICOTROPIC HORMONE          2
# 161                                               PGP          2
# 162                                              MDR1          2
# 163                                               MUL          2
# 164                                             FOXR2          2
# 165                                              BCOR          2
# 166                                            CTNNB1          2
# 167                                              INOS          2
# 168                                            PART 5          2
# 169                                                TR          2
# 170                                               KIT          2
# 171                                            PDGFRA          2
# 172                                          TGF-BETA          2
# 173                                           ARMS 1P          2
# 174                                              CCNU          2
# 175                                             SOD-1          2
# 176                                    P-GLYCOPROTEIN          2
# 177                                 ALPHA-FETOPROTEIN          2
# 178                                               HSA          2
# 179                                              P-GP          2
# 180                                               CB1          1
# 181                                              IL-4          1
# 182                                           GASTRIN          1
# 183                                  GASTRIN RECEPTOR          1
# 184                                              RAC2          1
# 185                                               BIK          1
# 186                    MYELIN-ASSOCIATED GLYCOPROTEIN          1
# 187                                           TP53BP1          1
# 188                                             FANCG          1
# 189                                             ALA/S          1
# 190                                               ECM          1
# 191                                            CH-TOG          1
# 192                                             LEU 7          1
# 193                                                TN          1
# 194                                        E-CADHERIN          1
# 195                                                SE          1
# 196                                               P44          1
# 197                                               P25          1
# 198                                             PARP1          1
# 199                                             RHO C          1
# 200                                               SNO          1
# 201                                              KRAS          1
# 202                                              SALP          1
# 203                                         ANNEXIN V          1
# 204                                              CMET          1
# 205                                              NAT2          1
# 206                                               XCT          1
# 207                                          MUC 8-22          1
# 208                                             TWIST          1
# 209                                             HESRG          1
# 210                              ACETYLCHOLINESTERASE          1
# 211                                              NADE          1
# 212                                               P21          1
# 213                                               NFH          1
# 214                                            PARP-1          1
# 215                                               PLP          1
# 216                                           OLIG1/2          1
# 217                                             OLIG1          1
# 218                                              TIC1          1
# 219                                             TCF-4          1
# 220                                               RAC          1
# 221                                            LAMP-1          1
# 222                                             CASP8          1
# 223                               INTERFERON-ALPHA 2B          1
# 224                             TUMOR NECROSIS FACTOR          1
# 225                                               P13          1
# 226                                               P12          1
# 227                                              C-14          1
# 228                                              P-31          1
# 229                                     MIN(-1) 100 G          1
# 230                                               PSR          1
# 231                                   SERINE PROTEASE          1
# 232                                     INTERLEUKIN-2          1
# 233                                              CPOX          1
# 234            GLIAL FIBRILLARY ACIDIC PROTEIN, S-100          1
# 235                                               GPS          1
# 236                                              A 20          1
# 237                                          NECTIN-1          1
# 238                             GLUTATHIONE REDUCTASE          1
# 239                                              SUR1          1
# 240                                              FARR          1
# 241                       ADAMS 8, 12, 15, 17, AND 19          1
# 242                                              CD34          1
# 243                                            ADAM19          1
# 244                                             ADAM8          1
# 245                                               CPM          1
# 246                                             VP 16          1
# 247                                              CHOP          1
# 248                                             AQP 4          1
# 249                                            ENDO 1          1
# 250                                        CALMODULIN          1
# 251                                               CB2          1
# 252                                          HDAC1-11          1
# 253                                              NPM1          1
# 254                                        PROMININ-1          1
# 255                                            CXCL12          1
# 256                                               ODC          1
# 257                                        AQP1 AND 4          1
# 258                                              AQP1          1
# 259          O-6 METHYLGUANINE- DNA METHYLTRANSFERASE          1
# 260                                            CATH D          1
# 261                                               CRT          1
# 262                                              BAI1          1
# 263                                              HPSE          1
# 264                                              HSPG          1
# 265                   TRANSFORMING GROWTH FACTOR-BETA          1
# 266                                             ERCC3          1
# 267                                              MMPS          1
# 268                                              CD45          1
# 269                                              PD-1          1
# 270                                           FACSTAR          1
# 271                                             TNKS2          1
# 272                                              TNKS          1
# 273                                           TERF2IP          1
# 274                                              TEP1          1
# 275                                              PS 2          1
# 276                                              LIG4          1
# 277                                           GADD45G          1
# 278                                        GALECTIN-3          1
# 279                                      AQP-1 AND -4          1
# 280                                             CAT B          1
# 281                                              BMP4          1
# 282                                              DDB2          1
# 283                                              SOD1          1
# 284                                              ETS2          1
# 285                                             SOX10          1
# 286                                             SNAI2          1
# 287                                               GSC          1
# 288                                             FOXC2          1
# 289                                              CDH2          1
# 290                                            IGFBP7          1
# 291                                              TPEF          1
# 292                                            G-CSFR          1
# 293                                             N-RAS          1
# 294                                              IL 1          1
# 295                  TYPE II IODOTHYRONINE DEIODINASE          1
# 296                                       PROTHROMBIN          1
# 297                                             HLA-A          1
# 298                                             LEU 1          1
# 299                                        TGF-BETA 1          1
# 300                                              ET-1          1
# 301                                             G-CSF          1
# 302                                         MUSASHI-1          1
# 303                                              SOX2          1
# 304                                            OLIG-2          1
# 305                                           CORD 20          1
# 306                                              LAT1          1
# 307                                        CSF, 3/230          1
# 308                                             PHS-1          1
# 309                                               PHS          1
# 310                                             PHS-2          1
# 311                                             THY-1          1
# 312                                             CD141          1
# 313                                        ENDOSIALIN          1
# 314                                               APR          1
# 315                                      NK1 RECEPTOR          1
# 316                                                SP          1
# 317                             VEGF,-PIGF,-HIF1ALPHA          1
# 318                                            VEGFR2          1
# 319                                               AGA          1
# 320                                 ALPHA(V) INTEGRIN          1
# 321                                             POMT1          1
# 322                                         IFN GAMMA          1
# 323                                              IL 3          1
# 324                                              SUFU          1
# 325                                              IL 6          1
# 326                                               ALP          1
# 327                                          NY-ESO-1          1
# 328                                              HDM2          1
# 329                                              MRP1          1
# 330                                              INCA          1
# 331                                               ABC          1
# 332                                          SLC22A18          1
# 333                                             TRIM3          1
# 334                                             TSSC3          1
# 335                                              IGF2          1
# 336                                             OCT-2          1
# 337                                           N-OCT-3          1
# 338                                             OCT-1          1
# 339                                               OCT          1
# 340                                               SKN          1
# 341                                             APO2L          1
# 342                                             DICER          1
# 343                                              PMS2          1
# 344                                              MSH2          1
# 345                                              MLH1          1
# 346            O6-METHYLGUANINE-DNA METHYLTRANSFERASE          1
# 347                                             SDF-1          1
# 348                                               PRL          1
# 349                                              NPCR          1
# 350                                               IL2          1
# 351                                        IFN BETA 1          1
# 352                                        TGF BETA 2          1
# 353                                   INTERFERON-BETA          1
# 354                                              L3-5          1
# 355                                              TN-C          1
# 356                                              RISC          1
# 357                                               GLI          1
# 358                                               SAS          1
# 359                                            MYD116          1
# 360                                               NOC          1
# 361                                        HIF-1ALPHA          1
# 362                                              DAXX          1
# 363                                             FUBP1          1
# 364                                               CIC          1
# 365                                               CPA          1
# 366                                             PD-L1          1
# 367                                             TSP-1          1
# 368                                              HIL2          1
# 369                                            CYP2C9          1
# 370                                               TCR          1
# 371                                              AXIN          1
# 372                                               CAM          1
# 373                                         PROLACTIN          1
# 374                                     INTERLEUKIN-4          1
# 375  GRANULOCYTE-MACROPHAGE COLONY-STIMULATING FACTOR          1
# 376                                         IFN-ALPHA          1
# 377                                             HTERT          1
# 378                                                GK          1
# 379                                            MPRAGE          1
# 380                                               CRP          1
# 381                                             SPARC          1
# 382                                        PDGFRALPHA          1
# 383                                             ERBB2          1
# 384                                               ABR          1
# 385                                             N MYC          1
# 386                                             MYCL1          1
# 387                                               CTX          1
# 388                                             IL-10          1
# 389                                        PODOPLANIN          1
# 390                                             CD 68          1
# 391                           NEURON-SPECIFIC ENOLASE          1
# 392                                         ROD-OPSIN          1
# 393                                              RAC3          1
# 394                                           C8ORF46          1
# 395                                            PPFIA4          1
# 396                                             CSPG4          1
# 397                                           GPR37L1          1
# 398                                           NCKAP1L          1
# 399                                               HUB          1
# 400                                             CD62L          1
# 401                                           GADD153          1
# 402                                            CTLA-4          1
# 403                                             FOXP3          1
# 404                                             IDH-1          1
# 405                                             MYBL1          1
# 406                                               QKI          1
# 407                                               MYB          1
# 408                                               SEP          1
# 409                                               JOS          1
# 410                                             VEGFR          1
# 411                                               LIF          1
# 412                                               IFN          1
# 413                                              A2MR          1
# 414                                             STAT3          1
# 415                                               AXL          1
# 416                                            PTPN11          1
# 417                                              CTSK          1
# 418                                                 A          1
# 419                                          TENASCIN          1
# 420                                              CT-H          1
# 421                                               LYN          1
# 422                                               GMP          1
# 423                                    MET-ENKEPHALIN          1
# 424                                           SYNEMIN          1
# 425                                  PREPROENKEPHALIN          1
# 426                                        PERIPHERIN          1
# 427                                  ALPHA-INTERNEXIN          1
# 428                                               HCG          1
# 429                                             SESN1          1
# 430                    GONADOTROPIN-RELEASING HORMONE          1
# 431                                              TCF4          1
# 432                                              DRD1          1
# 433                                           TAPASIN          1
# 434                                             PDE7A          1
# 435                                              BDNF          1
# 436                                              COMT          1
# 437                                          IFNGAMMA          1
# 438                                               PKC          1
# 439                                               TPA          1
# 440                                             XRCC3          1
# 441                                               LCA          1
# 442                                               TTR          1
# 443                                             GAL-3          1
# 444                   BETA-GALACTOSIDE-BINDING LECTIN          1
# 445                                        PROTEINASE          1
# 446                                             MIB.1          1
# 447                                               ITK          1
# 448                                         MIRNA-221          1
# 449                                          TGFBETA3          1
# 450                                          TGFBETA2          1
# 451                                          TGFBETA1          1
# 452                                            LEPTIN          1
# 453                                            CD45RO          1
# 454                  TRANSFORMING GROWTH FACTOR-ALPHA          1
# 455                                         PPARDELTA          1
# 456                                         PPARGAMMA          1
# 457                      INSULIN-LIKE GROWTH FACTOR I          1
# 458                       POLY(ADP-RIBOSE) POLYMERASE          1
# 459                                         CASPASE-3          1
# 460                                       FACTOR VIII          1
# 461                                            DNA-PK          1
# 462                                               VPF          1
# 463                                        S-100 BETA          1
# 464                                             ABCB1          1
# 465                                              NGAL          1
# 466               METHYLGUANINE-DNA METHYLTRANSFERASE          1
# 467                                             T2/B2          1
# 468                                             T1/B1          1
# 469                                            MARK 3          1
# 470                                              MARK          1
# 471                                         TGF-BETA1          1
# 472                                              CDC6          1
# 473                                              MCM5          1
# 474                                             CAV-1          1
# 475                                             ASXL1          1
# 476                                              RAF1          1
# 477                                              SPIN          1
# 478                                              IRGD          1
# 479                                             TRAF7          1
# 480                                             HTRA1          1
# 481                                          SH3PXD2A          1
# 482                          ALPHA-1-ANTICHYMOTRYPSIN          1
# 483                               ALPHA-1-ANTITRYPSIN          1
# 484                                              MTS1          1
# 485                                             IFN-B          1
# 486                         GLUTATHIONE S-TRANSFERASE          1
# 487                                            DNMT3B          1
# 488                                             TTYH1          1
# 489                                              DNMT          1
# 490                                               NIR          1
# 491                                              CRNN          1
# 492                                              AKT1          1
# 493                                               SAO          1
# 494                                         C-ERB B-2          1
# 495               INSULIN-LIKE GROWTH FACTOR I AND II          1
# 496                                             C-FOS          1
# 497        TRANSFORMING GROWTH FACTOR-ALPHA AND -BETA          1
# 498                                        FAS LIGAND          1
# 499                                             ICH-1          1
# 500                                               ICE          1
# 501                                             BCL-X          1
# 502                                               BET          1
# 503                                             DMBT1          1
# 504                                               CBP          1
# 505                                              KLF4          1
# 506                                               SMO          1
# 507                                             AQP-4          1
# 508                                        ENDOSTATIN          1
# 509                                             CIS-4          1
# 510                                           ELASTIN          1
# 511                                            TIMP-2          1
# 512                                              TIMP          1
# 513                                            MMP-12          1
# 514                                             MMP-9          1
# 515                                              CHK1          1
# 516                                               MMP          1
# 517                                              CHK2          1
# 518                             CARBONIC ANHYDRASE IX          1
# 519                                               MTX          1
# 520                                               SLT          1
# 521                                              AP-1          1
# 522                                             SART1          1
# 523                                            VEGF-D          1
# 524                                             INK4A          1
# 525                                             IL-13          1
# 526                                               PME          1
# 527                                               H15          1
# 528                             ALPHA 2-MACROGLOBULIN          1
# 529                                        ALPHA 1-AT          1
# 530                                               TRK          1
# 531                                               KEL          1
# 532                           TUMOR-REJECTION ANTIGEN          1
# 533                           PROGRAMMED CELL DEATH 1          1
# 534                                             CTLA4          1
# 535                                              CTSF          1
# 536                                              CTSC          1
# 537                                               LAC          1
# 538                                              GBA2          1
# 539                                              PLAP          1
# 540                                              ENOS          1
# 541                                            UCHL-1          1
# 542                                             DREAM          1
# 543                  NADPH CYTOCHROME P-450 REDUCTASE          1
# 544                                     DT-DIAPHORASE          1
# 545                       TUMOR NECROSIS FACTOR-ALPHA          1
# 546                                               MIM          1
# 547                                        PI3KC2BETA          1
# 548                                             C-KIT          1
# 549                                           NANOLUC          1
# 550                                             CASP9          1
# 551                           ORNITHINE DECARBOXYLASE          1
# 552                                               TIP          1
# 553                                              GOPC          1
# 554                                              ROS1          1
# 555                                             SOD-2          1
# 556                                             INI-1          1
# 557                                              EZH2          1
# 558                                               PIA          1
# 559                                   ARMS 1, 2 AND 3          1
# 560                                             MAD-4          1
# 561                                             N-MYC          1
# 562                                               NMT          1
# 563                                       OSTEOPONTIN          1
# 564                                              NMT2          1
# 565                                           PLASMIN          1
# 566                                              TR 1          1
# 567                                               TAG          1
# 568                                               PRB          1
# 569                              FERRITIN HEAVY CHAIN          1
# 570                                    ADRENOMEDULLIN          1
# 571          O(6)-METHYLGUANINE-DNA METHYLTRANSFERASE          1
# 572                                         FACTOR XA          1
# 573                                          THROMBIN          1
# 574                                               LIP          1
# 575                            CANCER-RELATED FATIGUE          1
# 576                                              CDK9          1
# 577                                               EP4          1
# 578                                             MIB 1          1
# 579                                            BCL-XL          1
# 580                                             C-JUN          1
# 581                                              VIII          1
# 582                                              HSF1          1
# 583                                          MIR-106B          1
# 584                                             TRPA1          1
# 585                                             TRPV1          1
# 586                                               CSK          1
# 587                                              BCRP          1
# 588                                               GAB          1
# 589                                              GLS2          1
# 590                                               KGA          1
# 591                                             NKG2D          1
# 592                                           MIR-338          1
# 593                                           MIR-219          1
# 594                                              NNOS          1
# 595                                           MIR-26A          1
# 596                                               MAG          1
# 597                                              YB-1          1
# 598                                             GST-P          1
# 599                                              RHOB          1
# 600                                               P15          1
# 601                                               GHR          1
# 602                                    SONIC HEDGEHOG          1
# 603                   MECHANISTIC TARGET OF RAPAMYCIN          1
# 604                          CFLIP, EFFECTOR CASPASES          1
# 605                   TRANSFORMING GROWTH FACTOR BETA          1
# 606                                  TUMOR SUPPRESSOR          1
# 607                                           BIKUNIN          1
# 608                                      CYTOCHROME C          1
# 609                                              IDO1          1
# 610                                            N-WASP          1
# 611                                               TDO          1
# 612                                              RHOA          1
# 613                                       PCNA/CYCLIN          1
# 614                                            HSP-27          1
# 615                                               AHR          1
# 616                                               PS1          1
# 617                                               NPY          1
# 618                                         LINC00461          1
# 619                                          MIR-216A          1
# 620                                            K1, K2          1
# 621                                               SRC          1
# 622                             FIBROBLAST INTERFERON          1
# 623                                      EGF RECEPTOR          1
# 624                                              NEU4          1
# 625                                              CTBS          1
# 626                              DNA POLYMERASE ALPHA          1
# 627                            CYCLOOXYGENASE (COX)-2          1
# 628                                  APOLIPOPROTEIN E          1
# 629                                         PLASTIN-1          1
# 630                                            STAT-5          1
# 631                                               JAK          1
# 632                                               NAT          1
# 633                                              GS-X          1
# 634                                                GR          1
# 635                                                GS          1
# 636                                               GCL          1
# 637                                              LACS          1
# 638                                              MAP2          1
# 639                                        IL-2RALPHA          1
# 640                                            DESMIN          1
# 641                                    CYTOKERATIN 18          1
# 642                                         FIBULIN-1          1
# 643                                               LOX          1
# 644                          GLUTATHIONE PEROXIDASE 3          1
# 645                              COAGULATION FACTOR V          1
# 646                                     TRANSTHYRETIN          1
# 647                                   STANNIOCALCIN-1          1
# 648                                            KIR7.1          1
# 649                                              CDT1          1
# 650                                               ATM          1
# 651                                        CALCITONIN          1
# 652                                         CYCLIN D2          1
# 653                                              X-CT          1
# 654                             CELL SURFACE RECEPTOR          1
# 655                                        K1, K2, K3          1
# 656                                           GEMININ          1

# %%
# Top 10 Frequency Table for Abstracts
top_10 = 10
top_ab_geneNames = ab_freq_table.head(top_10)
print(top_ab_geneNames)
# Out:
#   Gene Names  Frequency
# 0       GFAP         29
# 1       BRAF         27
# 2       EGFR         26
# 3       MGMT         25
# 4        IDH         25
# 5        P53         21
# 6      MIB-1         18
# 7       TP53         17
# 8       VEGF         15
# 9       PTEN         15

# %%
# Number of Frequencies that are unique (only have 1) for Full-text
gene_freq1_Abstract = ab_freq_table[ab_freq_table['Frequency'] == 1]
num_geneFreq1_Abstract = len(gene_freq1_Abstract)
print(num_geneFreq1_Abstract)
# Out:
# 477

# %% [markdown]
# ### <span style="color:red"> HTML Frequency Table For Abstracts</span>

# %%
# Count the total number of rows in the table
total_rows = len(ab_freq_table)-1

# Turning the full table to HTML
html_fullAB_table = ab_freq_table.to_html(index=False)

# Writing HTML to a file
with open('full_abstract_table.html', 'w') as file:
    file.write('<!DOCTYPE html>\n<html>\n<head>\n')
    file.write('<style>\n')
    file.write('th {text-align: center;}\n')
    file.write('</style>\n')
    file.write('</head>\n<body>\n')
    file.write(f'<h1>Total Number of Rows: {total_rows}</h1>\n')  # Include total rows count
    file.write('<h1>Full Abstracts Gene Frequency Table</h1>\n')
    file.write(html_fullAB_table)
    file.write('\n</body>\n</html>')

# %%
# Count the total number of rows in the table
total_rows = len(ab_freq_table) - 1

# Number of Frequencies that are unique (only have 1) for Full-text
gene_freq1_Abstract = ab_freq_table[ab_freq_table['Frequency'] == 1]
num_geneFreq1_Abstract = len(gene_freq1_Abstract)

# Turning the full table to HTML
html_fullAB_table = ab_freq_table.to_html(index=False)

# Writing HTML to a file
with open('full_abstract_table.html', 'w') as file:
    file.write('<!DOCTYPE html>\n<html>\n<head>\n')
    file.write('<style>\n')
    file.write('th {text-align: center;}\n')
    file.write('</style>\n')
    file.write('</head>\n<body>\n')
    # Include both total rows and unique count
    file.write(f'<h1>Total Number of Rows: {total_rows}</h1>\n')
    file.write(f'<h1>Number of Unique Frequencies(Frequencies of only 1): {num_geneFreq1_Abstract}</h1>\n')
    file.write('<h1>Full Abstracts Gene Frequency Table</h1>\n')
    file.write(html_fullAB_table)
    file.write('\n</body>\n</html>')

# %% [markdown]
# ## <span style="color:red">Frequency Table for Full-text</span>

# %%
# Full Frequency Table of Full Text
ft_df = pd.DataFrame({'Gene Names': ft_geneNames})
ft_freq_table = ft_df['Gene Names'].value_counts().reset_index()
ft_freq_table.columns = ['Gene Names', 'Frequency']

# Display the frequency table
pd.set_option('display.max_rows', None)
print(ft_freq_table)
# Out:
#                                             Gene Names  Frequency
# 0                                                 MGMT          8
# 1                                                 IDH1          7
# 2                                                 BRAF          6
# 3                                                  IDH          6
# 4                                                 EGFR          5
# 5                                                  MET          4
# 6                                                  IDO          3
# 7                                                 MYCN          3
# 8                                           PODOPLANIN          2
# 9                                                CLIC2          2
# 10                                                PARP          2
# 11                                        BETA-CATENIN          2
# 12                                         FIBRONECTIN          2
# 13                                                TEM1          2
# 14                    EPIDERMAL GROWTH FACTOR RECEPTOR          2
# 15                            NEUROFIBROMATOSIS TYPE 1          2
# 16                                              IFITM3          2
# 17                                                 SHH          2
# 18                                                 SMO          2
# 19                                                 NF1          2
# 20                                              CDKN2A          2
# 21                                                 MEK          2
# 22                           MALIGNANT LYMPHOMA (ML) 4          1
# 23                                 DNA POLYMERASE BETA          1
# 24                                               EPHX1          1
# 25                     PROGRAMMED CELL DEATH PROTEIN 1          1
# 26                                               OCT-4          1
# 27                                                 PDE          1
# 28                                             HGF/MET          1
# 29                                                GPC2          1
# 30                                                 HGF          1
# 31                                                APOE          1
# 32                                                 RTK          1
# 33                       ANAPLASTIC ASTROCYTOMA (AA) 2          1
# 34                                                RCBF          1
# 35                                                VEGF          1
# 36                                             MIR-92B          1
# 37                                              CHI3L1          1
# 38                                               FGFR1          1
# 39                                              CTNNB1          1
# 40                                                GNAS          1
# 41                                               NTRK1          1
# 42                                              PIK3CA          1
# 43                                                SOX2          1
# 44                                                TRF2          1
# 45                                                TRF1          1
# 46                                           IFN-GAMMA          1
# 47                                          TRF1 AND 2          1
# 48                                                 APT          1
# 49                                                 TNF          1
# 50                                                MTDH          1
# 51                                                DESI          1
# 52                                                 AQ4          1
# 53                                                GFAP          1
# 54                                               CD133          1
# 55                                                 ZIP          1
# 56                                                NRSF          1
# 57                                               IGF-I          1
# 58                                              IGF-IR          1
# 59                                               C-MET          1
# 60                                                 XCT          1
# 61                                                 FGB          1
# 62                                                 FGA          1
# 63                                                MYCC          1
# 64                                                 VPF          1
# 65                                                IDH2          1
# 66                                                PDL1          1
# 67   PROGRAMMED CELL DEATH 1/PROGRAMMED CELL DEATH ...          1
# 68             CYTOTOXIC T-LYMPHOCYTE ANTIGEN (CTLA)-4          1
# 69                                               BMI-1          1
# 70                                                 MPR          1
# 71                                            PRACTICE          1
# 72                                         CATHEPSIN B          1
# 73                                                CST6          1
# 74                                              CXCL10          1
# 75                                                 CD4          1
# 76                                            KIAA1549          1
# 77                                              LIN28A          1
# 78                                                TERT          1
# 79                                             HIF-1/2          1
# 80                                                 U87          1
# 81                                              KCA3.1          1
# 82                                              NESTIN          1
# 83                                                FACS          1
# 84                                                 DR5          1
# 85                                                 CAR          1
# 86                                                SCFV          1
# 87                                                HER2          1
# 88                                              CTLA-4          1
# 89                                            TGF-BETA          1
# 90                                             ARMS 1P          1
# 91                                               GSTM3          1
# 92                                               GSTP1          1
# 93                                               GSTT1          1
# 94                                               GSTM1          1
# 95                                                GSTS          1
# 96                           CYCLIN-DEPENDENT KINASE 7          1
# 97                                                 HIP          1
# 98                                               FOXP3          1
# 99                                               NTRK3          1
# 100                                               LDHA          1
# 101                                                ALK          1
# 102                                    ACID CERAMIDASE          1
# 103                                              CCND2          1
# 104                                                RAF          1
# 105                                                AHR          1
# 106                                                BTK          1
# 107                                               PTEN          1
# 108                                              V-RAF          1
# 109                                              MMP14          1
# 110                                              LIN28          1
# 111                                              BRCA1          1
# 112                                            BRCA1/2          1
# 113                                              PARP2          1
# 114                                              MYT1L          1
# 115                                               MYT1          1
# 116                                            NFI-A/B          1
# 117                                             IDH1/2          1
# 118                                              STAT3          1
# 119                                             E2F1-8          1
# 120                                          GLI-1/2/3          1
# 121                                              KIF14          1
# 122                                               CITK          1
# 123                                              CENPE          1
# 124                                               ASPM          1
# 125                                               KNL1          1
# 126                                              ERBB2          1
# 127                                               INI1          1
# 128                                                MYC          1
# 129                                           ALPHASMA          1
# 130                                                G9A          1
# 131             O6-METHYLGUANINE-DNA METHYLTRANSFERASE          1
# 132                                                ART          1
# 133                                               MTOR          1
# 134                                             DNMT3B          1
# 135                                             LIN28B          1
# 136                                          TNF-ALPHA          1

# %%
# Top 10 frequency table for Full text
top_ten = 10
top_ft_geneNames = ft_freq_table.head(top_ten)
print(top_ft_geneNames)
# Out:
#    Gene Names  Frequency
# 0        MGMT          8
# 1        IDH1          7
# 2        BRAF          6
# 3         IDH          6
# 4        EGFR          5
# 5         MET          4
# 6         IDO          3
# 7        MYCN          3
# 8  PODOPLANIN          2
# 9       CLIC2          2

# %%
# Number of Frequencies that are unique (only have 1) for Full-text
gene_freq1_FullText = ft_freq_table[ft_freq_table['Frequency'] == 1]
num_geneFreq1_FullText = len(gene_freq1_FullText)
print(num_geneFreq1_FullText)
# Out:
# 115

# %% [markdown]
# ### <span style="color:red"> HTML Frequency Table For Full-Text</span>

# %%
# Count the total number of rows in the table
total_rows = len(ft_freq_table)-1

# Turning the full table to HTML
html_fullText_table = ft_freq_table.to_html(index=False)

# Writing HTML to a file
with open('full_full-text_table.html', 'w') as file:
    file.write('<!DOCTYPE html>\n<html>\n<head>\n')
    file.write('<style>\n')
    file.write('th {text-align: center;}\n')
    file.write('</style>\n')
    file.write('</head>\n<body>\n')
    file.write(f'<h1>Total Number of Rows: {total_rows}</h1>\n')  # Include total rows count
    file.write('<h1>Full: Full-Text Gene Frequency Table</h1>\n')
    file.write(html_fullText_table)
    file.write('\n</body>\n</html>')

# %%
# Count the total number of rows in the table
total_rows = len(ft_freq_table) - 1

# Number of Frequencies that are unique (only have 1) for Full-text
gene_freq1_FullText = ft_freq_table[ft_freq_table['Frequency'] == 1]
num_geneFreq1_FullText = len(gene_freq1_FullText)

# Turning the full table to HTML
html_fullText_table = ft_freq_table.to_html(index=False)

# Writing HTML to a file
with open('full_full-text_table.html', 'w') as file:
    file.write('<!DOCTYPE html>\n<html>\n<head>\n')
    file.write('<style>\n')
    file.write('th {text-align: center;}\n')
    file.write('</style>\n')
    file.write('</head>\n<body>\n')
    # Include both total rows and unique count
    file.write(f'<h1>Total Number of Rows: {total_rows}</h1>\n')
    file.write(f'<h1>Number of Unique Frequencies(Frequencies of only 1): {num_geneFreq1_FullText}</h1>\n')
    file.write('<h1>Full: Full-Text Gene Frequency Table</h1>\n')
    file.write(html_fullText_table)
    file.write('\n</body>\n</html>')

# %% [markdown]
# ### <span style="color:red"> Frequency Table of Gene Names In Total </span>

# %%
# Full Frequency Table for Total Amount of Gene Names
TOTAL_df = pd.DataFrame({'Gene Names': geneNames_TOTAL})
TOTAL_freq_table = TOTAL_df['Gene Names'].value_counts().reset_index()
TOTAL_freq_table.columns = ['Gene Names', 'Frequency']

# Display the frequency table
pd.set_option('display.max_rows', None)
print(TOTAL_freq_table)
# Out:
#                                             Gene Names  Frequency
# 0                                                 BRAF         33
# 1                                                 MGMT         33
# 2                                                  IDH         31
# 3                                                 EGFR         31
# 4                                                 GFAP         30
# 5                                                  P53         21
# 6                                                 IDH1         18
# 7                                                MIB-1         18
# 8                                                 TP53         17
# 9                                                 VEGF         16
# 10                                                PTEN         16
# 11                    EPIDERMAL GROWTH FACTOR RECEPTOR         11
# 12                                                IL-2         11
# 13                                               CD133         10
# 14                                            VIMENTIN         10
# 15                                                 MET         10
# 16                                                 NF1         10
# 17                                               BCL-2          9
# 18                                                 AID          9
# 19                                       SYNAPTOPHYSIN          9
# 20                                               C-MYC          8
# 21                                            PRACTICE          8
# 22                                                MTOR          8
# 23                                              CDKN2A          8
# 24                     GLIAL FIBRILLARY ACIDIC PROTEIN          8
# 25                                                TERT          7
# 26                  VASCULAR ENDOTHELIAL GROWTH FACTOR          7
# 27                                      GROWTH HORMONE          7
# 28                                                  GH          7
# 29                                                 CD4          7
# 30                                                 AKT          7
# 31                                               H3F3A          6
# 32                                                 CEA          6
# 33                                                 SHH          6
# 34                                            KIAA1549          6
# 35                                             ALBUMIN          6
# 36                                                ATRX          6
# 37                                           TNF-ALPHA          6
# 38                                                 MYC          5
# 39                                        BETA-CATENIN          5
# 40                                                CDK4          5
# 41                                                MDM2          5
# 42                                              NESTIN          5
# 43                                                MYCN          5
# 44                            NEUROFIBROMATOSIS TYPE 1          5
# 45                                              IDH1/2          5
# 46                                                 TNF          5
# 47                                         FIBRONECTIN          5
# 48                                                 NF2          5
# 49                                                 AGE          4
# 50                                                ACTH          4
# 51                                                 CAR          4
# 52                                                 NSE          4
# 53                                                AQP4          4
# 54                                              PIK3CA          4
# 55                                                IDH2          4
# 56                                                 P16          4
# 57                                                 MEG          4
# 58                                               GSTP1          4
# 59                                               TRAIL          4
# 60                                                BFGF          4
# 61                                               C-MET          4
# 62                                                PCNA          4
# 63                                    INTERFERON-GAMMA          4
# 64                                                 MEK          4
# 65                                               OLIG2          4
# 66                                            CATALASE          4
# 67                                               FGFR1          3
# 68                                               IGF-I          3
# 69                                                 RAD          3
# 70                                               PAI-1          3
# 71                                               RIL-2          3
# 72                                                 MBP          3
# 73                                                 GFA          3
# 74                                          PODOPLANIN          3
# 75                                                 IDO          3
# 76                                                RAGE          3
# 77                                                RCBF          3
# 78                                                RAC1          3
# 79                                                 CAT          3
# 80                                             ARMS 1P          3
# 81                                                HER2          3
# 82                                                 TAU          3
# 83                             EPIDERMAL GROWTH FACTOR          3
# 84                                          FIBRINOGEN          3
# 85                                               VP-16          3
# 86                                                PDL1          3
# 87                                                APOE          3
# 88                                                 SMO          3
# 89                                                 ADC          3
# 90                                                 GST          3
# 91                                               GSTM1          3
# 92                                               GSTT1          3
# 93                                                 ERK          3
# 94                                                 NEU          3
# 95                                         TRANSFERRIN          3
# 96                                                 UPA          3
# 97                                               PDGFR          3
# 98                                                 CSF          3
# 99                                              CTNNB1          3
# 100                                                MRS          3
# 101                                                BAX          3
# 102                                                TNM          3
# 103                                           TGF-BETA          3
# 104                                              UBE4B          2
# 105                                              MMP-2          2
# 106                                                TSC          2
# 107                                               MSH6          2
# 108                                   CYCLOOXYGENASE-2          2
# 109                                  ESTROGEN RECEPTOR          2
# 110                                      IL-2 RECEPTOR          2
# 111                                     ANGIOTENSIN II          2
# 112                                               E2F1          2
# 113                                             MAP2K1          2
# 114                        ADRENOCORTICOTROPIC HORMONE          2
# 115                                             PDGF-B          2
# 116                                               SAGE          2
# 117                                                AFP          2
# 118                                       IL-13RALPHA2          2
# 119             O6-METHYLGUANINE-DNA METHYLTRANSFERASE          2
# 120                                               C-11          2
# 121                                              FOXR2          2
# 122                                             GLUT-1          2
# 123                                           CDKN2A/B          2
# 124                                               BCOR          2
# 125                                              EGR-1          2
# 126                           RECEPTOR TYROSINE KINASE          2
# 127                                                XCT          2
# 128                                             IFITM3          2
# 129                                 C-REACTIVE PROTEIN          2
# 130                      MAMMALIAN TARGET OF RAPAMYCIN          2
# 131                                             DNMT3B          2
# 132                                                FUS          2
# 133                                               RELA          2
# 134                                                 TF          2
# 135                                               DDR1          2
# 136                                                JNK          2
# 137                                              COX-2          2
# 138                                               SV2A          2
# 139                                          CYCLIN D1          2
# 140                                               CCNU          2
# 141                                  ALPHA-FETOPROTEIN          2
# 142                                               P-GP          2
# 143                                           IFN-BETA          2
# 144                                              HIF-1          2
# 145                                                GD3          2
# 146                                      METHEMOGLOBIN          2
# 147                                              SOD-1          2
# 148                                             CTLA-4          2
# 149                                              FOXP3          2
# 150                         BONE MORPHOGENETIC PROTEIN          2
# 151                                               FHIT          2
# 152                                                 TR          2
# 153                                                CYP          2
# 154                                             MIR-21          2
# 155                 PROLIFERATING CELL NUCLEAR ANTIGEN          2
# 156                                            TGFBETA          2
# 157                                                VPF          2
# 158                                               INOS          2
# 159                                               SOX2          2
# 160                                            SMARCB1          2
# 161                                              S-100          2
# 162                                               EPOR          2
# 163                                              RAD51          2
# 164                                                EPO          2
# 165                                              ERBB2          2
# 166                                               IL-6          2
# 167                                                EGF          2
# 168                                NEUROFIBROMATOSIS 1          2
# 169                                                TIL          2
# 170                                               GRPR          2
# 171                                             PDGFRA          2
# 172                                                KIT          2
# 173                                                HSA          2
# 174                                                AHR          2
# 175                                                 PH          2
# 176                                               PARP          2
# 177                                              CLIC2          2
# 178                                                ABO          2
# 179                                             PART 5          2
# 180                                                FLT          2
# 181                                              STAT3          2
# 182                                                PGP          2
# 183                                               MDR1          2
# 184                                                MUL          2
# 185                               BETA 2-MICROGLOBULIN          2
# 186                                     P-GLYCOPROTEIN          2
# 187                                                PSK          2
# 188                                                CD8          2
# 189                                      TISSUE FACTOR          2
# 190                                                PSF          2
# 191                                               BMI1          2
# 192                                             ICAM-1          2
# 193                                               TEM1          2
# 194                                                MER          2
# 195                                               NEUN          2
# 196                                            INSULIN          2
# 197                                               SUR1          1
# 198                                                CIC          1
# 199                                                CPA          1
# 200                                              PD-L1          1
# 201                                              TSP-1          1
# 202                                               HIL2          1
# 203                                               HPSE          1
# 204                                             CYP2C9          1
# 205                                                TCR          1
# 206                                             IGFBP7          1
# 207                                                MYB          1
# 208                                               AXIN          1
# 209                                              DICER          1
# 210                                               FARR          1
# 211                                              ERCC3          1
# 212                                          PROLACTIN          1
# 213                                      INTERLEUKIN-4          1
# 214                                            GADD45G          1
# 215   GRANULOCYTE-MACROPHAGE COLONY-STIMULATING FACTOR          1
# 216                                               LIG4          1
# 217                                          IFN-ALPHA          1
# 218                                               DDB2          1
# 219                    TRANSFORMING GROWTH FACTOR-BETA          1
# 220                                               HSPG          1
# 221                                              FUBP1          1
# 222                                            GADD153          1
# 223                                       AQP-1 AND -4          1
# 224                                               A2MR          1
# 225                                              MYCL1          1
# 226                                                IFN          1
# 227                                                LIF          1
# 228                                              N MYC          1
# 229                                               CDH2          1
# 230                                              FOXC2          1
# 231                                                GSC          1
# 232                                                GLI          1
# 233                                              SNAI2          1
# 234                                                SAS          1
# 235                                             MYD116          1
# 236                                                 GK          1
# 237                                                NOC          1
# 238                                              VEGFR          1
# 239                                              SOX10          1
# 240                                                JOS          1
# 241                                               ETS2          1
# 242                                         HIF-1ALPHA          1
# 243                                               DAXX          1
# 244                                               SOD1          1
# 245                                              HTERT          1
# 246                                              FANCG          1
# 247                                             MPRAGE          1
# 248                                      INTERLEUKIN-2          1
# 249                                               SALP          1
# 250                              TUMOR NECROSIS FACTOR          1
# 251                                                P13          1
# 252                                               KRAS          1
# 253                                                QKI          1
# 254                                                P12          1
# 255                                               C-14          1
# 256                                      MIN(-1) 100 G          1
# 257                                                PSR          1
# 258                                                SNO          1
# 259                                              RHO C          1
# 260                                              PARP1          1
# 261                                               CPOX          1
# 262                                                CRP          1
# 263                                              CASP8          1
# 264                                                P25          1
# 265                                                P44          1
# 266                                                 SE          1
# 267                                         E-CADHERIN          1
# 268                                            GASTRIN          1
# 269                                                 TN          1
# 270                                             CH-TOG          1
# 271                                   GASTRIN RECEPTOR          1
# 272                                               RAC2          1
# 273                                                BIK          1
# 274                                              ALA/S          1
# 275                                INTERFERON-ALPHA 2B          1
# 276                                          ANNEXIN V          1
# 277                                             LAMP-1          1
# 278                                              HESRG          1
# 279                                             G-CSFR          1
# 280                                              SPARC          1
# 281                                         PDGFRALPHA          1
# 282                                               TEP1          1
# 283                                            TERF2IP          1
# 284                                               TNKS          1
# 285                                            TP53BP1          1
# 286                                               PD-1          1
# 287                                               SUFU          1
# 288                                              N-RAS          1
# 289                                               CD45          1
# 290                                               TPEF          1
# 291                                               NADE          1
# 292                                               MMPS          1
# 293                                           NECTIN-1          1
# 294                                                P21          1
# 295                                               RISC          1
# 296                                              TWIST          1
# 297                                                NFH          1
# 298                                                PLP          1
# 299                                               NAT2          1
# 300                                            OLIG1/2          1
# 301                                              OLIG1          1
# 302                                              TCF-4          1
# 303                                                RAC          1
# 304                                              TNKS2          1
# 305                                  ALPHA(V) INTEGRIN          1
# 306                                              MYBL1          1
# 307                                                MPR          1
# 308                                               KNL1          1
# 309                                               ASPM          1
# 310                                              CENPE          1
# 311                                               CITK          1
# 312                                              KIF14          1
# 313                                          GLI-1/2/3          1
# 314                                             E2F1-8          1
# 315                                            HIF-1/2          1
# 316                                            NFI-A/B          1
# 317                                               MYT1          1
# 318                                              MYT1L          1
# 319                                              PARP2          1
# 320                                            BRCA1/2          1
# 321                                              BRCA1          1
# 322                                              MMP14          1
# 323                                               INI1          1
# 324                                           ALPHASMA          1
# 325                                                G9A          1
# 326                                              GSTM3          1
# 327                                                ALK          1
# 328                                               LDHA          1
# 329                                              NTRK3          1
# 330                                                HIP          1
# 331                          CYCLIN-DEPENDENT KINASE 7          1
# 332                                               GSTS          1
# 333                                               SCFV          1
# 334                                                ART          1
# 335                                                DR5          1
# 336                                               FACS          1
# 337                                             KCA3.1          1
# 338                                              V-RAF          1
# 339                                              LIN28          1
# 340                                             LIN28B          1
# 341                                                U87          1
# 342                                         TRF1 AND 2          1
# 343                                              CCND2          1
# 344                                               TRF1          1
# 345                                               CST6          1
# 346                                        CATHEPSIN B          1
# 347                                              BMI-1          1
# 348            CYTOTOXIC T-LYMPHOCYTE ANTIGEN (CTLA)-4          1
# 349  PROGRAMMED CELL DEATH 1/PROGRAMMED CELL DEATH ...          1
# 350                                               DESI          1
# 351                                               MYCC          1
# 352                                                FGA          1
# 353                                                FGB          1
# 354                                             IGF-IR          1
# 355                                               NRSF          1
# 356                                                ZIP          1
# 357                                                AQ4          1
# 358                                              OCT-4          1
# 359                                               GPC2          1
# 360                                             CXCL10          1
# 361                                             LIN28A          1
# 362                                               MTDH          1
# 363                      ANAPLASTIC ASTROCYTOMA (AA) 2          1
# 364                                               TRF2          1
# 365                                              NTRK1          1
# 366                                               GNAS          1
# 367                                             CHI3L1          1
# 368                                            MIR-92B          1
# 369                                                PDE          1
# 370                          MALIGNANT LYMPHOMA (ML) 4          1
# 371                                                APT          1
# 372                                DNA POLYMERASE BETA          1
# 373                                              EPHX1          1
# 374                    PROGRAMMED CELL DEATH PROTEIN 1          1
# 375                                            HGF/MET          1
# 376                                                HGF          1
# 377                                                RTK          1
# 378                                    ACID CERAMIDASE          1
# 379                                                RAF          1
# 380                                              IDH-1          1
# 381                                              G-CSF          1
# 382                                             VEGFR2          1
# 383                              VEGF,-PIGF,-HIF1ALPHA          1
# 384                                                 SP          1
# 385                                       NK1 RECEPTOR          1
# 386                                                APR          1
# 387                                         ENDOSIALIN          1
# 388                                              CD141          1
# 389                                              THY-1          1
# 390                                              PHS-2          1
# 391                                                PHS          1
# 392                                              PHS-1          1
# 393                                         CSF, 3/230          1
# 394                                               LAT1          1
# 395                                            CORD 20          1
# 396                                             OLIG-2          1
# 397                                                AGA          1
# 398                                             ADAM19          1
# 399                                              POMT1          1
# 400                                             PPFIA4          1
# 401                                              CD62L          1
# 402                                                CTX          1
# 403                                                HUB          1
# 404                                            NCKAP1L          1
# 405                                            GPR37L1          1
# 406                                              CSPG4          1
# 407                                            C8ORF46          1
# 408                                    INTERFERON-BETA          1
# 409                                          ROD-OPSIN          1
# 410                            NEURON-SPECIFIC ENOLASE          1
# 411                                              CD 68          1
# 412                                              IL-10          1
# 413                                               TN-C          1
# 414                                               L3-5          1
# 415                                          MUSASHI-1          1
# 416                                               ET-1          1
# 417                                                BTK          1
# 418                                         TGF-BETA 1          1
# 419                                                SKN          1
# 420                                                OCT          1
# 421                                              OCT-1          1
# 422                                            N-OCT-3          1
# 423                                              OCT-2          1
# 424                                               IGF2          1
# 425                                              TSSC3          1
# 426                                              TRIM3          1
# 427                                           SLC22A18          1
# 428                                                ABC          1
# 429                                               INCA          1
# 430                                               MRP1          1
# 431                                               HDM2          1
# 432                                           NY-ESO-1          1
# 433                                                ALP          1
# 434                                              APO2L          1
# 435                                               PMS2          1
# 436                                               MSH2          1
# 437                                               IL 3          1
# 438                                              LEU 1          1
# 439                                              HLA-A          1
# 440                                        PROTHROMBIN          1
# 441                   TYPE II IODOTHYRONINE DEIODINASE          1
# 442                                          IFN GAMMA          1
# 443                                               IL 1          1
# 444                                               IL 6          1
# 445                                               MLH1          1
# 446                                         TGF BETA 2          1
# 447                                         IFN BETA 1          1
# 448                                                IL2          1
# 449                                               NPCR          1
# 450                                                PRL          1
# 451                                              SDF-1          1
# 452                        ADAMS 8, 12, 15, 17, AND 19          1
# 453                                               GBA2          1
# 454                                              ADAM8          1
# 455                                                PIA          1
# 456                                               TIMP          1
# 457                                             TIMP-2          1
# 458                                            ELASTIN          1
# 459                                              CIS-4          1
# 460                                              AQP-4          1
# 461                                                NMT          1
# 462                                               SPIN          1
# 463                                              MMP-9          1
# 464                                               RAF1          1
# 465                                              ASXL1          1
# 466                                                TTR          1
# 467                                                LCA          1
# 468                                               EZH2          1
# 469                                                TPA          1
# 470                                             MMP-12          1
# 471                                                MMP          1
# 472                                               KLF4          1
# 473                                            PLASMIN          1
# 474                                              CTLA4          1
# 475                            PROGRAMMED CELL DEATH 1          1
# 476                                                KEL          1
# 477                                   APOLIPOPROTEIN E          1
# 478                                         ALPHA 1-AT          1
# 479                              ALPHA 2-MACROGLOBULIN          1
# 480                                                PME          1
# 481                                               NMT2          1
# 482                                              IL-13          1
# 483                                             VEGF-D          1
# 484                                               AP-1          1
# 485                                                SLT          1
# 486                                                MTX          1
# 487                              CARBONIC ANHYDRASE IX          1
# 488                                                PKC          1
# 489                                              INI-1          1
# 490                                               COMT          1
# 491                METHYLGUANINE-DNA METHYLTRANSFERASE          1
# 492                                               NNOS          1
# 493                                          TGF-BETA1          1
# 494                                               MARK          1
# 495                                             MARK 3          1
# 496                                              T1/B1          1
# 497                                              T2/B2          1
# 498                                                CSK          1
# 499                                               BDNF          1
# 500                               FERRITIN HEAVY CHAIN          1
# 501                                         S-100 BETA          1
# 502                                             DNA-PK          1
# 503                                          MIRNA-221          1
# 504                                        FACTOR VIII          1
# 505                                          CASPASE-3          1
# 506                                              CAV-1          1
# 507                                              MIB.1          1
# 508                                         PROTEINASE          1
# 509                                                  A          1
# 510                                               ENOS          1
# 511                                               CT-H          1
# 512                                                GMP          1
# 513                            ORNITHINE DECARBOXYLASE          1
# 514                                            SYNEMIN          1
# 515                                               GOPC          1
# 516                                         PERIPHERIN          1
# 517                                   ALPHA-INTERNEXIN          1
# 518                                               ROS1          1
# 519                                              SESN1          1
# 520                                               TCF4          1
# 521                                               DRD1          1
# 522                                              PDE7A          1
# 523                                               AKT1          1
# 524                                              TRAF7          1
# 525                       INSULIN-LIKE GROWTH FACTOR I          1
# 526                                            TAPASIN          1
# 527                                            BIKUNIN          1
# 528                                                LYN          1
# 529                                     MET-ENKEPHALIN          1
# 530                                   PREPROENKEPHALIN          1
# 531                                                HCG          1
# 532                     GONADOTROPIN-RELEASING HORMONE          1
# 533                                           IFNGAMMA          1
# 534                                           TENASCIN          1
# 535                                              XRCC3          1
# 536                                              GAL-3          1
# 537                    BETA-GALACTOSIDE-BINDING LECTIN          1
# 538                    TRANSFORMING GROWTH FACTOR BETA          1
# 539                           CFLIP, EFFECTOR CASPASES          1
# 540                                               CHK1          1
# 541                                       CYTOCHROME C          1
# 542                                                ITK          1
# 543                                              HTRA1          1
# 544                                          PPARDELTA          1
# 545                                               CTSK          1
# 546                                               CTSF          1
# 547                                               CTBS          1
# 548                                               NEU4          1
# 549                                           MIR-216A          1
# 550                                             CD45RO          1
# 551                                          PPARGAMMA          1
# 552                                               IDO1          1
# 553                                          LINC00461          1
# 554                                              ABCB1          1
# 555                                               NGAL          1
# 556                                               CDC6          1
# 557                                               MCM5          1
# 558                                                TDO          1
# 559                                               CHK2          1
# 560                                         ENDOSTATIN          1
# 561                                              INK4A          1
# 562                                               CRNN          1
# 563                                         FAS LIGAND          1
# 564         TRANSFORMING GROWTH FACTOR-ALPHA AND -BETA          1
# 565                                              C-FOS          1
# 566                INSULIN-LIKE GROWTH FACTOR I AND II          1
# 567                                          C-ERB B-2          1
# 568                                                SAO          1
# 569                                                ATM          1
# 570                                                H15          1
# 571                                               DNMT          1
# 572                                              TTYH1          1
# 573                                               MTS1          1
# 574                                ALPHA-1-ANTITRYPSIN          1
# 575                           ALPHA-1-ANTICHYMOTRYPSIN          1
# 576                                           SH3PXD2A          1
# 577                                              ICH-1          1
# 578                                                ICE          1
# 579                                              BCL-X          1
# 580                                          CYCLIN D2          1
# 581                                              DMBT1          1
# 582                                                CBP          1
# 583                                                AXL          1
# 584                                               CDK9          1
# 585                                                BET          1
# 586                                               IRGD          1
# 587                                                NIR          1
# 588                          GLUTATHIONE S-TRANSFERASE          1
# 589                              CELL SURFACE RECEPTOR          1
# 590                                              IFN-B          1
# 591                                              SART1          1
# 592                            TUMOR-REJECTION ANTIGEN          1
# 593                                                TRK          1
# 594                        POLY(ADP-RIBOSE) POLYMERASE          1
# 595                                                EP4          1
# 596                                                CPM          1
# 597                                               HSF1          1
# 598                                                KGA          1
# 599                                               GLS2          1
# 600                                                GAB          1
# 601                                               BCRP          1
# 602                                              TRPV1          1
# 603                                              TRPA1          1
# 604                                                SEP          1
# 605                                            MIR-338          1
# 606                                               VIII          1
# 607                                              C-JUN          1
# 608                                             BCL-XL          1
# 609                                              MIB 1          1
# 610                                               RAC3          1
# 611                             CANCER-RELATED FATIGUE          1
# 612                                              NKG2D          1
# 613                                            MIR-219          1
# 614                                                TIP          1
# 615                   NADPH CYTOCHROME P-450 REDUCTASE          1
# 616                                            NANOLUC          1
# 617                                              C-KIT          1
# 618                                         PI3KC2BETA          1
# 619                                                MIM          1
# 620                        TUMOR NECROSIS FACTOR-ALPHA          1
# 621                                      DT-DIAPHORASE          1
# 622                                              DREAM          1
# 623                                            MIR-26A          1
# 624                                             UCHL-1          1
# 625                                               PLAP          1
# 626                                               TR 1          1
# 627                                                TAG          1
# 628                                                PRB          1
# 629                                           MIR-106B          1
# 630                                           THROMBIN          1
# 631                                          FACTOR XA          1
# 632           O(6)-METHYLGUANINE-DNA METHYLTRANSFERASE          1
# 633                                             CXCL12          1
# 634                                               A 20          1
# 635                                               BAI1          1
# 636                                             CATH D          1
# 637           O-6 METHYLGUANINE- DNA METHYLTRANSFERASE          1
# 638                                               AQP1          1
# 639                                         AQP1 AND 4          1
# 640                                         PROMININ-1          1
# 641                                     ADRENOMEDULLIN          1
# 642                                               NPM1          1
# 643                                           HDAC1-11          1
# 644                                         CALMODULIN          1
# 645                                             ENDO 1          1
# 646                                               CHOP          1
# 647                                              VP 16          1
# 648                                                CB1          1
# 649                                                CB2          1
# 650                                              AQP 4          1
# 651                                               CD34          1
# 652                                               BMP4          1
# 653                                         GALECTIN-3          1
# 654                                            FACSTAR          1
# 655                                               CMET          1
# 656                                              LEU 7          1
# 657                     MYELIN-ASSOCIATED GLYCOPROTEIN          1
# 658                                           MUC 8-22          1
# 659                                    SERINE PROTEASE          1
# 660                                               P-31          1
# 661                                               TIC1          1
# 662                                             PARP-1          1
# 663                                               CTSC          1
# 664                                             PTPN11          1
# 665                                              CASP9          1
# 666                                                ABR          1
# 667                   TRANSFORMING GROWTH FACTOR-ALPHA          1
# 668                    MECHANISTIC TARGET OF RAPAMYCIN          1
# 669                              GLUTATHIONE REDUCTASE          1
# 670                                             N-WASP          1
# 671                                   TUMOR SUPPRESSOR          1
# 672                                                GPS          1
# 673             GLIAL FIBRILLARY ACIDIC PROTEIN, S-100          1
# 674                                                ECM          1
# 675                                     SONIC HEDGEHOG          1
# 676                                               RHOA          1
# 677                                                GHR          1
# 678                                                P15          1
# 679                               DNA POLYMERASE ALPHA          1
# 680                                        PCNA/CYCLIN          1
# 681                             CYCLOOXYGENASE (COX)-2          1
# 682                                                LOX          1
# 683                                               RHOB          1
# 684                                             HSP-27          1
# 685                                              SOD-2          1
# 686                                              CAT B          1
# 687                                             LEPTIN          1
# 688                                                LIP          1
# 689                                           TGFBETA1          1
# 690                                           TGFBETA2          1
# 691                                           TGFBETA3          1
# 692                                                LAC          1
# 693                                                CRT          1
# 694                                                PS1          1
# 695                                       EGF RECEPTOR          1
# 696                              FIBROBLAST INTERFERON          1
# 697                                                SRC          1
# 698                                             K1, K2          1
# 699                                                ODC          1
# 700                                                NPY          1
# 701                                         K1, K2, K3          1
# 702                                               IL-4          1
# 703                                               X-CT          1
# 704                                               YB-1          1
# 705                                                 GR          1
# 706                                               GS-X          1
# 707                                                NAT          1
# 708                                                JAK          1
# 709                                             STAT-5          1
# 710                                              GST-P          1
# 711                                                MAG          1
# 712                                         CALCITONIN          1
# 713                                               PS 2          1
# 714                                        OSTEOPONTIN          1
# 715                                              N-MYC          1
# 716                                              MAD-4          1
# 717                                    ARMS 1, 2 AND 3          1
# 718                                                CAM          1
# 719                                                 GS          1
# 720                                                GCL          1
# 721                                               LACS          1
# 722                               ACETYLCHOLINESTERASE          1
# 723                                               MAP2          1
# 724                                         IL-2RALPHA          1
# 725                                             DESMIN          1
# 726                                     CYTOKERATIN 18          1
# 727                                          PLASTIN-1          1
# 728                                          FIBULIN-1          1
# 729                           GLUTATHIONE PEROXIDASE 3          1
# 730                               COAGULATION FACTOR V          1
# 731                                      TRANSTHYRETIN          1
# 732                                    STANNIOCALCIN-1          1
# 733                                             KIR7.1          1
# 734                                               CDT1          1
# 735                                            GEMININ          1
# 736                                          IFN-GAMMA          1

# %% [markdown]
# ### <span style="color:red"> HTML Frequency Table For Total Gene Names</span>

# %%
# Count the total number of rows in the table
total_rows = len(TOTAL_freq_table)-1

# Turning the full table to HTML
html_fullTOTAL_table = TOTAL_freq_table.to_html(index=False)

# Writing HTML to a file
with open('full_total_table.html', 'w') as file:
    file.write('<!DOCTYPE html>\n<html>\n<head>\n')
    file.write('<style>\n')
    file.write('th {text-align: center;}\n')
    file.write('</style>\n')
    file.write('</head>\n<body>\n')
    file.write(f'<h1>Total Number of Rows: {total_rows}</h1>\n')  # Include total rows count
    file.write('<h1>Full Total Gene Frequency Table</h1>\n')
    file.write(html_fullTOTAL_table)
    file.write('\n</body>\n</html>')

# %%
# Count the total number of rows in the table
total_rows = len(TOTAL_freq_table)-1

# Number of Frequencies that are unique (only have 1) for Full-text
gene_freq1_TotalTable = TOTAL_freq_table[TOTAL_freq_table['Frequency'] == 1]
num_geneFreq1_TotalTable = len(gene_freq1_TotalTable)

# Turning the full table to HTML
html_fullTOTAL_table = TOTAL_freq_table.to_html(index=False)

# Writing HTML to a file
with open('full_total_table.html', 'w') as file:
    file.write('<!DOCTYPE html>\n<html>\n<head>\n')
    file.write('<style>\n')
    file.write('th {text-align: center;}\n')
    file.write('</style>\n')
    file.write('</head>\n<body>\n')
    # Include both total rows and unique count
    file.write(f'<h1>Total Number of Rows: {total_rows}</h1>\n')
    file.write(f'<h1>Number of Unique Frequencies(Frequencies of only 1): {num_geneFreq1_TotalTable}</h1>\n')
    file.write('<h1>Full Total Gene Frequency Table</h1>\n')
    file.write(html_fullTOTAL_table)
    file.write('\n</body>\n</html>')

# %%
# Top 10 Gene Names for TOTAL
top_ten = 10
top_TOTAL_geneNames = TOTAL_freq_table.head(top_ten)
print(top_TOTAL_geneNames)
# Out:
#   Gene Names  Frequency
# 0       BRAF         33
# 1       MGMT         33
# 2        IDH         31
# 3       EGFR         31
# 4       GFAP         30
# 5        P53         21
# 6       IDH1         18
# 7      MIB-1         18
# 8       TP53         17
# 9       VEGF         16

# %%
# least frequent for TOTAL
totalGeneName = len(TOTAL_freq_table)

# The number of genes you want to retrieve
bottom_ten = 10

# calculate the stating index
start_index = max(0, totalGeneName - bottom_ten)

# Output the bottom ten
bottomTOTAL_geneNames = TOTAL_freq_table.tail(totalGeneName-start_index)
print(bottomTOTAL_geneNames)
# Out:
#                    Gene Names  Frequency
# 727                 PLASTIN-1          1
# 728                 FIBULIN-1          1
# 729  GLUTATHIONE PEROXIDASE 3          1
# 730      COAGULATION FACTOR V          1
# 731             TRANSTHYRETIN          1
# 732           STANNIOCALCIN-1          1
# 733                    KIR7.1          1
# 734                      CDT1          1
# 735                   GEMININ          1
# 736                 IFN-GAMMA          1

# %%
# Number of Frequencies that are unique (only have 1) for TOTAL
gene_freq1 = TOTAL_freq_table[TOTAL_freq_table['Frequency'] == 1]
num_geneFreq1 = len(gene_freq1)
print(num_geneFreq1)
# Out:
# 540

# %% [markdown]
# ## Bar graphs

# %% [markdown]
# ### <span style="color:red"> Abrstact </span>

# %%
# Top Ten Abstracts
import matplotlib.pyplot as plt
import random

# Generate random colors for each bar
num_bars = len(top_ab_geneNames)
random_colors = ['#' + '%06X' % random.randint(0, 0xFFFFFF) for _ in range(num_bars)]

# Plotting the bar graph
plt.figure(figsize=(8, 8))
plt.bar(top_ab_geneNames['Gene Names'], top_ab_geneNames['Frequency'], color=random_colors)
plt.xlabel('Gene Names')
plt.ylabel('Frequency')
plt.title('Top 10 Abstracts: Gene Names Frequency')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### <span style="color:red"> Full-Text</span>

# %%
# Top Ten Full Abstracts
import matplotlib.pyplot as plt

# Plotting the bar graph
plt.figure(figsize=(8, 8))
plt.bar(top_ft_geneNames['Gene Names'], top_ft_geneNames['Frequency'], color=random_colors)
plt.xlabel('Gene Names')
plt.ylabel('Frequency')
plt.title('Top 10 Full-Text: Gene Names Frequency')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### <span style="color:red"> Total Gene Names</span>

# %%
# Top Ten Total Gene Names
import matplotlib.pyplot as plt

# Plotting the bar graph
plt.figure(figsize=(8, 8))
plt.bar(top_TOTAL_geneNames['Gene Names'], top_TOTAL_geneNames['Frequency'], color=random_colors)
plt.xlabel('Gene Names')
plt.ylabel('Frequency')
plt.title('Top 10 TOTAL: Gene Names Frequency')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Word cloud

# %% [markdown]
# ### <span style="color: red"> Abstract</span>

# %%
# Abstracts
from wordcloud import WordCloud

all_ab_geneNames = ' '.join(filter(None, ab_geneNames))

ab_wordcloud = WordCloud(width=800, height=400, background_color='white').generate(all_ab_geneNames)

plt.figure(figsize=(10,8))
plt.imshow(ab_wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Abstract Word Cloud of Gene Names')
plt.show()

# %% [markdown]
# ### <span style="color:red"> Full-Text</span>

# %%
# Full Text
from wordcloud import WordCloud

all_ft_geneNames = ' '.join(filter(None, ft_geneNames))

ft_wordcloud = WordCloud(width=800, height=400, background_color='white').generate(all_ft_geneNames)

plt.figure(figsize=(10,8))
plt.imshow(ft_wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Full Text Word Cloud of Gene Names')
plt.show()

# %% [markdown]
# ### <span style="color:red"> TOTAL Gene Names</span>

# %%
# Total
from wordcloud import WordCloud

all_geneNames_TOTAL = ' '.join(filter(None, geneNames_TOTAL))

geneNames_TOTAL_wordcloud = WordCloud(width=800, height=400, background_color='white').generate(all_geneNames_TOTAL)

plt.figure(figsize=(10,8))
plt.imshow(geneNames_TOTAL_wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Overall Total of Gene Names')
plt.show()

# %%
from docx2html import convert

# Convert the Word document to HTML
html_content = convert("Identifying Genes Associated with Brain Tumors.docx")

# Save the HTML file
with open("Identifying Genes Associated with Brain Tumors.html", "w") as f:
    f.write(html_content)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12380\1416796888.py in <module>
# ----> 1 from docx2html import convert
#       2
#       3 # Convert the Word document to HTML
#       4 html_content = convert("Identifying Genes Associated with Brain Tumors.docx")
#       5
#
# ModuleNotFoundError: No module named 'docx2html'
